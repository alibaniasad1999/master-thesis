# %%
### make environment for reinforcement learning ###
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.integrate import ode
import gym
from gym import spaces

# %%
# example of scipy ode solver
def f(t, y, params):
    dydt = np.zeros(2)
    dydt[0] = y[1]
    dydt[1] = -params[0]*y[0] - params[1]*y[1]
    return dydt

def solve_ode(params):
    t0 = 0
    t1 = 0.01
    dt = 0.01
    y0 = [1, 0]
    r = ode(f).set_integrator('dopri5')
    r.set_initial_value(y0, t0).set_f_params(params)
    t = []
    y = []
    while r.successful() and r.t < t1:
        r.integrate(r.t+dt)
        t.append(r.t)
        y.append(r.y)
    return np.array(t), np.array(y)

# %%
# python env for mass spring damper from gym
class MassSpringDamperEnv(gym.Env):
    def __init__(self) -> None:
        super().__init__()
        self.spring_constant = 1
        self.damping_constant = 0.1
        self.mass = 1
        self.gravity = 9.8
        self.dt = 0.01
        self.max_t = 10
        self.max_x = 10
        self.max_v = 10
        self.max_u = 10
        self.action_space = spaces.Box(low=-self.max_u, high=self.max_u, shape=(1,))
        self.observation_space = spaces.Box(low=np.array([-self.max_x, -self.max_v]), high=np.array([self.max_x, self.max_v]), shape=(2,))
        self.reset()

    def reset(self):
        self.t = 0
        self.x = 0
        self.v = 0
        return np.array([self.x, self.v])
    
    def step(self, u): # state, reward, done, info
        self.t += self.dt
        self.x += self.v*self.dt
        self.v += (self.gravity - self.damping_constant*self.v - self.spring_constant*self.x/self.mass + u/self.mass)*self.dt

        if self.t >= self.max_t:
            done = True
        else:
            done = False
        
        return np.array([self.x, self.v, 0, done, {}], dtype=object)


    
    def render(self):
        pass

    def close(self):
        pass

# %%
# python env for mass spring damper check #
if __name__ == "__main__":
    env = MassSpringDamperEnv()
    env.reset()
    for i in range(1000):
        u = np.random.randn(1)
        result = env.step(u)
        print(result)
        state = result[0]
        reward = result[1]
        done = result[2]
        info = result[3]
        print(env.step(u))
    env.close()
# Out:
# [0.0 array([0.0819265]) 0 False {}]
# [array([0.00081926]) array([0.16376287]) 0 False {}]
# [array([0.00245689]) array([0.27221646]) 0 False {}]
# [array([0.00517906]) array([0.38053437]) 0 False {}]
# [array([0.0089844]) array([0.47770243]) 0 False {}]
# [array([0.01376143]) array([0.57472555]) 0 False {}]
# [array([0.01950868]) array([0.67654395]) 0 False {}]
# [array([0.02627412]) array([0.77819288]) 0 False {}]
# [array([0.03405605]) array([0.87588005]) 0 False {}]
# [array([0.04281485]) array([0.97338195]) 0 False {}]
# [array([0.05254867]) array([1.06558398]) 0 False {}]
# [array([0.06320451]) array([1.15758724]) 0 False {}]
# [array([0.07478038]) array([1.24987344]) 0 False {}]
# [array([0.08727912]) array([1.34194237]) 0 False {}]
# [array([0.10069854]) array([1.42717061]) 0 False {}]
# [array([0.11497025]) array([1.5121709]) 0 False {}]
# [array([0.13009196]) array([1.61610631]) 0 False {}]
# [array([0.14625302]) array([1.71977619]) 0 False {}]
# [array([0.16345078]) array([1.80210814]) 0 False {}]
# [array([0.18147186]) array([1.88417755]) 0 False {}]
# [array([0.20031364]) array([1.95438411]) 0 False {}]
# [array([0.21985748]) array([2.02432503]) 0 False {}]
# [array([0.24010073]) array([2.1273024]) 0 False {}]
# [array([0.26137375]) array([2.22996407]) 0 False {}]
# [array([0.28367339]) array([2.34050769]) 0 False {}]
# [array([0.30707847]) array([2.45070673]) 0 False {}]
# [array([0.33158554]) array([2.51930646]) 0 False {}]
# [array([0.3567786]) array([2.58758565]) 0 False {}]
# [array([0.38265446]) array([2.68439149]) 0 False {}]
# [array([0.40949837]) array([2.78083208]) 0 False {}]
# [array([0.43730669]) array([2.87478558]) 0 False {}]
# [array([0.46605455]) array([2.96835765]) 0 False {}]
# [array([0.49573813]) array([3.06237358]) 0 False {}]
# [array([0.52636186]) array([3.15598926]) 0 False {}]
# [array([0.55792176]) array([3.25725304]) 0 False {}]
# [array([0.59049429]) array([3.35808983]) 0 False {}]
# [array([0.62407518]) array([3.43337376]) 0 False {}]
# [array([0.65840892]) array([3.50823907]) 0 False {}]
# [array([0.69349131]) array([3.59642549]) 0 False {}]
# [array([0.72945557]) array([3.68416409]) 0 False {}]
# [array([0.76629721]) array([3.77259392]) 0 False {}]
# [array([0.80402315]) array([3.86055805]) 0 False {}]
# [array([0.84262873]) array([3.96334637]) 0 False {}]
# [array([0.88226219]) array([4.06563557]) 0 False {}]
# [array([0.92291855]) array([4.15093594]) 0 False {}]
# [array([0.96442791]) array([4.23573592]) 0 False {}]
# [array([1.00678527]) array([4.31087629]) 0 False {}]
# [array([1.04989403]) array([4.38551044]) 0 False {}]
# [array([1.09374913]) array([4.47007899]) 0 False {}]
# [array([1.13844992]) array([4.55411596]) 0 False {}]
# [array([1.18399108]) array([4.64103575]) 0 False {}]
# [array([1.23040144]) array([4.72740451]) 0 False {}]
# [array([1.27767549]) array([4.80245152]) 0 False {}]
# [array([1.3257]) array([4.87694324]) 0 False {}]
# [array([1.37446943]) array([4.95160985]) 0 False {}]
# [array([1.42398553]) array([5.02570663]) 0 False {}]
# [array([1.4742426]) array([5.10456326]) 0 False {}]
# [array([1.52528823]) array([5.18283058]) 0 False {}]
# [array([1.57711654]) array([5.26278631]) 0 False {}]
# [array([1.6297444]) array([5.34213581]) 0 False {}]
# [array([1.68316576]) array([5.42019203]) 0 False {}]
# [array([1.73736768]) array([5.49762817]) 0 False {}]
# [array([1.79234396]) array([5.57914551]) 0 False {}]
# [array([1.84813541]) array([5.66002342]) 0 False {}]
# [array([1.90473565]) array([5.72515344]) 0 False {}]
# [array([1.96198718]) array([5.78964581]) 0 False {}]
# [array([2.01988364]) array([5.8687045]) 0 False {}]
# [array([2.07857069]) array([5.94709726]) 0 False {}]
# [array([2.13804166]) array([6.04101493]) 0 False {}]
# [array([2.19845181]) array([6.13423458]) 0 False {}]
# [array([2.25979415]) array([6.19390044]) 0 False {}]
# [array([2.32173316]) array([6.25288725]) 0 False {}]
# [array([2.38426203]) array([6.33656625]) 0 False {}]
# [array([2.44762769]) array([6.41952791]) 0 False {}]
# [array([2.51182297]) array([6.47670881]) 0 False {}]
# [array([2.57659006]) array([6.53318486]) 0 False {}]
# [array([2.64192191]) array([6.58670519]) 0 False {}]
# [array([2.70778896]) array([6.63951334]) 0 False {}]
# [array([2.77418409]) array([6.68740828]) 0 False {}]
# [array([2.84105818]) array([6.73458659]) 0 False {}]
# [array([2.90840404]) array([6.78943626]) 0 False {}]
# [array([2.97629841]) array([6.84355214]) 0 False {}]
# [array([3.04473393]) array([6.90810401]) 0 False {}]
# [array([3.11381497]) array([6.97190052]) 0 False {}]
# [array([3.18353397]) array([7.0403498]) 0 False {}]
# [array([3.25393747]) array([7.1080266]) 0 False {}]
# [array([3.32501774]) array([7.16464898]) 0 False {}]
# [array([3.39666423]) array([7.22049827]) 0 False {}]
# [array([3.46886921]) array([7.27922088]) 0 False {}]
# [array([3.54166142]) array([7.33715685]) 0 False {}]
# [array([3.61503299]) array([7.37273424]) 0 False {}]
# [array([3.68876033]) array([7.40753878]) 0 False {}]
# [array([3.76283572]) array([7.46768051]) 0 False {}]
# [array([3.83751252]) array([7.52701532]) 0 False {}]
# [array([3.91278267]) array([7.58702153]) 0 False {}]
# [array([3.98865289]) array([7.64620903]) 0 False {}]
# [array([4.06511498]) array([7.6929321]) 0 False {}]
# [array([4.1420443]) array([7.73883916]) 0 False {}]
# [array([4.21943269]) array([7.78675614]) 0 False {}]
# [array([4.29730025]) array([7.83384652]) 0 False {}]
# [array([4.37563872]) array([7.88756851]) 0 False {}]
# [array([4.4545144]) array([7.94044801]) 0 False {}]
# [array([4.53391888]) array([7.98376048]) 0 False {}]
# [array([4.61375649]) array([8.02623125]) 0 False {}]
# [array([4.6940188]) array([8.06143059]) 0 False {}]
# [array([4.77463311]) array([8.09578859]) 0 False {}]
# [array([4.85559099]) array([8.12077135]) 0 False {}]
# [array([4.93679871]) array([8.14491704]) 0 False {}]
# [array([5.01824788]) array([8.18264625]) 0 False {}]
# [array([5.10007434]) array([8.21951948]) 0 False {}]
# [array([5.18226953]) array([8.26198064]) 0 False {}]
# [array([5.26488934]) array([8.30357315]) 0 False {}]
# [array([5.34792507]) array([8.34566645]) 0 False {}]
# [array([5.43138174]) array([8.38688309]) 0 False {}]
# [array([5.51525057]) array([8.42370714]) 0 False {}]
# [array([5.59948764]) array([8.45965199]) 0 False {}]
# [array([5.68408416]) array([8.50894178]) 0 False {}]
# [array([5.76917358]) array([8.55733138]) 0 False {}]
# [array([5.85474689]) array([8.5839735]) 0 False {}]
# [array([5.94058663]) array([8.60973059]) 0 False {}]
# [array([6.02668393]) array([8.63531796]) 0 False {}]
# [array([6.11303711]) array([8.66001621]) 0 False {}]
# [array([6.19963727]) array([8.69337275]) 0 False {}]
# [array([6.286571]) array([8.72582659]) 0 False {}]
# [array([6.37382927]) array([8.74775969]) 0 False {}]
# [array([6.46130686]) array([8.76879609]) 0 False {}]
# [array([6.54899482]) array([8.80911775]) 0 False {}]
# [array([6.637086]) array([8.84851817]) 0 False {}]
# [array([6.72557118]) array([8.8621859]) 0 False {}]
# [array([6.81419304]) array([8.87495374]) 0 False {}]
# [array([6.90294258]) array([8.88606909]) 0 False {}]
# [array([6.99180327]) array([8.89628472]) 0 False {}]
# [array([7.08076612]) array([8.92604577]) 0 False {}]
# [array([7.17002658]) array([8.95488445]) 0 False {}]
# [array([7.25957542]) array([8.96224535]) 0 False {}]
# [array([7.34919787]) array([8.96870265]) 0 False {}]
# [array([7.4388849]) array([8.97814182]) 0 False {}]
# [array([7.52866632]) array([8.98667374]) 0 False {}]
# [array([7.61853306]) array([9.01736178]) 0 False {}]
# [array([7.70870667]) array([9.04711739]) 0 False {}]
# [array([7.79917785]) array([9.060013]) 0 False {}]
# [array([7.88977798]) array([9.07198971]) 0 False {}]
# [array([7.98049788]) array([9.09528379]) 0 False {}]
# [array([8.07145071]) array([9.11764505]) 0 False {}]
# [array([8.16262716]) array([9.13373532]) 0 False {}]
# [array([8.25396452]) array([9.14889612]) 0 False {}]
# [array([8.34545348]) array([9.14088295]) 0 False {}]
# [array([8.43686231]) array([9.1319637]) 0 False {}]
# [array([8.52818194]) array([9.12973421]) 0 False {}]
# [array([8.61947929]) array([9.12659398]) 0 False {}]
# [array([8.71074523]) array([9.12516887]) 0 False {}]
# [array([8.80199691]) array([9.12283266]) 0 False {}]
# [array([8.89322524]) array([9.13451975]) 0 False {}]
# [array([8.98457044]) array([9.1452817]) 0 False {}]
# [array([9.07602326]) array([9.14311086]) 0 False {}]
# [array([9.16745436]) array([9.14002787]) 0 False {}]
# [array([9.25885464]) array([9.12097095]) 0 False {}]
# [array([9.35006435]) array([9.10102098]) 0 False {}]
# [array([9.44107456]) array([9.09283653]) 0 False {}]
# [array([9.53200293]) array([9.08375098]) 0 False {}]
# [array([9.62284044]) array([9.05777833]) 0 False {}]
# [array([9.71341822]) array([9.03092588]) 0 False {}]
# [array([9.80372748]) array([9.01422066]) 0 False {}]
# [array([9.89386969]) array([8.99663072]) 0 False {}]
# [array([9.98383599]) array([8.9848698]) 0 False {}]
# [array([10.07368469]) array([8.97222215]) 0 False {}]
# [array([10.16340691]) array([8.95624451]) 0 False {}]
# [array([10.25296936]) array([8.93938723]) 0 False {}]
# [array([10.34236323]) array([8.93448837]) 0 False {}]
# [array([10.43170811]) array([8.92870096]) 0 False {}]
# [array([10.52099512]) array([8.90888093]) 0 False {}]
# [array([10.61008393]) array([8.88818983]) 0 False {}]
# [array([10.69896583]) array([8.86264773]) 0 False {}]
# [array([10.78759231]) array([8.83624491]) 0 False {}]
# [array([10.87595476]) array([8.80344977]) 0 False {}]
# [array([10.96398926]) array([8.76980707]) 0 False {}]
# [array([11.05168733]) array([8.73688018]) 0 False {}]
# [array([11.13905613]) array([8.70311254]) 0 False {}]
# [array([11.22608725]) array([8.67894856]) 0 False {}]
# [array([11.31287674]) array([8.65394084]) 0 False {}]
# [array([11.39941615]) array([8.62824474]) 0 False {}]
# [array([11.48569859]) array([8.60171151]) 0 False {}]
# [array([11.57171571]) array([8.56518915]) 0 False {}]
# [array([11.6573676]) array([8.5278468]) 0 False {}]
# [array([11.74264607]) array([8.51161764]) 0 False {}]
# [array([11.82776225]) array([8.49455355]) 0 False {}]
# [array([11.91270778]) array([8.46181946]) 0 False {}]
# [array([11.99732598]) array([8.42827191]) 0 False {}]
# [array([12.08160869]) array([8.3894334]) 0 False {}]
# [array([12.16550303]) array([8.34979479]) 0 False {}]
# [array([12.24900098]) array([8.33480539]) 0 False {}]
# [array([12.33234903]) array([8.31899749]) 0 False {}]
# [array([12.41553901]) array([8.28252777]) 0 False {}]
# [array([12.49836428]) array([8.24526626]) 0 False {}]
# [array([12.58081695]) array([8.19930931]) 0 False {}]
# [array([12.66281004]) array([8.15257838]) 0 False {}]
# [array([12.74433582]) array([8.12238763]) 0 False {}]
# [array([12.8255597]) array([8.09141484]) 0 False {}]
# [array([12.90647385]) array([8.04124025]) 0 False {}]
# [array([12.98688625]) array([7.99031172]) 0 False {}]
# [array([13.06678937]) array([7.94871308]) 0 False {}]
# [array([13.1462765]) array([7.90636117]) 0 False {}]
# [array([13.22534011]) array([7.86456582]) 0 False {}]
# [array([13.30398577]) array([7.8220258]) 0 False {}]
# [array([13.38220603]) array([7.78726811]) 0 False {}]
# [array([13.46007871]) array([7.75176645]) 0 False {}]
# [array([13.53759637]) array([7.69207477]) 0 False {}]
# [array([13.61451712]) array([7.63167356]) 0 False {}]
# [array([13.69083385]) array([7.58216303]) 0 False {}]
# [array([13.76665549]) array([7.5319438]) 0 False {}]
# [array([13.84197492]) array([7.47698506]) 0 False {}]
# [array([13.91674477]) array([7.42133359]) 0 False {}]
# [array([13.99095811]) array([7.37360494]) 0 False {}]
# [array([14.06469416]) array([7.32518665]) 0 False {}]
# [array([14.13794603]) array([7.26661237]) 0 False {}]
# [array([14.21061215]) array([7.20737001]) 0 False {}]
# [array([14.28268585]) array([7.1329415]) 0 False {}]
# [array([14.35401526]) array([7.05787412]) 0 False {}]
# [array([14.42459401]) array([7.00328386]) 0 False {}]
# [array([14.49462684]) array([6.94804786]) 0 False {}]
# [array([14.56410732]) array([6.90893]) 0 False {}]
# [array([14.63319662]) array([6.86916036]) 0 False {}]
# [array([14.70188823]) array([6.81555465]) 0 False {}]
# [array([14.77004377]) array([6.761321]) 0 False {}]
# [array([14.83765698]) array([6.70284166]) 0 False {}]
# [array([14.9046854]) array([6.64375052]) 0 False {}]
# [array([14.9711229]) array([6.57990395]) 0 False {}]
# [array([15.03692194]) array([6.51546323]) 0 False {}]
# [array([15.10207658]) array([6.45339652]) 0 False {}]
# [array([15.16661054]) array([6.39074653]) 0 False {}]
# [array([15.23051801]) array([6.32584274]) 0 False {}]
# [array([15.29377643]) array([6.26037127]) 0 False {}]
# [array([15.35638015]) array([6.19952054]) 0 False {}]
# [array([15.41837535]) array([6.13811071]) 0 False {}]
# [array([15.47975646]) array([6.08549931]) 0 False {}]
# [array([15.54061145]) array([6.03233197]) 0 False {}]
# [array([15.60093477]) array([5.96676185]) 0 False {}]
# [array([15.66060239]) array([5.90066061]) 0 False {}]
# [array([15.719609]) array([5.83355864]) 0 False {}]
# [array([15.77794458]) array([5.76594042]) 0 False {}]
# [array([15.83560399]) array([5.71768996]) 0 False {}]
# [array([15.89278089]) array([5.66891597]) 0 False {}]
# [array([15.94947005]) array([5.6037592]) 0 False {}]
# [array([16.00550764]) array([5.53810721]) 0 False {}]
# [array([16.06088871]) array([5.45904655]) 0 False {}]
# [array([16.11547918]) array([5.37951904]) 0 False {}]
# [array([16.16927437]) array([5.31989363]) 0 False {}]
# [array([16.2224733]) array([5.25979585]) 0 False {}]
# [array([16.27507126]) array([5.17442658]) 0 False {}]
# [array([16.32681553]) array([5.08862522]) 0 False {}]
# [array([16.37770178]) array([5.02974545]) 0 False {}]
# [array([16.42799923]) array([4.97042159]) 0 False {}]
# [array([16.47770345]) array([4.90136495]) 0 False {}]
# [array([16.5267171]) array([4.83188724]) 0 False {}]
# [array([16.57503597]) array([4.7281152]) 0 False {}]
# [array([16.62231712]) array([4.62397412]) 0 False {}]
# [array([16.66855687]) array([4.53396973]) 0 False {}]
# [array([16.71389656]) array([4.44360196]) 0 False {}]
# [array([16.75833258]) array([4.37355795]) 0 False {}]
# [array([16.80206816]) array([4.30314663]) 0 False {}]
# [array([16.84509963]) array([4.23940578]) 0 False {}]
# [array([16.88749369]) array([4.17530473]) 0 False {}]
# [array([16.92924673]) array([4.10431362]) 0 False {}]
# [array([16.97028987]) array([4.03298307]) 0 False {}]
# [array([17.0106197]) array([3.96228213]) 0 False {}]
# [array([17.05024252]) array([3.89125567]) 0 False {}]
# [array([17.08915508]) array([3.82821637]) 0 False {}]
# [array([17.12743724]) array([3.76485728]) 0 False {}]
# [array([17.16508581]) array([3.68874937]) 0 False {}]
# [array([17.20197331]) array([3.61234868]) 0 False {}]
# [array([17.2380968]) array([3.53185638]) 0 False {}]
# [array([17.27341536]) array([3.4510914]) 0 False {}]
# [array([17.30792627]) array([3.37320515]) 0 False {}]
# [array([17.34165832]) array([3.29505947]) 0 False {}]
# [array([17.37460892]) array([3.22440045]) 0 False {}]
# [array([17.40685292]) array([3.15348964]) 0 False {}]
# [array([17.43838782]) array([3.06861208]) 0 False {}]
# [array([17.46907394]) array([2.98351252]) 0 False {}]
# [array([17.49890907]) array([2.9043127]) 0 False {}]
# [array([17.52795219]) array([2.82490165]) 0 False {}]
# [array([17.55620121]) array([2.73493567]) 0 False {}]
# [array([17.58355057]) array([2.64478617]) 0 False {}]
# [array([17.60999843]) array([2.5628769]) 0 False {}]
# [array([17.6356272]) array([2.48079326]) 0 False {}]
# [array([17.66043513]) array([2.40247136]) 0 False {}]
# [array([17.68445984]) array([2.32398753]) 0 False {}]
# [array([17.70769972]) array([2.25143874]) 0 False {}]
# [array([17.73021411]) array([2.17873735]) 0 False {}]
# [array([17.75200148]) array([2.10125735]) 0 False {}]
# [array([17.77301405]) array([2.0236447]) 0 False {}]
# [array([17.7932505]) array([1.94014179]) 0 False {}]
# [array([17.81265192]) array([1.85652837]) 0 False {}]
# [array([17.8312172]) array([1.77389906]) 0 False {}]
# [array([17.84895619]) array([1.691175]) 0 False {}]
# [array([17.86586794]) array([1.61746424]) 0 False {}]
# [array([17.88204258]) array([1.54366544]) 0 False {}]
# [array([17.89747924]) array([1.4575744]) 0 False {}]
# [array([17.91205498]) array([1.37142368]) 0 False {}]
# [array([17.92576922]) array([1.2781136]) 0 False {}]
# [array([17.93855036]) array([1.18476901]) 0 False {}]
# [array([17.95039805]) array([1.09640102]) 0 False {}]
# [array([17.96136206]) array([1.00801176]) 0 False {}]
# [array([17.97144217]) array([0.93897382]) 0 False {}]
# [array([17.98083191]) array([0.86991102]) 0 False {}]
# [array([17.98953102]) array([0.7819097]) 0 False {}]
# [array([17.99735012]) array([0.69391818]) 0 False {}]
# [array([18.0042893]) array([0.61394348]) 0 False {}]
# [array([18.01042874]) array([0.53398736]) 0 False {}]
# [array([18.01576861]) array([0.45275495]) 0 False {}]
# [array([18.02029616]) array([0.37155849]) 0 False {}]
# [array([18.02401174]) array([0.29201386]) 0 False {}]
# [array([18.02693188]) array([0.21251957]) 0 False {}]
# [array([18.02905708]) array([0.10773944]) 0 False {}]
# [array([18.03013447]) array([0.00305331]) 0 False {}]
# [array([18.03016501]) array([-0.08928969]) 0 False {}]
# [array([18.02927211]) array([-0.18153142]) 0 False {}]
# [array([18.02745679]) array([-0.25119225]) 0 False {}]
# [array([18.02494487]) array([-0.3207583]) 0 False {}]
# [array([18.02173729]) array([-0.41862696]) 0 False {}]
# [array([18.01755102]) array([-0.51635589]) 0 False {}]
# [array([18.01238746]) array([-0.58792606]) 0 False {}]
# [array([18.0065082]) array([-0.65936587]) 0 False {}]
# [array([17.99991454]) array([-0.74604552]) 0 False {}]
# [array([17.99245409]) array([-0.83256388]) 0 False {}]
# [array([17.98412845]) array([-0.89798984]) 0 False {}]
# [array([17.97514855]) array([-0.96326057]) 0 False {}]
# [array([17.96551594]) array([-1.03929092]) 0 False {}]
# [array([17.95512303]) array([-1.1151413]) 0 False {}]
# [array([17.94397162]) array([-1.19219064]) 0 False {}]
# [array([17.93204971]) array([-1.26904371]) 0 False {}]
# [array([17.91935928]) array([-1.36108417]) 0 False {}]
# [array([17.90574844]) array([-1.45289648]) 0 False {}]
# [array([17.89121947]) array([-1.53335325]) 0 False {}]
# [array([17.87588594]) array([-1.61357623]) 0 False {}]
# [array([17.85975018]) array([-1.69097847]) 0 False {}]
# [array([17.84284039]) array([-1.76813421]) 0 False {}]
# [array([17.82515905]) array([-1.83993012]) 0 False {}]
# [array([17.80675975]) array([-1.91147025]) 0 False {}]
# [array([17.78764505]) array([-1.98200246]) 0 False {}]
# [array([17.76782502]) array([-2.05226594]) 0 False {}]
# [array([17.74730236]) array([-2.14390245]) 0 False {}]
# [array([17.72586334]) array([-2.23523293]) 0 False {}]
# [array([17.70351101]) array([-2.32100846]) 0 False {}]
# [array([17.68030092]) array([-2.4064661]) 0 False {}]
# [array([17.65623626]) array([-2.49872414]) 0 False {}]
# [array([17.63124902]) array([-2.59064004]) 0 False {}]
# [array([17.60534262]) array([-2.66178407]) 0 False {}]
# [array([17.57872478]) array([-2.73259078]) 0 False {}]
# [array([17.55139887]) array([-2.81601356]) 0 False {}]
# [array([17.52323874]) array([-2.89907131]) 0 False {}]
# [array([17.49424802]) array([-2.99505201]) 0 False {}]
# [array([17.4642975]) array([-3.09063722]) 0 False {}]
# [array([17.43339113]) array([-3.18057182]) 0 False {}]
# [array([17.40158541]) array([-3.27009844]) 0 False {}]
# [array([17.36888443]) array([-3.33733025]) 0 False {}]
# [array([17.33551113]) array([-3.4041611]) 0 False {}]
# [array([17.30146951]) array([-3.48223389]) 0 False {}]
# [array([17.26664718]) array([-3.55988039]) 0 False {}]
# [array([17.23104837]) array([-3.6328195]) 0 False {}]
# [array([17.19472018]) array([-3.70532239]) 0 False {}]
# [array([17.15766695]) array([-3.77337064]) 0 False {}]
# [array([17.11993325]) array([-3.8409735]) 0 False {}]
# [array([17.08152351]) array([-3.92176452]) 0 False {}]
# [array([17.04230587]) array([-4.00208257]) 0 False {}]
# [array([17.00228504]) array([-4.06636327]) 0 False {}]
# [array([16.96162141]) array([-4.13017305]) 0 False {}]
# [array([16.92031968]) array([-4.20537002]) 0 False {}]
# [array([16.87826598]) array([-4.28007126]) 0 False {}]
# [array([16.83546526]) array([-4.34929546]) 0 False {}]
# [array([16.79197231]) array([-4.4180155]) 0 False {}]
# [array([16.74779215]) array([-4.48121259]) 0 False {}]
# [array([16.70298003]) array([-4.54389836]) 0 False {}]
# [array([16.65754105]) array([-4.59777006]) 0 False {}]
# [array([16.61156334]) array([-4.6511281]) 0 False {}]
# [array([16.56505206]) array([-4.70707369]) 0 False {}]
# [array([16.51798133]) array([-4.76249263]) 0 False {}]
# [array([16.4703564]) array([-4.83154622]) 0 False {}]
# [array([16.42204094]) array([-4.90004761]) 0 False {}]
# [array([16.37304046]) array([-4.9646822]) 0 False {}]
# [array([16.32339364]) array([-5.02875568]) 0 False {}]
# [array([16.27310608]) array([-5.08632515]) 0 False {}]
# [array([16.22224283]) array([-5.14332842]) 0 False {}]
# [array([16.17080955]) array([-5.19884503]) 0 False {}]
# [array([16.1188211]) array([-5.25378623]) 0 False {}]
# [array([16.06628324]) array([-5.30519257]) 0 False {}]
# [array([16.01323131]) array([-5.35601699]) 0 False {}]
# [array([15.95967114]) array([-5.41915151]) 0 False {}]
# [array([15.90547962]) array([-5.48168098]) 0 False {}]
# [array([15.85066281]) array([-5.56035373]) 0 False {}]
# [array([15.79505928]) array([-5.63839176]) 0 False {}]
# [array([15.73867536]) array([-5.6982362]) 0 False {}]
# [array([15.681693]) array([-5.75745096]) 0 False {}]
# [array([15.62411849]) array([-5.80277653]) 0 False {}]
# [array([15.56609072]) array([-5.84747649]) 0 False {}]
# [array([15.50761596]) array([-5.89288796]) 0 False {}]
# [array([15.44868708]) array([-5.93766473]) 0 False {}]
# [array([15.38931043]) array([-5.9913181]) 0 False {}]
# [array([15.32939725]) array([-6.04431868]) 0 False {}]
# [array([15.26895406]) array([-6.09035636]) 0 False {}]
# [array([15.2080505]) array([-6.13573897]) 0 False {}]
# [array([15.14669311]) array([-6.18076116]) 0 False {}]
# [array([15.0848855]) array([-6.22512026]) 0 False {}]
# [array([15.0226343]) array([-6.28750006]) 0 False {}]
# [array([14.9597593]) array([-6.34918874]) 0 False {}]
# [array([14.89626741]) array([-6.39017248]) 0 False {}]
# [array([14.83236568]) array([-6.43047622]) 0 False {}]
# [array([14.76806092]) array([-6.48764317]) 0 False {}]
# [array([14.70318449]) array([-6.5441042]) 0 False {}]
# [array([14.63774345]) array([-6.58585833]) 0 False {}]
# [array([14.57188486]) array([-6.62691213]) 0 False {}]
# [array([14.50561574]) array([-6.66127937]) 0 False {}]
# [array([14.43900295]) array([-6.69494611]) 0 False {}]
# [array([14.37205349]) array([-6.73879437]) 0 False {}]
# [array([14.30466554]) array([-6.78192489]) 0 False {}]
# [array([14.2368463]) array([-6.80677712]) 0 False {}]
# [array([14.16877852]) array([-6.83092381]) 0 False {}]
# [array([14.10046929]) array([-6.87077907]) 0 False {}]
# [array([14.0317615]) array([-6.9099074]) 0 False {}]
# [array([13.96266242]) array([-6.9258272]) 0 False {}]
# [array([13.89340415]) array([-6.9410385]) 0 False {}]
# [array([13.82399376]) array([-6.96308285]) 0 False {}]
# [array([13.75436294]) array([-6.98440885]) 0 False {}]
# [array([13.68451885]) array([-7.02742161]) 0 False {}]
# [array([13.61424463]) array([-7.06968862]) 0 False {}]
# [array([13.54354774]) array([-7.10558321]) 0 False {}]
# [array([13.47249191]) array([-7.14073134]) 0 False {}]
# [array([13.4010846]) array([-7.15514934]) 0 False {}]
# [array([13.32953311]) array([-7.16883742]) 0 False {}]
# [array([13.25784473]) array([-7.20160383]) 0 False {}]
# [array([13.18582869]) array([-7.23361732]) 0 False {}]
# [array([13.11349252]) array([-7.27615311]) 0 False {}]
# [array([13.04073099]) array([-7.31791874]) 0 False {}]
# [array([12.9675518]) array([-7.35927974]) 0 False {}]
# [array([12.893959]) array([-7.39986344]) 0 False {}]
# [array([12.81996037]) array([-7.42726643]) 0 False {}]
# [array([12.74568771]) array([-7.45389928]) 0 False {}]
# [array([12.67114871]) array([-7.46656379]) 0 False {}]
# [array([12.59648308]) array([-7.47846897]) 0 False {}]
# [array([12.52169839]) array([-7.50465743]) 0 False {}]
# [array([12.44665181]) array([-7.53006923]) 0 False {}]
# [array([12.37135112]) array([-7.54368027]) 0 False {}]
# [array([12.29591432]) array([-7.55652334]) 0 False {}]
# [array([12.22034908]) array([-7.57240208]) 0 False {}]
# [array([12.14462506]) array([-7.5875077]) 0 False {}]
# [array([12.06874998]) array([-7.59427168]) 0 False {}]
# [array([11.99280727]) array([-7.60026947]) 0 False {}]
# [array([11.91680457]) array([-7.61414705]) 0 False {}]
# [array([11.8406631]) array([-7.62724933]) 0 False {}]
# [array([11.76439061]) array([-7.63738425]) 0 False {}]
# [array([11.68801677]) array([-7.6467453]) 0 False {}]
# [array([11.61154931]) array([-7.63802786]) 0 False {}]
# [array([11.53516904]) array([-7.62855534]) 0 False {}]
# [array([11.45888348]) array([-7.62552648]) 0 False {}]
# [array([11.38262822]) array([-7.62173809]) 0 False {}]
# [array([11.30641084]) array([-7.64127513]) 0 False {}]
# [array([11.22999809]) array([-7.6600285]) 0 False {}]
# [array([11.1533978]) array([-7.64929664]) 0 False {}]
# [array([11.07690483]) array([-7.63781058]) 0 False {}]
# [array([11.00052673]) array([-7.6564538]) 0 False {}]
# [array([10.92396219]) array([-7.67431274]) 0 False {}]
# [array([10.84721906]) array([-7.69134923]) 0 False {}]
# [array([10.77030557]) array([-7.70759956]) 0 False {}]
# [array([10.69322957]) array([-7.72940477]) 0 False {}]
# [array([10.61593553]) array([-7.75041523]) 0 False {}]
# [array([10.53843137]) array([-7.75645701]) 0 False {}]
# [array([10.4608668]) array([-7.76171711]) 0 False {}]
# [array([10.38324963]) array([-7.75710029]) 0 False {}]
# [array([10.30567863]) array([-7.75171237]) 0 False {}]
# [array([10.22816151]) array([-7.74540238]) 0 False {}]
# [array([10.15070748]) array([-7.73832417]) 0 False {}]
# [array([10.07332424]) array([-7.72655053]) 0 False {}]
# [array([9.99605874]) array([-7.71401602]) 0 False {}]
# [array([9.91891858]) array([-7.72037107]) 0 False {}]
# [array([9.84171487]) array([-7.72594772]) 0 False {}]
# [array([9.76445539]) array([-7.71923741]) 0 False {}]
# [array([9.68726301]) array([-7.71176189]) 0 False {}]
# [array([9.6101454]) array([-7.71515483]) 0 False {}]
# [array([9.53299385]) array([-7.71777286]) 0 False {}]
# [array([9.45581612]) array([-7.71590007]) 0 False {}]
# [array([9.37865712]) array([-7.71325756]) 0 False {}]
# [array([9.30152454]) array([-7.7282002]) 0 False {}]
# [array([9.22424254]) array([-7.74235508]) 0 False {}]
# [array([9.14681899]) array([-7.73105423]) 0 False {}]
# [array([9.06950845]) array([-7.71899158]) 0 False {}]
# [array([8.99231853]) array([-7.69044077]) 0 False {}]
# [array([8.91541412]) array([-7.66114947]) 0 False {}]
# [array([8.83880263]) array([-7.64630104]) 0 False {}]
# [array([8.76233962]) array([-7.63070283]) 0 False {}]
# [array([8.68603259]) array([-7.61844878]) 0 False {}]
# [array([8.6098481]) array([-7.60544514]) 0 False {}]
# [array([8.53379365]) array([-7.58147326]) 0 False {}]
# [array([8.45797892]) array([-7.55676721]) 0 False {}]
# [array([8.38241125]) array([-7.54297267]) 0 False {}]
# [array([8.30698152]) array([-7.52843762]) 0 False {}]
# [array([8.23169714]) array([-7.50176699]) 0 False {}]
# [array([8.15667947]) array([-7.47437285]) 0 False {}]
# [array([8.08193574]) array([-7.44529817]) 0 False {}]
# [array([8.00748276]) array([-7.41550803]) 0 False {}]
# [array([7.93332768]) array([-7.38693631]) 0 False {}]
# [array([7.85945832]) array([-7.35765446]) 0 False {}]
# [array([7.78588178]) array([-7.3375074]) 0 False {}]
# [array([7.7125067]) array([-7.31664674]) 0 False {}]
# [array([7.63934023]) array([-7.29034759]) 0 False {}]
# [array([7.56643676]) array([-7.26334571]) 0 False {}]
# [array([7.4938033]) array([-7.23299034]) 0 False {}]
# [array([7.4214734]) array([-7.20194203]) 0 False {}]
# [array([7.34945398]) array([-7.17301688]) 0 False {}]
# [array([7.27772381]) array([-7.14340335]) 0 False {}]
# [array([7.20628977]) array([-7.1077028]) 0 False {}]
# [array([7.13521275]) array([-7.07132718]) 0 False {}]
# [array([7.06449947]) array([-7.05313004]) 0 False {}]
# [array([6.99396817]) array([-7.03424579]) 0 False {}]
# [array([6.92362572]) array([-6.99586013]) 0 False {}]
# [array([6.85366712]) array([-6.95681327]) 0 False {}]
# [array([6.78409898]) array([-6.93477535]) 0 False {}]
# [array([6.71475123]) array([-6.91206599]) 0 False {}]
# [array([6.64563057]) array([-6.87085815]) 0 False {}]
# [array([6.57692199]) array([-6.82900445]) 0 False {}]
# [array([6.50863194]) array([-6.7896264]) 0 False {}]
# [array([6.44073568]) array([-6.74960877]) 0 False {}]
# [array([6.37323959]) array([-6.69774738]) 0 False {}]
# [array([6.30626212]) array([-6.64526807]) 0 False {}]
# [array([6.23980944]) array([-6.61428214]) 0 False {}]
# [array([6.17366662]) array([-6.58266576]) 0 False {}]
# [array([6.10783996]) array([-6.5386705]) 0 False {}]
# [array([6.04245325]) array([-6.49406536]) 0 False {}]
# [array([5.9775126]) array([-6.4546863]) 0 False {}]
# [array([5.91296574]) array([-6.41470115]) 0 False {}]
# [array([5.84881873]) array([-6.38364111]) 0 False {}]
# [array([5.78498231]) array([-6.35197377]) 0 False {}]
# [array([5.72146258]) array([-6.29604326]) 0 False {}]
# [array([5.65850214]) array([-6.23953908]) 0 False {}]
# [array([5.59610675]) array([-6.17549625]) 0 False {}]
# [array([5.53435179]) array([-6.11089991]) 0 False {}]
# [array([5.47324279]) array([-6.05025803]) 0 False {}]
# [array([5.41274021]) array([-5.98907177]) 0 False {}]
# [array([5.35284949]) array([-5.94356228]) 0 False {}]
# [array([5.29341387]) array([-5.89750395]) 0 False {}]
# [array([5.23443883]) array([-5.84864984]) 0 False {}]
# [array([5.17595233]) array([-5.79925971]) 0 False {}]
# [array([5.11795974]) array([-5.75044113]) 0 False {}]
# [array([5.06045532]) array([-5.70109633]) 0 False {}]
# [array([5.00344436]) array([-5.63908655]) 0 False {}]
# [array([4.9470535]) array([-5.57657488]) 0 False {}]
# [array([4.89128775]) array([-5.52970931]) 0 False {}]
# [array([4.83599065]) array([-5.48233763]) 0 False {}]
# [array([4.78116728]) array([-5.4131159]) 0 False {}]
# [array([4.72703612]) array([-5.34342208]) 0 False {}]
# [array([4.6736019]) array([-5.29035335]) 0 False {}]
# [array([4.62069836]) array([-5.23680866]) 0 False {}]
# [array([4.56833028]) array([-5.17705082]) 0 False {}]
# [array([4.51655977]) array([-5.11683503]) 0 False {}]
# [array([4.46539142]) array([-5.04218049]) 0 False {}]
# [array([4.41496961]) array([-4.96709638]) 0 False {}]
# [array([4.36529865]) array([-4.92200713]) 0 False {}]
# [array([4.31607858]) array([-4.87647077]) 0 False {}]
# [array([4.26731387]) array([-4.8259377]) 0 False {}]
# [array([4.21905449]) array([-4.77497258]) 0 False {}]
# [array([4.17130477]) array([-4.71470681]) 0 False {}]
# [array([4.1241577]) array([-4.65402983]) 0 False {}]
# [array([4.0776174]) array([-4.58515968]) 0 False {}]
# [array([4.03176581]) array([-4.51589988]) 0 False {}]
# [array([3.98660681]) array([-4.44403428]) 0 False {}]
# [array([3.94216646]) array([-4.37179614]) 0 False {}]
# [array([3.8984485]) array([-4.3164248]) 0 False {}]
# [array([3.85528425]) array([-4.26067719]) 0 False {}]
# [array([3.81267748]) array([-4.20241056]) 0 False {}]
# [array([3.77065338]) array([-4.14378196]) 0 False {}]
# [array([3.72921556]) array([-4.09346695]) 0 False {}]
# [array([3.68828089]) array([-4.0427929]) 0 False {}]
# [array([3.64785296]) array([-3.97869049]) 0 False {}]
# [array([3.60806605]) array([-3.91425431]) 0 False {}]
# [array([3.56892351]) array([-3.86774302]) 0 False {}]
# [array([3.53024608]) array([-3.82089147]) 0 False {}]
# [array([3.49203717]) array([-3.75498233]) 0 False {}]
# [array([3.45448734]) array([-3.6887636]) 0 False {}]
# [array([3.41759971]) array([-3.62641276]) 0 False {}]
# [array([3.38133558]) array([-3.56376163]) 0 False {}]
# [array([3.34569796]) array([-3.49429916]) 0 False {}]
# [array([3.31075497]) array([-3.42455672]) 0 False {}]
# [array([3.2765094]) array([-3.36047037]) 0 False {}]
# [array([3.2429047]) array([-3.29611207]) 0 False {}]
# [array([3.20994358]) array([-3.22442965]) 0 False {}]
# [array([3.17769928]) array([-3.15249647]) 0 False {}]
# [array([3.14617432]) array([-3.08266631]) 0 False {}]
# [array([3.11534766]) array([-3.01259771]) 0 False {}]
# [array([3.08522168]) array([-2.9555985]) 0 False {}]
# [array([3.05566569]) array([-2.89836074]) 0 False {}]
# [array([3.02668209]) array([-2.82578863]) 0 False {}]
# [array([2.9984242]) array([-2.75300652]) 0 False {}]
# [array([2.97089413]) array([-2.67614767]) 0 False {}]
# [array([2.94413266]) array([-2.59909806]) 0 False {}]
# [array([2.91814168]) array([-2.53782117]) 0 False {}]
# [array([2.89276346]) array([-2.47635178]) 0 False {}]
# [array([2.86799995]) array([-2.41275858]) 0 False {}]
# [array([2.84387236]) array([-2.34898769]) 0 False {}]
# [array([2.82038248]) array([-2.28553824]) 0 False {}]
# [array([2.7975271]) array([-2.22192369]) 0 False {}]
# [array([2.77530787]) array([-2.15641647]) 0 False {}]
# [array([2.7537437]) array([-2.09075912]) 0 False {}]
# [array([2.73283611]) array([-2.04015903]) 0 False {}]
# [array([2.71243452]) array([-1.98940553]) 0 False {}]
# [array([2.69254046]) array([-1.92914686]) 0 False {}]
# [array([2.673249]) array([-1.86875553]) 0 False {}]
# [array([2.65456144]) array([-1.77659782]) 0 False {}]
# [array([2.63679546]) array([-1.6843546]) 0 False {}]
# [array([2.61995192]) array([-1.59783162]) 0 False {}]
# [array([2.6039736]) array([-1.51123537]) 0 False {}]
# [array([2.58886125]) array([-1.43920676]) 0 False {}]
# [array([2.57446918]) array([-1.36710625]) 0 False {}]
# [array([2.56079812]) array([-1.27470116]) 0 False {}]
# [array([2.5480511]) array([-1.18226102]) 0 False {}]
# [array([2.53622849]) array([-1.10567324]) 0 False {}]
# [array([2.52517176]) array([-1.02905149]) 0 False {}]
# [array([2.51488125]) array([-0.96131514]) 0 False {}]
# [array([2.5052681]) array([-0.89355039]) 0 False {}]
# [array([2.49633259]) array([-0.81986853]) 0 False {}]
# [array([2.48813391]) array([-0.74617835]) 0 False {}]
# [array([2.48067212]) array([-0.68310644]) 0 False {}]
# [array([2.47384106]) array([-0.62002928]) 0 False {}]
# [array([2.46764077]) array([-0.55535354]) 0 False {}]
# [array([2.46208723]) array([-0.49068694]) 0 False {}]
# [array([2.45718036]) array([-0.40937511]) 0 False {}]
# [array([2.45308661]) array([-0.32810365]) 0 False {}]
# [array([2.44980557]) array([-0.25453296]) 0 False {}]
# [array([2.44726024]) array([-0.18101039]) 0 False {}]
# [array([2.44545014]) array([-0.11635784]) 0 False {}]
# [array([2.44428656]) array([-0.0517583]) 0 False {}]
# [array([2.44376898]) array([0.02091639]) 0 False {}]
# [array([2.44397814]) array([0.09351631]) 0 False {}]
# [array([2.4449133]) array([0.17368306]) 0 False {}]
# [array([2.44665014]) array([0.25375228]) 0 False {}]
# [array([2.44918766]) array([0.30123322]) 0 False {}]
# [array([2.45219999]) array([0.34863656]) 0 False {}]
# [array([2.45568636]) array([0.41402897]) 0 False {}]
# [array([2.45982665]) array([0.47931459]) 0 False {}]
# [array([2.46461979]) array([0.58995093]) 0 False {}]
# [array([2.4705193]) array([0.70041764]) 0 False {}]
# [array([2.47752348]) array([0.77168293]) 0 False {}]
# [array([2.48524031]) array([0.8427998]) 0 False {}]
# [array([2.4936683]) array([0.91183211]) 0 False {}]
# [array([2.50278663]) array([0.98070421]) 0 False {}]
# [array([2.51259367]) array([1.06269346]) 0 False {}]
# [array([2.5232206]) array([1.14449445]) 0 False {}]
# [array([2.53466555]) array([1.20345343]) 0 False {}]
# [array([2.54670008]) array([1.2622331]) 0 False {}]
# [array([2.55932241]) array([1.32183792]) 0 False {}]
# [array([2.57254079]) array([1.38125094]) 0 False {}]
# [array([2.5863533]) array([1.44644038]) 0 False {}]
# [array([2.6008177]) array([1.51141999]) 0 False {}]
# [array([2.6159319]) array([1.56938498]) 0 False {}]
# [array([2.63162575]) array([1.62713506]) 0 False {}]
# [array([2.64789711]) array([1.70844254]) 0 False {}]
# [array([2.66498153]) array([1.78949786]) 0 False {}]
# [array([2.68287651]) array([1.84359076]) 0 False {}]
# [array([2.70131242]) array([1.8974452]) 0 False {}]
# [array([2.72028687]) array([1.95270285]) 0 False {}]
# [array([2.7398139]) array([2.00770997]) 0 False {}]
# [array([2.759891]) array([2.06906567]) 0 False {}]
# [array([2.78058165]) array([2.13015311]) 0 False {}]
# [array([2.80188318]) array([2.19747064]) 0 False {}]
# [array([2.82385789]) array([2.2645011]) 0 False {}]
# [array([2.8465029]) array([2.33907509]) 0 False {}]
# [array([2.86989365]) array([2.41334061]) 0 False {}]
# [array([2.89402706]) array([2.46329981]) 0 False {}]
# [array([2.91866006]) array([2.51296273]) 0 False {}]
# [array([2.94378968]) array([2.57936187]) 0 False {}]
# [array([2.9695833]) array([2.64543668]) 0 False {}]
# [array([2.99603767]) array([2.71234131]) 0 False {}]
# [array([3.02316108]) array([2.7789078]) 0 False {}]
# [array([3.05095016]) array([2.84297709]) 0 False {}]
# [array([3.07937993]) array([2.90669802]) 0 False {}]
# [array([3.10844691]) array([2.96604079]) 0 False {}]
# [array([3.13810732]) array([3.02502762]) 0 False {}]
# [array([3.1683576]) array([3.08478319]) 0 False {}]
# [array([3.19920543]) array([3.14417053]) 0 False {}]
# [array([3.23064713]) array([3.19587549]) 0 False {}]
# [array([3.26260589]) array([3.24720915]) 0 False {}]
# [array([3.29507798]) array([3.30837183]) 0 False {}]
# [array([3.3281617]) array([3.3691425]) 0 False {}]
# [array([3.36185312]) array([3.43691239]) 0 False {}]
# [array([3.39622225]) array([3.50427081]) 0 False {}]
# [array([3.43126496]) array([3.56038679]) 0 False {}]
# [array([3.46686882]) array([3.61609061]) 0 False {}]
# [array([3.50302973]) array([3.67466754]) 0 False {}]
# [array([3.5397764]) array([3.73281842]) 0 False {}]
# [array([3.57710459]) array([3.79048284]) 0 False {}]
# [array([3.61500942]) array([3.84771054]) 0 False {}]
# [array([3.65348652]) array([3.90690913]) 0 False {}]
# [array([3.69255561]) array([3.96565782]) 0 False {}]
# [array([3.73221219]) array([4.02129801]) 0 False {}]
# [array([3.77242517]) array([4.07648042]) 0 False {}]
# [array([3.81318998]) array([4.13822079]) 0 False {}]
# [array([3.85457218]) array([4.19948559]) 0 False {}]
# [array([3.89656704]) array([4.25473236]) 0 False {}]
# [array([3.93911436]) array([4.30949841]) 0 False {}]
# [array([3.98220935]) array([4.35643661]) 0 False {}]
# [array([4.02577371]) array([4.40289221]) 0 False {}]
# [array([4.06980264]) array([4.44804901]) 0 False {}]
# [array([4.11428313]) array([4.49271584]) 0 False {}]
# [array([4.15921028]) array([4.55418682]) 0 False {}]
# [array([4.20475215]) array([4.61514091]) 0 False {}]
# [array([4.25090356]) array([4.68119091]) 0 False {}]
# [array([4.29771547]) array([4.74670674]) 0 False {}]
# [array([4.34518254]) array([4.79705939]) 0 False {}]
# [array([4.39315313]) array([4.84688198]) 0 False {}]
# [array([4.44162195]) array([4.89652573]) 0 False {}]
# [array([4.49058721]) array([4.94563018]) 0 False {}]
# [array([4.54004351]) array([4.99208336]) 0 False {}]
# [array([4.58996434]) array([5.03799088]) 0 False {}]
# [array([4.64034425]) array([5.11039032]) 0 False {}]
# [array([4.69144816]) array([5.18220632]) 0 False {}]
# [array([4.74327022]) array([5.22770675]) 0 False {}]
# [array([4.79554729]) array([5.27263891]) 0 False {}]
# [array([4.84827368]) array([5.30735286]) 0 False {}]
# [array([4.9013472]) array([5.34150137]) 0 False {}]
# [array([4.95476222]) array([5.38516347]) 0 False {}]
# [array([5.00861385]) array([5.4282434]) 0 False {}]
# [array([5.06289629]) array([5.4638139]) 0 False {}]
# [array([5.11753443]) array([5.49880244]) 0 False {}]
# [array([5.17252245]) array([5.55826157]) 0 False {}]
# [array([5.22810507]) array([5.61710541]) 0 False {}]
# [array([5.28427612]) array([5.66457736]) 0 False {}]
# [array([5.34092189]) array([5.71143539]) 0 False {}]
# [array([5.39803625]) array([5.75204085]) 0 False {}]
# [array([5.45555666]) array([5.79203049]) 0 False {}]
# [array([5.51347696]) array([5.82887254]) 0 False {}]
# [array([5.57176569]) array([5.86509485]) 0 False {}]
# [array([5.63041664]) array([5.89175988]) 0 False {}]
# [array([5.68933423]) array([5.91780906]) 0 False {}]
# [array([5.74851232]) array([5.94729969]) 0 False {}]
# [array([5.80798532]) array([5.97616611]) 0 False {}]
# [array([5.86774698]) array([6.01792009]) 0 False {}]
# [array([5.92792618]) array([6.05903052]) 0 False {}]
# [array([5.98851649]) array([6.0770027]) 0 False {}]
# [array([6.04928652]) array([6.09434921]) 0 False {}]
# [array([6.11023001]) array([6.11526622]) 0 False {}]
# [array([6.17138267]) array([6.13555079]) 0 False {}]
# [array([6.23273818]) array([6.16760149]) 0 False {}]
# [array([6.29441419]) array([6.19900337]) 0 False {}]
# [array([6.35640423]) array([6.23653274]) 0 False {}]
# [array([6.41876955]) array([6.27340092]) 0 False {}]
# [array([6.48150356]) array([6.29369096]) 0 False {}]
# [array([6.54444047]) array([6.31333134]) 0 False {}]
# [array([6.60757379]) array([6.32075367]) 0 False {}]
# [array([6.67078132]) array([6.32753651]) 0 False {}]
# [array([6.73405669]) array([6.34875824]) 0 False {}]
# [array([6.79754427]) array([6.36932388]) 0 False {}]
# [array([6.86123751]) array([6.39867256]) 0 False {}]
# [array([6.92522423]) array([6.42735202]) 0 False {}]
# [array([6.98949775]) array([6.45953138]) 0 False {}]
# [array([7.05409307]) array([6.4910326]) 0 False {}]
# [array([7.11900339]) array([6.51565023]) 0 False {}]
# [array([7.1841599]) array([6.53959167]) 0 False {}]
# [array([7.24955581]) array([6.54549915]) 0 False {}]
# [array([7.31501081]) array([6.55074618]) 0 False {}]
# [array([7.38051827]) array([6.57145345]) 0 False {}]
# [array([7.4462328]) array([6.59148287]) 0 False {}]
# [array([7.51214763]) array([6.61050329]) 0 False {}]
# [array([7.57825266]) array([6.62884364]) 0 False {}]
# [array([7.6445411]) array([6.64808396]) 0 False {}]
# [array([7.71102194]) array([6.66664024]) 0 False {}]
# [array([7.77768834]) array([6.6747231]) 0 False {}]
# [array([7.84443557]) array([6.68213041]) 0 False {}]
# [array([7.91125688]) array([6.69704097]) 0 False {}]
# [array([7.97822729]) array([6.71126692]) 0 False {}]
# [array([8.04533996]) array([6.7311488]) 0 False {}]
# [array([8.11265144]) array([6.75033768]) 0 False {}]
# [array([8.18015482]) array([6.75718577]) 0 False {}]
# [array([8.24772668]) array([6.7633513]) 0 False {}]
# [array([8.31536019]) array([6.78027936]) 0 False {}]
# [array([8.38316298]) array([6.79651247]) 0 False {}]
# [array([8.45112811]) array([6.78657288]) 0 False {}]
# [array([8.51899384]) array([6.77596456]) 0 False {}]
# [array([8.58675348]) array([6.77034184]) 0 False {}]
# [array([8.6544569]) array([6.7640477]) 0 False {}]
# [array([8.72209738]) array([6.76755315]) 0 False {}]
# [array([8.78977291]) array([6.77037833]) 0 False {}]
# [array([8.85747669]) array([6.78064193]) 0 False {}]
# [array([8.92528311]) array([6.7902172]) 0 False {}]
# [array([8.99318529]) array([6.79557825]) 0 False {}]
# [array([9.06114107]) array([6.80025437]) 0 False {}]
# [array([9.12914361]) array([6.78609276]) 0 False {}]
# [array([9.19700454]) array([6.7712667]) 0 False {}]
# [array([9.26471721]) array([6.77518439]) 0 False {}]
# [array([9.33246905]) array([6.77842065]) 0 False {}]
# [array([9.40025326]) array([6.78311336]) 0 False {}]
# [array([9.46808439]) array([6.78712306]) 0 False {}]
# [array([9.53595562]) array([6.79161149]) 0 False {}]
# [array([9.60387174]) array([6.79541627]) 0 False {}]
# [array([9.6718259]) array([6.79382174]) 0 False {}]
# [array([9.73976412]) array([6.79154942]) 0 False {}]
# [array([9.80767961]) array([6.78416328]) 0 False {}]
# [array([9.87552124]) array([6.77610611]) 0 False {}]
# [array([9.9432823]) array([6.76620508]) 0 False {}]
# [array([10.01094435]) array([6.75563732]) 0 False {}]
# [array([10.07850073]) array([6.75140971]) 0 False {}]
# [array([10.14601482]) array([6.7465112]) 0 False {}]
# [array([10.21347994]) array([6.75154209]) 0 False {}]
# [array([10.28099536]) array([6.75589279]) 0 False {}]
# [array([10.34855429]) array([6.73911708]) 0 False {}]
# [array([10.41594546]) array([6.72168424]) 0 False {}]
# [array([10.4831623]) array([6.68390229]) 0 False {}]
# [array([10.55000132]) array([6.64548972]) 0 False {}]
# [array([10.61645622]) array([6.62390635]) 0 False {}]
# [array([10.68269528]) array([6.60168217]) 0 False {}]
# [array([10.7487121]) array([6.59762179]) 0 False {}]
# [array([10.81468832]) array([6.59290572]) 0 False {}]
# [array([10.88061738]) array([6.57401264]) 0 False {}]
# [array([10.94635751]) array([6.55448106]) 0 False {}]
# [array([11.01190232]) array([6.5460033]) 0 False {}]
# [array([11.07736235]) array([6.53687941]) 0 False {}]
# [array([11.14273114]) array([6.53022424]) 0 False {}]
# [array([11.20803339]) array([6.5229227]) 0 False {}]
# [array([11.27326261]) array([6.50859555]) 0 False {}]
# [array([11.33834857]) array([6.49363187]) 0 False {}]
# [array([11.40328489]) array([6.48452862]) 0 False {}]
# [array([11.46813017]) array([6.47478602]) 0 False {}]
# [array([11.53287803]) array([6.46274727]) 0 False {}]
# [array([11.59750551]) array([6.4500743]) 0 False {}]
# [array([11.66200625]) array([6.43222156]) 0 False {}]
# [array([11.72632846]) array([6.41374346]) 0 False {}]
# [array([11.7904659]) array([6.39427468]) 0 False {}]
# [array([11.85440865]) array([6.37418595]) 0 False {}]
# [array([11.91815051]) array([6.34226643]) 0 False {}]
# [array([11.98157317]) array([6.3097446]) 0 False {}]
# [array([12.04467062]) array([6.27925253]) 0 False {}]
# [array([12.10746314]) array([6.24816303]) 0 False {}]
# [array([12.16994477]) array([6.21200562]) 0 False {}]
# [array([12.23206483]) array([6.17526316]) 0 False {}]
# [array([12.29381746]) array([6.16362977]) 0 False {}]
# [array([12.35545376]) array([6.15139165]) 0 False {}]
# [array([12.41696767]) array([6.1195529]) 0 False {}]
# [array([12.4781632]) array([6.08713404]) 0 False {}]
# [array([12.53903454]) array([6.04169151]) 0 False {}]
# [array([12.59945146]) array([5.99569026]) 0 False {}]
# [array([12.65940836]) array([5.94448355]) 0 False {}]
# [array([12.7188532]) array([5.89273361]) 0 False {}]
# [array([12.77778053]) array([5.84385143]) 0 False {}]
# [array([12.83621905]) array([5.79443374]) 0 False {}]
# [array([12.89416338]) array([5.76111526]) 0 False {}]
# [array([12.95177454]) array([5.72725399]) 0 False {}]
# [array([13.00904708]) array([5.6915297]) 0 False {}]
# [array([13.06596237]) array([5.65527198]) 0 False {}]
# [array([13.12251509]) array([5.61962665]) 0 False {}]
# [array([13.17871136]) array([5.58345501]) 0 False {}]
# [array([13.23454591]) array([5.56304019]) 0 False {}]
# [array([13.29017631]) array([5.54208948]) 0 False {}]
# [array([13.34559721]) array([5.51806008]) 0 False {}]
# [array([13.40077781]) array([5.4935029]) 0 False {}]
# [array([13.45571284]) array([5.43870305]) 0 False {}]
# [array([13.51009987]) array([5.38341413]) 0 False {}]
# [array([13.56393401]) array([5.3386404]) 0 False {}]
# [array([13.61732041]) array([5.29337757]) 0 False {}]
# [array([13.67025419]) array([5.24944501]) 0 False {}]
# [array([13.72274864]) array([5.20503144]) 0 False {}]
# [array([13.77479895]) array([5.16542089]) 0 False {}]
# [array([13.82645316]) array([5.12533341]) 0 False {}]
# [array([13.8777065]) array([5.07367072]) 0 False {}]
# [array([13.9284432]) array([5.02155233]) 0 False {}]
# [array([13.97865873]) array([4.9765343]) 0 False {}]
# [array([14.02842407]) array([4.93106363]) 0 False {}]
# [array([14.0777347]) array([4.89123021]) 0 False {}]
# [array([14.12664701]) array([4.8509475]) 0 False {}]
# [array([14.17515648]) array([4.80343605]) 0 False {}]
# [array([14.22319084]) array([4.75549177]) 0 False {}]
# [array([14.27074576]) array([4.68816502]) 0 False {}]
# [array([14.31762741]) array([4.62043678]) 0 False {}]
# [array([14.36383178]) array([4.56359078]) 0 False {}]
# [array([14.40946769]) array([4.50634528]) 0 False {}]
# [array([14.45453114]) array([4.45580551]) 0 False {}]
# [array([14.49908919]) array([4.40487069]) 0 False {}]
# [array([14.5431379]) array([4.35745466]) 0 False {}]
# [array([14.58671245]) array([4.3096503]) 0 False {}]
# [array([14.62980895]) array([4.26359788]) 0 False {}]
# [array([14.67244493]) array([4.21716514]) 0 False {}]
# [array([14.71461658]) array([4.15378547]) 0 False {}]
# [array([14.75615444]) array([4.09005381]) 0 False {}]
# [array([14.79705497]) array([4.02706707]) 0 False {}]
# [array([14.83732564]) array([3.96374061]) 0 False {}]
# [array([14.87696305]) array([3.90882666]) 0 False {}]
# [array([14.91605132]) array([3.85357673]) 0 False {}]
# [array([14.95458708]) array([3.78943959]) 0 False {}]
# [array([14.99248148]) array([3.72498765]) 0 False {}]
# [array([15.02973136]) array([3.68327058]) 0 False {}]
# [array([15.06656406]) array([3.64122689]) 0 False {}]
# [array([15.10297633]) array([3.58684829]) 0 False {}]
# [array([15.13884481]) array([3.53216537]) 0 False {}]
# [array([15.17416647]) array([3.47745482]) 0 False {}]
# [array([15.20894102]) array([3.42245124]) 0 False {}]
# [array([15.24316553]) array([3.36696157]) 0 False {}]
# [array([15.27683514]) array([3.31119069]) 0 False {}]
# [array([15.30994705]) array([3.23965929]) 0 False {}]
# [array([15.34234364]) array([3.16787545]) 0 False {}]
# [array([15.3740224]) array([3.11460347]) 0 False {}]
# [array([15.40516843]) array([3.06107331]) 0 False {}]
# ...
# [array([11.27159676]) array([-4.20820328]) 0 True {}]
# [array([11.22951473]) array([-4.2237189]) 0 True {}]
# [array([11.18727754]) array([-4.22435414]) 0 True {}]
# [array([11.145034]) array([-4.22456631]) 0 True {}]
# [array([11.10278834]) array([-4.23435178]) 0 True {}]
# [array([11.06044482]) array([-4.24370403]) 0 True {}]
# [array([11.01800778]) array([-4.26098063]) 0 True {}]
# [array([10.97539797]) array([-4.27781385]) 0 True {}]
# [array([10.93261983]) array([-4.2889104]) 0 True {}]
# [array([10.88973073]) array([-4.29956697]) 0 True {}]
# [array([10.84673506]) array([-4.3196968]) 0 True {}]
# [array([10.80353809]) array([-4.33937453]) 0 True {}]
# [array([10.76014435]) array([-4.36626185]) 0 True {}]
# [array([10.71648173]) array([-4.39268565]) 0 True {}]
# [array([10.67255487]) array([-4.41259066]) 0 True {}]
# [array([10.62842897]) array([-4.4320345]) 0 True {}]
# [array([10.58410862]) array([-4.43241734]) 0 True {}]
# [array([10.53978445]) array([-4.43235656]) 0 True {}]
# [array([10.49546088]) array([-4.44071501]) 0 True {}]
# [array([10.45105373]) array([-4.44862103]) 0 True {}]
# [array([10.40656752]) array([-4.45384868]) 0 True {}]
# [array([10.36202903]) array([-4.45862571]) 0 True {}]
# [array([10.31744278]) array([-4.46587437]) 0 True {}]
# [array([10.27278403]) array([-4.47266918]) 0 True {}]
# [array([10.22805734]) array([-4.48082803]) 0 True {}]
# [array([10.18324906]) array([-4.48853064]) 0 True {}]
# [array([10.13836376]) array([-4.48393787]) 0 True {}]
# [array([10.09352438]) array([-4.4789013]) 0 True {}]
# [array([10.04873536]) array([-4.48610461]) 0 True {}]
# [array([10.00387432]) array([-4.4928521]) 0 True {}]
# [array([9.9589458]) array([-4.49707234]) 0 True {}]
# [array([9.91397507]) array([-4.50083865]) 0 True {}]
# [array([9.86896669]) array([-4.50602085]) 0 True {}]
# [array([9.82390648]) array([-4.51074727]) 0 True {}]
# [array([9.77879901]) array([-4.50593107]) 0 True {}]
# [array([9.73373969]) array([-4.50066909]) 0 True {}]
# [array([9.688733]) array([-4.47929106]) 0 True {}]
# [array([9.64394009]) array([-4.45748647]) 0 True {}]
# [array([9.59936523]) array([-4.44519729]) 0 True {}]
# [array([9.55491326]) array([-4.43247588]) 0 True {}]
# [array([9.5105885]) array([-4.41608555]) 0 True {}]
# [array([9.46642764]) array([-4.39927]) 0 True {}]
# [array([9.42243494]) array([-4.37194665]) 0 True {}]
# [array([9.37871547]) array([-4.34421343]) 0 True {}]
# [array([9.33527334]) array([-4.34739702]) 0 True {}]
# [array([9.29179937]) array([-4.35014268]) 0 True {}]
# [array([9.24829794]) array([-4.34383248]) 0 True {}]
# [array([9.20485962]) array([-4.33709419]) 0 True {}]
# [array([9.16148868]) array([-4.30838187]) 0 True {}]
# [array([9.11840486]) array([-4.27926741]) 0 True {}]
# [array([9.07561218]) array([-4.26095598]) 0 True {}]
# [array([9.03300262]) array([-4.24223676]) 0 True {}]
# [array([8.99058026]) array([-4.21845395]) 0 True {}]
# [array([8.94839572]) array([-4.19427307]) 0 True {}]
# [array([8.90645299]) array([-4.18401006]) 0 True {}]
# [array([8.86461289]) array([-4.1733389]) 0 True {}]
# [array([8.8228795]) array([-4.16461054]) 0 True {}]
# [array([8.78123339]) array([-4.15547444]) 0 True {}]
# [array([8.73967865]) array([-4.14876311]) 0 True {}]
# [array([8.69819102]) array([-4.14164362]) 0 True {}]
# [array([8.65677458]) array([-4.13284891]) 0 True {}]
# [array([8.61544609]) array([-4.12364972]) 0 True {}]
# [array([8.57420959]) array([-4.11724319]) 0 True {}]
# [array([8.53303716]) array([-4.11043134]) 0 True {}]
# [array([8.49193285]) array([-4.08343637]) 0 True {}]
# [array([8.45109848]) array([-4.05606005]) 0 True {}]
# [array([8.41053788]) array([-4.03538025]) 0 True {}]
# [array([8.37018408]) array([-4.01431759]) 0 True {}]
# [array([8.33004091]) array([-3.98824452]) 0 True {}]
# [array([8.29015846]) array([-3.96179869]) 0 True {}]
# [array([8.25054047]) array([-3.93791148]) 0 True {}]
# [array([8.21116136]) array([-3.91365436]) 0 True {}]
# [array([8.17202482]) array([-3.89168784]) 0 True {}]
# [array([8.13310794]) array([-3.86935412]) 0 True {}]
# [array([8.0944144]) array([-3.84705507]) 0 True {}]
# [array([8.05594384]) array([-3.82439362]) 0 True {}]
# [array([8.01769991]) array([-3.79543115]) 0 True {}]
# [array([7.9797456]) array([-3.7661181]) 0 True {}]
# [array([7.94208442]) array([-3.74192157]) 0 True {}]
# [array([7.9046652]) array([-3.71737504]) 0 True {}]
# [array([7.86749145]) array([-3.69487327]) 0 True {}]
# [array([7.83054272]) array([-3.67202451]) 0 True {}]
# [array([7.79382247]) array([-3.64610159]) 0 True {}]
# [array([7.75736146]) array([-3.61983998]) 0 True {}]
# [array([7.72116306]) array([-3.59535534]) 0 True {}]
# [array([7.6852095]) array([-3.57053566]) 0 True {}]
# [array([7.64950415]) array([-3.53947594]) 0 True {}]
# [array([7.61410939]) array([-3.50809333]) 0 True {}]
# [array([7.57902845]) array([-3.4845426]) 0 True {}]
# [array([7.54418303]) array([-3.46066696]) 0 True {}]
# [array([7.50957636]) array([-3.4302809]) 0 True {}]
# [array([7.47527355]) array([-3.39958219]) 0 True {}]
# [array([7.44127773]) array([-3.37459258]) 0 True {}]
# [array([7.4075318]) array([-3.3492905]) 0 True {}]
# [array([7.3740389]) array([-3.33438148]) 0 True {}]
# [array([7.34069508]) array([-3.31915393]) 0 True {}]
# [array([7.30750354]) array([-3.28873042]) 0 True {}]
# [array([7.27461624]) array([-3.25800846]) 0 True {}]
# [array([7.24203615]) array([-3.23599707]) 0 True {}]
# [array([7.20967618]) array([-3.21368409]) 0 True {}]
# [array([7.17753934]) array([-3.17383903]) 0 True {}]
# [array([7.14580095]) array([-3.13371643]) 0 True {}]
# [array([7.11446379]) array([-3.10878736]) 0 True {}]
# [array([7.08337591]) array([-3.08357235]) 0 True {}]
# [array([7.05254019]) array([-3.05935804]) 0 True {}]
# [array([7.02194661]) array([-3.03486202]) 0 True {}]
# [array([6.99159799]) array([-3.01413765]) 0 True {}]
# [array([6.96145661]) array([-2.9931326]) 0 True {}]
# [array([6.93152529]) array([-2.94979825]) 0 True {}]
# [array([6.9020273]) array([-2.90621226]) 0 True {}]
# [array([6.87296518]) array([-2.86904043]) 0 True {}]
# [array([6.84427478]) array([-2.83161887]) 0 True {}]
# [array([6.81595859]) array([-2.79860824]) 0 True {}]
# [array([6.78797251]) array([-2.76535077]) 0 True {}]
# [array([6.760319]) array([-2.72687275]) 0 True {}]
# [array([6.73305027]) array([-2.68816051]) 0 True {}]
# [array([6.70616867]) array([-2.66501694]) 0 True {}]
# [array([6.6795185]) array([-2.64163]) 0 True {}]
# [array([6.6531022]) array([-2.62804512]) 0 True {}]
# [array([6.62682175]) array([-2.61421102]) 0 True {}]
# [array([6.60067964]) array([-2.59558121]) 0 True {}]
# [array([6.57472382]) array([-2.57671048]) 0 True {}]
# [array([6.54895672]) array([-2.54914029]) 0 True {}]
# [array([6.52346532]) array([-2.52134277]) 0 True {}]
# [array([6.49825189]) array([-2.49382886]) 0 True {}]
# [array([6.4733136]) array([-2.46609308]) 0 True {}]
# [array([6.44865267]) array([-2.4354314]) 0 True {}]
# [array([6.42429835]) array([-2.40455685]) 0 True {}]
# [array([6.40025279]) array([-2.36665362]) 0 True {}]
# [array([6.37658625]) array([-2.32855163]) 0 True {}]
# [array([6.35330073]) array([-2.3089888]) 0 True {}]
# [array([6.33021085]) array([-2.28921463]) 0 True {}]
# [array([6.3073187]) array([-2.24379828]) 0 True {}]
# [array([6.28488072]) array([-2.19820296]) 0 True {}]
# [array([6.26289869]) array([-2.15850391]) 0 True {}]
# [array([6.24131365]) array([-2.11862871]) 0 True {}]
# [array([6.22012736]) array([-2.07708351]) 0 True {}]
# [array([6.19935653]) array([-2.03537215]) 0 True {}]
# [array([6.1790028]) array([-2.00278798]) 0 True {}]
# [array([6.15897492]) array([-1.97003611]) 0 True {}]
# [array([6.13927456]) array([-1.94109849]) 0 True {}]
# [array([6.11986358]) array([-1.91199569]) 0 True {}]
# [array([6.10074362]) array([-1.8798812]) 0 True {}]
# [array([6.08194481]) array([-1.84761084]) 0 True {}]
# [array([6.0634687]) array([-1.8111131]) 0 True {}]
# [array([6.04535757]) array([-1.77447074]) 0 True {}]
# [array([6.02761286]) array([-1.74637515]) 0 True {}]
# [array([6.01014911]) array([-1.71813301]) 0 True {}]
# [array([5.99296778]) array([-1.67988121]) 0 True {}]
# [array([5.97616897]) array([-1.64149967]) 0 True {}]
# [array([5.95975397]) array([-1.58977864]) 0 True {}]
# [array([5.94385619]) array([-1.53795035]) 0 True {}]
# [array([5.92847668]) array([-1.50983291]) 0 True {}]
# [array([5.91337835]) array([-1.4815926]) 0 True {}]
# [array([5.89856243]) array([-1.45666105]) 0 True {}]
# [array([5.88399582]) array([-1.43160876]) 0 True {}]
# [array([5.86967973]) array([-1.38775732]) 0 True {}]
# [array([5.85580216]) array([-1.34381096]) 0 True {}]
# [array([5.84236405]) array([-1.29236962]) 0 True {}]
# [array([5.82944035]) array([-1.24085049]) 0 True {}]
# [array([5.81703185]) array([-1.20459728]) 0 True {}]
# [array([5.80498587]) array([-1.16825987]) 0 True {}]
# [array([5.79330327]) array([-1.14244897]) 0 True {}]
# [array([5.78187878]) array([-1.11654964]) 0 True {}]
# [array([5.77071329]) array([-1.07777889]) 0 True {}]
# [array([5.7599355]) array([-1.03893914]) 0 True {}]
# [array([5.74954611]) array([-1.01191957]) 0 True {}]
# [array([5.73942691]) array([-0.98482582]) 0 True {}]
# [array([5.72957865]) array([-0.94577668]) 0 True {}]
# [array([5.72012089]) array([-0.90667201]) 0 True {}]
# [array([5.71105417]) array([-0.85210499]) 0 True {}]
# [array([5.70253312]) array([-0.79750732]) 0 True {}]
# [array([5.69455804]) array([-0.75124962]) 0 True {}]
# [array([5.68704555]) array([-0.70496305]) 0 True {}]
# [array([5.67999592]) array([-0.66893338]) 0 True {}]
# [array([5.67330658]) array([-0.63287286]) 0 True {}]
# [array([5.66697785]) array([-0.57305501]) 0 True {}]
# [array([5.6612473]) array([-0.51323968]) 0 True {}]
# [array([5.65611491]) array([-0.46015236]) 0 True {}]
# [array([5.65151338]) array([-0.40707211]) 0 True {}]
# [array([5.64744266]) array([-0.36549135]) 0 True {}]
# [array([5.64378775]) array([-0.32391562]) 0 True {}]
# [array([5.64054859]) array([-0.27965856]) 0 True {}]
# [array([5.63775201]) array([-0.23541778]) 0 True {}]
# [array([5.63539783]) array([-0.17579435]) 0 True {}]
# [array([5.63363989]) array([-0.11621296]) 0 True {}]
# [array([5.63247776]) array([-0.06962753]) 0 True {}]
# [array([5.63178148]) array([-0.02308173]) 0 True {}]
# [array([5.63155066]) array([0.02436438]) 0 True {}]
# [array([5.63179431]) array([0.07176061]) 0 True {}]
# [array([5.63251191]) array([0.10582558]) 0 True {}]
# [array([5.63357017]) array([0.13984591]) 0 True {}]
# [array([5.63496863]) array([0.19509392]) 0 True {}]
# [array([5.63691957]) array([0.25026718]) 0 True {}]
# [array([5.63942224]) array([0.28718803]) 0 True {}]
# [array([5.64229412]) array([0.32404324]) 0 True {}]
# [array([5.64553455]) array([0.34879877]) 0 True {}]
# [array([5.64902254]) array([0.37349466]) 0 True {}]
# [array([5.65275749]) array([0.43897261]) 0 True {}]
# [array([5.65714721]) array([0.50434119]) 0 True {}]
# [array([5.66219063]) array([0.54494343]) 0 True {}]
# [array([5.66764006]) array([0.58545057]) 0 True {}]
# [array([5.67349457]) array([0.61735518]) 0 True {}]
# [array([5.67966812]) array([0.64916614]) 0 True {}]
# [array([5.68615978]) array([0.67692725]) 0 True {}]
# [array([5.69292905]) array([0.7045929]) 0 True {}]
# [array([5.69997498]) array([0.73583975]) 0 True {}]
# [array([5.70733338]) array([0.76698176]) 0 True {}]
# [array([5.71500319]) array([0.80364727]) 0 True {}]
# [array([5.72303967]) array([0.84019576]) 0 True {}]
# [array([5.73144163]) array([0.89626885]) 0 True {}]
# [array([5.74040431]) array([0.95219624]) 0 True {}]
# [array([5.74992628]) array([1.01644761]) 0 True {}]
# [array([5.76009075]) array([1.08053309]) 0 True {}]
# [array([5.77089608]) array([1.13754026]) 0 True {}]
# [array([5.78227149]) array([1.19437667]) 0 True {}]
# [array([5.79421525]) array([1.24680417]) 0 True {}]
# [array([5.80668329]) array([1.29905457]) 0 True {}]
# [array([5.81967384]) array([1.31286454]) 0 True {}]
# [array([5.83280248]) array([1.32652941]) 0 True {}]
# [array([5.84606778]) array([1.36773976]) 0 True {}]
# [array([5.85974518]) array([1.40877213]) 0 True {}]
# [array([5.8738329]) array([1.45076278]) 0 True {}]
# [array([5.88834053]) array([1.49256635]) 0 True {}]
# [array([5.90326619]) array([1.52185232]) 0 True {}]
# [array([5.91848471]) array([1.55095683]) 0 True {}]
# [array([5.93399428]) array([1.597705]) 0 True {}]
# [array([5.94997133]) array([1.64424666]) 0 True {}]
# [array([5.9664138]) array([1.68623218]) 0 True {}]
# [array([5.98327612]) array([1.72800708]) 0 True {}]
# [array([6.00055619]) array([1.77473174]) 0 True {}]
# [array([6.01830351]) array([1.8212322]) 0 True {}]
# [array([6.03651583]) array([1.85306361]) 0 True {}]
# [array([6.05504647]) array([1.88467788]) 0 True {}]
# [array([6.07389324]) array([1.92609184]) 0 True {}]
# [array([6.09315416]) array([1.96727178]) 0 True {}]
# [array([6.11282688]) array([2.00078923]) 0 True {}]
# [array([6.13283477]) array([2.03407308]) 0 True {}]
# [array([6.1531755]) array([2.06226382]) 0 True {}]
# [array([6.17379814]) array([2.09022014]) 0 True {}]
# [array([6.19470034]) array([2.12597533]) 0 True {}]
# [array([6.2159601]) array([2.16148217]) 0 True {}]
# [array([6.23757492]) array([2.19060881]) 0 True {}]
# [array([6.25948101]) array([2.21948726]) 0 True {}]
# [array([6.28167588]) array([2.25575608]) 0 True {}]
# [array([6.30423344]) array([2.29176306]) 0 True {}]
# [array([6.32715107]) array([2.31761152]) 0 True {}]
# [array([6.35032719]) array([2.34320238]) 0 True {}]
# [array([6.37375921]) array([2.36862844]) 0 True {}]
# [array([6.39744549]) array([2.3937922]) 0 True {}]
# [array([6.42138342]) array([2.43564448]) 0 True {}]
# [array([6.44573986]) array([2.47721134]) 0 True {}]
# [array([6.47051197]) array([2.52569421]) 0 True {}]
# [array([6.49576892]) array([2.57387602]) 0 True {}]
# [array([6.52150768]) array([2.63433381]) 0 True {}]
# [array([6.54785101]) array([2.69446771]) 0 True {}]
# [array([6.57479569]) array([2.71403037]) 0 True {}]
# [array([6.60193599]) array([2.73330206]) 0 True {}]
# [array([6.62926902]) array([2.74652292]) 0 True {}]
# [array([6.65673424]) array([2.75945591]) 0 True {}]
# [array([6.6843288]) array([2.79151288]) 0 True {}]
# [array([6.71224393]) array([2.82325863]) 0 True {}]
# [array([6.74047652]) array([2.85598362]) 0 True {}]
# [array([6.76903636]) array([2.88839029]) 0 True {}]
# [array([6.79792026]) array([2.91031191]) 0 True {}]
# [array([6.82702338]) array([2.93192057]) 0 True {}]
# [array([6.85634258]) array([2.95668457]) 0 True {}]
# [array([6.88590943]) array([2.98112814]) 0 True {}]
# [array([6.91572071]) array([3.00376982]) 0 True {}]
# [array([6.94575841]) array([3.02608848]) 0 True {}]
# [array([6.97601929]) array([3.04863511]) 0 True {}]
# [array([7.00650564]) array([3.07085433]) 0 True {}]
# [array([7.03721419]) array([3.1063515]) 0 True {}]
# [array([7.0682777]) array([3.14150254]) 0 True {}]
# [array([7.09969273]) array([3.15465993]) 0 True {}]
# [array([7.13123933]) array([3.1674887]) 0 True {}]
# [array([7.16291421]) array([3.20027258]) 0 True {}]
# [array([7.19491694]) array([3.23270364]) 0 True {}]
# [array([7.22724398]) array([3.25222968]) 0 True {}]
# [array([7.25976627]) array([3.27141097]) 0 True {}]
# [array([7.29248038]) array([3.30158705]) 0 True {}]
# [array([7.32549625]) array([3.33140279]) 0 True {}]
# [array([7.35881028]) array([3.33901043]) 0 True {}]
# [array([7.39220039]) array([3.34627657]) 0 True {}]
# [array([7.42566315]) array([3.34965014]) 0 True {}]
# [array([7.45915965]) array([3.35268537]) 0 True {}]
# [array([7.49268651]) array([3.37060448]) 0 True {}]
# [array([7.52639255]) array([3.38816862]) 0 True {}]
# [array([7.56027424]) array([3.39520876]) 0 True {}]
# [array([7.59422632]) array([3.40190233]) 0 True {}]
# [array([7.62824535]) array([3.42338976]) 0 True {}]
# [array([7.66247925]) array([3.44451335]) 0 True {}]
# [array([7.69692438]) array([3.44707091]) 0 True {}]
# [array([7.73139509]) array([3.4492812]) 0 True {}]
# [array([7.7658879]) array([3.48373535]) 0 True {}]
# [array([7.80072525]) array([3.51780666]) 0 True {}]
# [array([7.83590332]) array([3.55777482]) 0 True {}]
# [array([7.87148107]) array([3.59734724]) 0 True {}]
# [array([7.90745454]) array([3.59846007]) 0 True {}]
# [array([7.94343914]) array([3.59921193]) 0 True {}]
# [array([7.97943126]) array([3.59933329]) 0 True {}]
# [array([8.01542459]) array([3.5990946]) 0 True {}]
# [array([8.05141554]) array([3.60940777]) 0 True {}]
# [array([8.08750962]) array([3.61934969]) 0 True {}]

# %%
# train withh pytorch #
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import random
from collections import deque
import matplotlib.pyplot as plt
import numpy as np
import gym
import time

# hyperparameters
learning_rate = 0.0005
gamma = 0.98
buffer_limit = 50000
batch_size = 32

# Q-network
class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(2, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 1)
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        q = self.fc3(x)
        return q

    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(-10, 10)
        else:
            return out.item()
        
# replay buffer
class ReplayBuffer():
    def __init__(self):
        self.buffer = deque(maxlen=buffer_limit)
    
    def put(self, data):
        self.buffer.append(data)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])
        
        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
            torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
                torch.tensor(done_mask_lst)

    def size(self):
        return len(self.buffer)
    
# train
def train(q, q_target, memory):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)
        
        q_out = q(s)
        q_a = q_out.gather(1,a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        
        q.optimizer.zero_grad()
        loss.backward()
        q.optimizer.step()

# main
def main():
    env = MassSpringDamperEnv()
    q = Qnet()
    q_target = Qnet()
    q_target.load_state_dict(q.state_dict())
    memory = ReplayBuffer()

    score = 0.0
    print_interval = 20

    for n_epi in range(10000):
        epsilon = max(0.01, 0.08 - 0.01*(n_epi/200)) # linear annealing from 8% to 1%
        s = env.reset()
        done = False

        while not done:
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)
            result = env.step(a)
            s_prime = result[0]
            r = result[1]
            done = result[2]
            info = result[3]
            done_mask = 0.0 if done else 1.0
            memory.put((s,a,r/100.0,s_prime, done_mask))
            s = s_prime

            score += r
            if done:
                break
        
        if memory.size()>2000:
            train(q, q_target, memory)
        
        if n_epi%print_interval==0 and n_epi!=0:
            q_target.load_state_dict(q.state_dict())
            print("# of episode :{}, avg score : {:.1f}, buffer size : {}, epsilon : {:.1f}%".format(
                n_epi, score/print_interval, memory.size(), epsilon*100))
            score = 0.0
    env.close()

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb Cell 5 line 1
#     <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=122'>123</a>     env.close()
#     <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=124'>125</a> if __name__ == '__main__':
# --> <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=125'>126</a>     main()
#
# /Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=97'>98</a> done = False
#     <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=99'>100</a> while not done:
# --> <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=100'>101</a>     a = q.sample_action(torch.from_numpy(s).float(), epsilon)
#     <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=101'>102</a>     result = env.step(a)
#     <a href='vscode-notebook-cell:/Users/Ali/Documents/BAI/Master/master-thesis/Code/Environment/env.ipynb#W2sZmlsZQ%3D%3D?line=102'>103</a>     s_prime = result[0]
#
# TypeError: expected np.ndarray (got float)
