# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, action_dim)

        self.max_action = max_action

    def forward(self, state):
        a = F.tanh(self.l1(state))
        a = F.tanh(self.l2(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-4)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
	eval_env.reset(seed=seed
    )

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
import gym
import numpy as np
import math

# Define the custom Gym environment for the mass-spring-damper system
class MassSpringDamperEnv(gym.Env):
    def __init__(self):
        super(MassSpringDamperEnv, self).__init__()

        # System parameters
        self.m = 1.0  # Mass (kg)
        self.k = 1.0  # Spring constant (N/m)
        self.c = 0.1  # Damping coefficient (N*s/m)

        # Simulation parameters
        self.dt = 0.01  # Time step (s)
        self.max_steps = 1000  # Maximum simulation steps
        self.current_step = 0

        # State and action spaces
        self.action_space = gym.spaces.Box(low=-100.0, high=100.0, shape=(1,))
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(2,))

        # Initial state
        self.state = None

    def reset(self, seed=None, return_info=False, options=None):
        # Reset the environment to an initial state
        self.state = np.random.uniform(low=-10, high=10, size=(2,))
        self.current_step = 0
        return self.state

    def step(self, action):
        # Apply control action and simulate one time step using Euler integration
        force = action[0]
        position, velocity = self.state

        acceleration = (force - self.c * velocity - self.k * position) / self.m
        velocity += acceleration * self.dt
        position += velocity * self.dt

        self.state = np.array([position, velocity])
        self.current_step += 1

        # Calculate the reward (e.g., minimize position error)
        reward = -abs(position)  # Negative position as the reward (minimize position error)

        # Check if the episode is done
        done = self.current_step >= self.max_steps

        return self.state, reward, done, {}

    def render(self, mode='human'):
        pass

    def close(self):
        pass

# Create the custom mass-spring-damper environment
env = MassSpringDamperEnv()

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "MBK"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(25e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(1e5)
DEFAULT_EXPL_NOISE = 0.1
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.2
DEFAULT_NOISE_CLIP = 0.5
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")
    
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ} 
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# ---------------------------------------
# Policy: TD3, Env: MBK, Seed: 0
# ---------------------------------------
# ---------------------------------------
# Evaluation over 10 episodes: -1024.540
# ---------------------------------------

# %%
for t in range(int(DEFAULT_MAX_TIMESTEPS)):
    
    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action) 
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done: 
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1 

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# Total T: 1000 Episode Num: 1 Episode T: 1000 Reward: -8565.925
# Total T: 2000 Episode Num: 2 Episode T: 1000 Reward: -7317.764
# Total T: 3000 Episode Num: 3 Episode T: 1000 Reward: -6233.481
# Total T: 4000 Episode Num: 4 Episode T: 1000 Reward: -9716.445
# Total T: 5000 Episode Num: 5 Episode T: 1000 Reward: -3209.578
# ---------------------------------------
# Evaluation over 10 episodes: -1265.182
# ---------------------------------------
# Total T: 5001 Episode Num: 6 Episode T: 1 Reward: -0.805
# Total T: 6001 Episode Num: 7 Episode T: 1000 Reward: -5887.909
# Total T: 7001 Episode Num: 8 Episode T: 1000 Reward: -5407.450
# Total T: 8001 Episode Num: 9 Episode T: 1000 Reward: -4331.128
# Total T: 9001 Episode Num: 10 Episode T: 1000 Reward: -4722.945
# ---------------------------------------
# Evaluation over 10 episodes: -1017.406
# ---------------------------------------
# Total T: 10001 Episode Num: 11 Episode T: 1000 Reward: -6280.928
# Total T: 11001 Episode Num: 12 Episode T: 1000 Reward: -12228.026
# Total T: 12001 Episode Num: 13 Episode T: 1000 Reward: -4586.472
# Total T: 13001 Episode Num: 14 Episode T: 1000 Reward: -4485.083
# Total T: 14001 Episode Num: 15 Episode T: 1000 Reward: -7986.155
# ---------------------------------------
# Evaluation over 10 episodes: -956.141
# ---------------------------------------
# Total T: 15001 Episode Num: 16 Episode T: 1000 Reward: -13630.454
# Total T: 16001 Episode Num: 17 Episode T: 1000 Reward: -15649.333
# Total T: 17001 Episode Num: 18 Episode T: 1000 Reward: -10532.911
# Total T: 18001 Episode Num: 19 Episode T: 1000 Reward: -9289.350
# Total T: 19001 Episode Num: 20 Episode T: 1000 Reward: -7188.516
# ---------------------------------------
# Evaluation over 10 episodes: -1038.816
# ---------------------------------------
# Total T: 20001 Episode Num: 21 Episode T: 1000 Reward: -10223.957
# Total T: 21001 Episode Num: 22 Episode T: 1000 Reward: -4875.610
# Total T: 22001 Episode Num: 23 Episode T: 1000 Reward: -7604.406
# Total T: 23001 Episode Num: 24 Episode T: 1000 Reward: -10412.034
# Total T: 24001 Episode Num: 25 Episode T: 1000 Reward: -11691.441
# ---------------------------------------
# Evaluation over 10 episodes: -1047.791
# ---------------------------------------
# Total T: 25001 Episode Num: 26 Episode T: 1000 Reward: -6725.829
# Total T: 26001 Episode Num: 27 Episode T: 1000 Reward: -59907.996
# Total T: 27001 Episode Num: 28 Episode T: 1000 Reward: -51820.965
# Total T: 28001 Episode Num: 29 Episode T: 1000 Reward: -211.963
# Total T: 29001 Episode Num: 30 Episode T: 1000 Reward: -182.648
# ---------------------------------------
# Evaluation over 10 episodes: -162.394
# ---------------------------------------
# Total T: 30001 Episode Num: 31 Episode T: 1000 Reward: -122.127
# Total T: 31001 Episode Num: 32 Episode T: 1000 Reward: -147.906
# Total T: 32001 Episode Num: 33 Episode T: 1000 Reward: -185.260
# Total T: 33001 Episode Num: 34 Episode T: 1000 Reward: -240.078
# Total T: 34001 Episode Num: 35 Episode T: 1000 Reward: -413.966
# ---------------------------------------
# Evaluation over 10 episodes: -517.697
# ---------------------------------------
# Total T: 35001 Episode Num: 36 Episode T: 1000 Reward: -533.427
# Total T: 36001 Episode Num: 37 Episode T: 1000 Reward: -644.182
# Total T: 37001 Episode Num: 38 Episode T: 1000 Reward: -615.799
# Total T: 38001 Episode Num: 39 Episode T: 1000 Reward: -625.233
# Total T: 39001 Episode Num: 40 Episode T: 1000 Reward: -556.760
# ---------------------------------------
# Evaluation over 10 episodes: -560.658
# ---------------------------------------
# Total T: 40001 Episode Num: 41 Episode T: 1000 Reward: -682.624
# Total T: 41001 Episode Num: 42 Episode T: 1000 Reward: -685.598
# Total T: 42001 Episode Num: 43 Episode T: 1000 Reward: -517.321
# Total T: 43001 Episode Num: 44 Episode T: 1000 Reward: -247.899
# Total T: 44001 Episode Num: 45 Episode T: 1000 Reward: -351.011
# ---------------------------------------
# Evaluation over 10 episodes: -301.550
# ---------------------------------------
# Total T: 45001 Episode Num: 46 Episode T: 1000 Reward: -168.523
# Total T: 46001 Episode Num: 47 Episode T: 1000 Reward: -169.276
# Total T: 47001 Episode Num: 48 Episode T: 1000 Reward: -349.896
# Total T: 48001 Episode Num: 49 Episode T: 1000 Reward: -265.788
# Total T: 49001 Episode Num: 50 Episode T: 1000 Reward: -242.932
# ---------------------------------------
# Evaluation over 10 episodes: -559.424
# ---------------------------------------
# Total T: 50001 Episode Num: 51 Episode T: 1000 Reward: -290.136
# Total T: 51001 Episode Num: 52 Episode T: 1000 Reward: -741.330
# Total T: 52001 Episode Num: 53 Episode T: 1000 Reward: -780.601
# Total T: 53001 Episode Num: 54 Episode T: 1000 Reward: -572.628
# Total T: 54001 Episode Num: 55 Episode T: 1000 Reward: -392.797
# ---------------------------------------
# Evaluation over 10 episodes: -362.200
# ---------------------------------------
# Total T: 55001 Episode Num: 56 Episode T: 1000 Reward: -231.673
# Total T: 56001 Episode Num: 57 Episode T: 1000 Reward: -169.563
# Total T: 57001 Episode Num: 58 Episode T: 1000 Reward: -282.007
# Total T: 58001 Episode Num: 59 Episode T: 1000 Reward: -300.250
# Total T: 59001 Episode Num: 60 Episode T: 1000 Reward: -464.408
# ---------------------------------------
# Evaluation over 10 episodes: -641.617
# ---------------------------------------
# Total T: 60001 Episode Num: 61 Episode T: 1000 Reward: -406.347
# Total T: 61001 Episode Num: 62 Episode T: 1000 Reward: -437.443
# Total T: 62001 Episode Num: 63 Episode T: 1000 Reward: -688.818
# Total T: 63001 Episode Num: 64 Episode T: 1000 Reward: -678.923
# Total T: 64001 Episode Num: 65 Episode T: 1000 Reward: -645.656
# ---------------------------------------
# Evaluation over 10 episodes: -803.946
# ---------------------------------------
# Total T: 65001 Episode Num: 66 Episode T: 1000 Reward: -760.512
# Total T: 66001 Episode Num: 67 Episode T: 1000 Reward: -815.333
# Total T: 67001 Episode Num: 68 Episode T: 1000 Reward: -662.376
# Total T: 68001 Episode Num: 69 Episode T: 1000 Reward: -1080.408
# Total T: 69001 Episode Num: 70 Episode T: 1000 Reward: -401.872
# ---------------------------------------
# Evaluation over 10 episodes: -451.177
# ---------------------------------------
# Total T: 70001 Episode Num: 71 Episode T: 1000 Reward: -436.281
# Total T: 71001 Episode Num: 72 Episode T: 1000 Reward: -532.442
# Total T: 72001 Episode Num: 73 Episode T: 1000 Reward: -483.070
# Total T: 73001 Episode Num: 74 Episode T: 1000 Reward: -372.696
# Total T: 74001 Episode Num: 75 Episode T: 1000 Reward: -494.771
# ---------------------------------------
# Evaluation over 10 episodes: -360.648
# ---------------------------------------
# Total T: 75001 Episode Num: 76 Episode T: 1000 Reward: -342.463
# Total T: 76001 Episode Num: 77 Episode T: 1000 Reward: -400.453
# Total T: 77001 Episode Num: 78 Episode T: 1000 Reward: -141.547
# Total T: 78001 Episode Num: 79 Episode T: 1000 Reward: -156.283
# Total T: 79001 Episode Num: 80 Episode T: 1000 Reward: -51.345
# ---------------------------------------
# Evaluation over 10 episodes: -249.311
# ---------------------------------------
# Total T: 80001 Episode Num: 81 Episode T: 1000 Reward: -358.767
# Total T: 81001 Episode Num: 82 Episode T: 1000 Reward: -248.550
# Total T: 82001 Episode Num: 83 Episode T: 1000 Reward: -161.995
# Total T: 83001 Episode Num: 84 Episode T: 1000 Reward: -176.639
# Total T: 84001 Episode Num: 85 Episode T: 1000 Reward: -424.911
# ---------------------------------------
# Evaluation over 10 episodes: -313.705
# ---------------------------------------
# Total T: 85001 Episode Num: 86 Episode T: 1000 Reward: -251.470
# Total T: 86001 Episode Num: 87 Episode T: 1000 Reward: -381.710
# Total T: 87001 Episode Num: 88 Episode T: 1000 Reward: -387.357
# Total T: 88001 Episode Num: 89 Episode T: 1000 Reward: -502.702
# Total T: 89001 Episode Num: 90 Episode T: 1000 Reward: -283.305
# ---------------------------------------
# Evaluation over 10 episodes: -345.234
# ---------------------------------------
# Total T: 90001 Episode Num: 91 Episode T: 1000 Reward: -249.436
# Total T: 91001 Episode Num: 92 Episode T: 1000 Reward: -216.884
# Total T: 92001 Episode Num: 93 Episode T: 1000 Reward: -207.737
# Total T: 93001 Episode Num: 94 Episode T: 1000 Reward: -234.827
# Total T: 94001 Episode Num: 95 Episode T: 1000 Reward: -206.158
# ---------------------------------------
# Evaluation over 10 episodes: -304.183
# ---------------------------------------
# Total T: 95001 Episode Num: 96 Episode T: 1000 Reward: -369.615
# Total T: 96001 Episode Num: 97 Episode T: 1000 Reward: -434.586
# Total T: 97001 Episode Num: 98 Episode T: 1000 Reward: -348.713
# Total T: 98001 Episode Num: 99 Episode T: 1000 Reward: -51.221
# Total T: 99001 Episode Num: 100 Episode T: 1000 Reward: -83.502
# ---------------------------------------
# Evaluation over 10 episodes: -163.748
# ---------------------------------------

# %%
import matplotlib.pyplot as plt

evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
# show results for one episode with policy
state, done = env.reset(), False
episode_reward = 0
state_array = []
action_array = []
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    state_array.append(state)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
# Out:
# Episode Reward: -70.663

# %%
# show results for one episode with policy
state, done = env.reset(), False
episode_reward = 0
state_array = []
action_array = []
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    state_array.append(state)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
