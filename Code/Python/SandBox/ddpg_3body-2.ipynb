# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
import gym
from gym import spaces
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(trajectory[:,0], trajectory[:,1])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# three body problem env
import gym
from gym import spaces
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-150, high=0, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        force = action[0] * env.state[2:] + action[1] * env.state[:2]
        a_x = force[0]
        a_y = force[1]

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y

        x = x + xdot*self.dt
        y = y + ydot*self.dt

        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        # reward = 1 - np.linalg.norm(self.position - self.trajectory[self.steps], axis=0)**2 + self.steps/100
        reward = self.steps/1000
        done = self.steps >= self.max_steps
        if np.linalg.norm(self.position[0:2] - self.trajectory[-1, 0:2]) < 0.01:
            done = True
            print('Done!')
            reward = 1000000
        if self.steps > 1000:
            done = True
            print('Done Time!')
            reward = -100000
        if np.linalg.norm(self.state) > 0.5:
            done = True
            print('Too much error!')
            reward = -100000

        # print(self.state, reward, done, self.position)
        return 10000*self.state, reward, done, self.position

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]

    def reset(self):
        self.position = self.trajectory[0]
        self.steps = 0
        self.position2state()
        return 10000*self.state

    def render(self):
        pass

    def close(self):
        pass

# %%
# problem = "Pendulum-v1"
# env = gym.make(problem)
env = three_body_env(trajectory)
num_states = env.observation_space.shape[0]
print("Size of State Space ->  {}".format(num_states))
num_actions = env.action_space.shape[0]
print("Size of Action Space ->  {}".format(num_actions))

upper_bound = env.action_space.high[0]
lower_bound = env.action_space.low[0]

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  4
# Size of Action Space ->  2
# Max Value of Action ->  0.0
# Min Value of Action ->  -150.0

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        # Formula taken from https://www.wikipedia.org/wiki/Ornstein-Uhlenbeck_process.
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity=1000, batch_size=64):
        # Number of "experiences" to store at max
        self.buffer_capacity = buffer_capacity
        # Num of tuples to train on.
        self.batch_size = batch_size

        # Its tells us num of times record() was called.
        self.buffer_counter = 0

        # Instead of list of tuples as the exp.replay concept go
        # We use different np.arrays for each tuple element
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))

    # Takes (s,a,r,s') observation tuple as input
    def record(self, obs_tuple):
        # Set index to zero if buffer_capacity is exceeded,
        # replacing old records
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1][0]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    # Eager execution is turned on by default in TensorFlow 2. Decorating with tf.function allows
    # TensorFlow to build a static graph out of the logic and computations in our function.
    # This provides a large speed up for blocks of code that contain many small TensorFlow operations such as this one.
    @tf.function
    def update(
        self, state_batch, action_batch, reward_batch, next_state_batch,
    ):
        # Training and updating Actor & Critic networks.
        # See Pseudo Code.
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            y = reward_batch + gamma * target_critic(
                [next_state_batch, target_actions], training=True
            )
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = tf.math.reduce_mean(tf.math.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            # Used `-value` as we want to maximize the value given
            # by the critic for our actions
            actor_loss = -tf.math.reduce_mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    # We compute the loss and update parameters
    def learn(self):
        # Get sampling range
        record_range = min(self.buffer_counter, self.buffer_capacity)
        # Randomly sample indices
        batch_indices = np.random.choice(record_range, self.batch_size)

        # Convert to tensors
        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])

        self.update(state_batch, action_batch, reward_batch, next_state_batch)


# This update target parameters slowly
# Based on rate `tau`, which is much less than one.
@tf.function
def update_target(target_weights, weights, tau):
    for (a, b) in zip(target_weights, weights):
        a.assign(b * tau + a * (1 - tau))

# %%
def get_actor():
    # Initialize weights between -3e-3 and 3-e3
    last_init = tf.random_uniform_initializer(minval=-0.003, maxval=0.003)

    inputs = layers.Input(shape=(num_states,))
    out = layers.Dense(8, activation="relu")(inputs)
    out = layers.Dense(8, activation="relu")(out)
    outputs = layers.Dense(2, activation="tanh", kernel_initializer=last_init)(out)

    # Our upper bound is 2.0 for Pendulum.
    outputs = outputs * upper_bound
    model = tf.keras.Model(inputs, outputs)
    # model = tf.keras.models.load_model('model.h5')
    return model


def get_critic():
    # State as input
    state_input = layers.Input(shape=(num_states))
    state_out = layers.Dense(16, activation="relu")(state_input)
    state_out = layers.Dense(32, activation="relu")(state_out)

    # Action as input
    action_input = layers.Input(shape=(num_actions))
    action_out = layers.Dense(32, activation="relu")(action_input)

    # Both are passed through seperate layer before concatenating
    concat = layers.Concatenate()([state_out, action_out])

    out = layers.Dense(64, activation="relu")(concat)
    out = layers.Dense(64, activation="relu")(out)
    outputs = layers.Dense(1)(out)

    # Outputs single value for give state-action
    model = tf.keras.Model([state_input, action_input], outputs)

    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    # Adding noise to action
    sampled_actions = sampled_actions.numpy() + noise

    # We make sure action is within bounds
    legal_action = np.clip(sampled_actions, lower_bound, upper_bound)

    return [np.squeeze(legal_action)]

# %%
std_dev = 10
ou_noise = OUActionNoise(mean=np.zeros(1), std_deviation=float(std_dev) * np.ones(1))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_lr = 0.2
actor_lr = 0.1

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

total_episodes = 1000
# Discount factor for future rewards
gamma = 0.99
# Used to update target networks
tau = 0.0005

buffer = Buffer(50000, 64)

# %%
# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []

# Takes about 4 min to train
for ep in range(total_episodes):

    prev_state= env.reset()
    episodic_reward = 0

    while True:
        # Uncomment this to see the Actor in action
        # But not in a python notebook.
        # env.render()

        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        action = policy(tf_prev_state, ou_noise)
        # Recieve state and reward from environment.
        state, reward, done, info = env.step(action[0])

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        # End this episode when `done` is True
        if done:
            break

        prev_state = state

    ep_reward_list.append(episodic_reward)

    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-40:])
    print("Episode * {} * Avg Reward is ==> {}".format(ep, avg_reward))
    avg_reward_list.append(avg_reward)

# Plotting graph
# Episodes versus Avg. Rewards
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
# Out:
# Done!
# Episode * 0 * Avg Reward is ==> 1000140.715
# Too much error!
# Episode * 1 * Avg Reward is ==> 450139.39499999996
# Too much error!
# Episode * 2 * Avg Reward is ==> 266766.3636666666
# Too much error!
# Episode * 3 * Avg Reward is ==> 175092.11724999998
# Too much error!
# Episode * 4 * Avg Reward is ==> 120086.90699999998
# Too much error!
# Episode * 5 * Avg Reward is ==> 83409.55433333332
# Done!
# Episode * 6 * Avg Reward is ==> 214371.83657142855
# Done!
# Episode * 7 * Avg Reward is ==> 312594.16025
# Too much error!
# Episode * 8 * Avg Reward is ==> 266755.348
# Too much error!
# Episode * 9 * Avg Reward is ==> 230081.8433
# Done!
# Episode * 10 * Avg Reward is ==> 300088.93890909094
# Too much error!
# Episode * 11 * Avg Reward is ==> 266754.00658333336
# Too much error!
# Episode * 12 * Avg Reward is ==> 238543.72153846157
# Too much error!
# Episode * 13 * Avg Reward is ==> 214363.50614285716
# Too much error!
# Episode * 14 * Avg Reward is ==> 193407.29246666667
# Done!
# Episode * 15 * Avg Reward is ==> 243828.1978125
# Too much error!
# Episode * 16 * Avg Reward is ==> 223604.26388235294
# Too much error!
# Episode * 17 * Avg Reward is ==> 205627.37705555555
# Too much error!
# Episode * 18 * Avg Reward is ==> 189542.79410526316
# Too much error!
# Episode * 19 * Avg Reward is ==> 175066.66945
# Too much error!
# Episode * 20 * Avg Reward is ==> 161969.22333333333
# Too much error!
# Episode * 21 * Avg Reward is ==> 150062.5005
# Too much error!
# Episode * 22 * Avg Reward is ==> 139192.36808695653
# Too much error!
# Episode * 23 * Avg Reward is ==> 129231.19654166668
# Done!
# Episode * 24 * Avg Reward is ==> 164067.64112
# Done!
# Episode * 25 * Avg Reward is ==> 196224.2774230769
# Too much error!
# Episode * 26 * Avg Reward is ==> 185264.2024444444
# Too much error!
# Episode * 27 * Avg Reward is ==> 175076.92024999997
# Too much error!
# Episode * 28 * Avg Reward is ==> 165592.22320689654
# Too much error!
# Episode * 29 * Avg Reward is ==> 156739.82579999996
# Too much error!
# Episode * 30 * Avg Reward is ==> 148458.6944193548
# Done!
# Episode * 31 * Avg Reward is ==> 175073.7575625
# Done!
# Episode * 32 * Avg Reward is ==> 200075.8511212121
# Done!
# Episode * 33 * Avg Reward is ==> 223607.4401470588
# Too much error!
# Episode * 34 * Avg Reward is ==> 214364.22271428572
# Too much error!
# Episode * 35 * Avg Reward is ==> 205632.4471111111
# Too much error!
# Episode * 36 * Avg Reward is ==> 197372.65937837836
# Too much error!
# Episode * 37 * Avg Reward is ==> 189548.5177631579
# Too much error!
# Episode * 38 * Avg Reward is ==> 182128.08205128205
# Done!
# Episode * 39 * Avg Reward is ==> 202578.42445
# Done!
# Episode * 40 * Avg Reward is ==> 202578.53135
# Done!
# Episode * 41 * Avg Reward is ==> 230078.62392500002
# Too much error!
# Episode * 42 * Avg Reward is ==> 230079.87889999998
# Too much error!
# Episode * 43 * Avg Reward is ==> 230078.74670000002
# Too much error!
# Episode * 44 * Avg Reward is ==> 230077.602575
# Too much error!
# Episode * 45 * Avg Reward is ==> 230077.540325
# Too much error!
# Episode * 46 * Avg Reward is ==> 202574.40959999998
# Too much error!
# Episode * 47 * Avg Reward is ==> 175071.1717
# Done!
# Episode * 48 * Avg Reward is ==> 202573.58159999998
# Too much error!
# Episode * 49 * Avg Reward is ==> 202573.62795000002
# Too much error!
# Episode * 50 * Avg Reward is ==> 175070.13809999995
# Too much error!
# Episode * 51 * Avg Reward is ==> 175070.091725
# Too much error!
# Episode * 52 * Avg Reward is ==> 175070.14865
# Too much error!
# Episode * 53 * Avg Reward is ==> 175070.13852500002
# Too much error!
# Episode * 54 * Avg Reward is ==> 175070.138525
# Too much error!
# Episode * 55 * Avg Reward is ==> 147567.1016
# Too much error!
# Episode * 56 * Avg Reward is ==> 147567.0761
# Too much error!
# Episode * 57 * Avg Reward is ==> 147567.0761
# Too much error!
# Episode * 58 * Avg Reward is ==> 147567.0761
# Too much error!
# Episode * 59 * Avg Reward is ==> 147567.0761
# Too much error!
# Episode * 60 * Avg Reward is ==> 147567.0761
# Too much error!
# Episode * 61 * Avg Reward is ==> 147567.05060000002
# Too much error!
# Episode * 62 * Avg Reward is ==> 147566.32175
# Too much error!
# Episode * 63 * Avg Reward is ==> 147563.78525000002
# Too much error!
# Episode * 64 * Avg Reward is ==> 120060.7605
# Too much error!
# Episode * 65 * Avg Reward is ==> 92557.7889
# Too much error!
# Episode * 66 * Avg Reward is ==> 92550.74010000001
# Too much error!
# Episode * 67 * Avg Reward is ==> 92550.8239
# Too much error!
# Episode * 68 * Avg Reward is ==> 92550.813775
# Too much error!
# Episode * 69 * Avg Reward is ==> 92550.813775
# Too much error!
# Episode * 70 * Avg Reward is ==> 92550.786275
# Too much error!
# Episode * 71 * Avg Reward is ==> 65047.780975
# Too much error!
# Episode * 72 * Avg Reward is ==> 37545.414975
# Too much error!
# Episode * 73 * Avg Reward is ==> 10042.175550000009
# Too much error!
# Episode * 74 * Avg Reward is ==> 10040.312325
# Too much error!
# Episode * 75 * Avg Reward is ==> 10041.064875000011
# Too much error!
# Episode * 76 * Avg Reward is ==> 10041.064875
# Done!
# Episode * 77 * Avg Reward is ==> 37543.26742500001
# Too much error!
# Episode * 78 * Avg Reward is ==> 37540.92005
# Too much error!
# Episode * 79 * Avg Reward is ==> 10037.888175000015
# Too much error!
# Episode * 80 * Avg Reward is ==> -17464.72485
# Done!
# Episode * 81 * Avg Reward is ==> -17464.590474999997
# Too much error!
# Episode * 82 * Avg Reward is ==> -17465.835325
# Too much error!
# Episode * 83 * Avg Reward is ==> -17464.521674999996
# Too much error!
# Episode * 84 * Avg Reward is ==> -17464.521674999996
# Too much error!
# Episode * 85 * Avg Reward is ==> -17464.521674999996
# Too much error!
# Episode * 86 * Avg Reward is ==> -17464.521675
# Too much error!
# Episode * 87 * Avg Reward is ==> -17464.53185
# Too much error!
# Episode * 88 * Avg Reward is ==> -44967.449725
# Too much error!
# Episode * 89 * Avg Reward is ==> -44966.32457499999
# Too much error!
# Episode * 90 * Avg Reward is ==> -44966.2887
# Too much error!
# Episode * 91 * Avg Reward is ==> -44966.343525
# Too much error!
# Episode * 92 * Avg Reward is ==> -44965.82385
# Too much error!
# Episode * 93 * Avg Reward is ==> -44965.82384999999
# Too much error!
# Episode * 94 * Avg Reward is ==> -44965.723625
# Too much error!
# Episode * 95 * Avg Reward is ==> -44965.60114999999
# Too much error!
# Episode * 96 * Avg Reward is ==> -44965.60114999999
# Too much error!
# Episode * 97 * Avg Reward is ==> -44965.580799999996
# Too much error!
# Episode * 98 * Avg Reward is ==> -44965.580799999996
# Too much error!
# Episode * 99 * Avg Reward is ==> -44965.580799999996
# Too much error!
# Episode * 100 * Avg Reward is ==> -44965.544924999995
# Too much error!
# Episode * 101 * Avg Reward is ==> -44965.544924999995
# Too much error!
# Episode * 102 * Avg Reward is ==> -44965.544924999995
# Too much error!
# Episode * 103 * Avg Reward is ==> -44965.607175
# Too much error!
# Episode * 104 * Avg Reward is ==> -44965.632675
# Too much error!
# Episode * 105 * Avg Reward is ==> -44965.658175000004
# Too much error!
# Episode * 106 * Avg Reward is ==> -44964.449825
# Too much error!
# Episode * 107 * Avg Reward is ==> -44964.071625
# Done!
# Episode * 108 * Avg Reward is ==> -17461.061275000004
# Too much error!
# Episode * 109 * Avg Reward is ==> -17460.402175000003
# Too much error!
# Episode * 110 * Avg Reward is ==> -17460.485975000007
# Too much error!
# Episode * 111 * Avg Reward is ==> -17460.491025000003
# Too much error!
# Episode * 112 * Avg Reward is ==> -17461.188625000003
# Too much error!
# Episode * 113 * Avg Reward is ==> -17461.188625000003
# Too much error!
# Episode * 114 * Avg Reward is ==> -17461.188625000003
# Too much error!
# Episode * 115 * Avg Reward is ==> -17461.941175000004
# Too much error!
# Episode * 116 * Avg Reward is ==> -17461.941175000004
# Too much error!
# Episode * 117 * Avg Reward is ==> -44965.008025
# Done!
# Episode * 118 * Avg Reward is ==> -17462.877650000002
# Too much error!
# Episode * 119 * Avg Reward is ==> -17458.05195
# Too much error!
# Episode * 120 * Avg Reward is ==> -17458.556175
# Too much error!
# Episode * 121 * Avg Reward is ==> -44960.664124999996
# Too much error!
# Episode * 122 * Avg Reward is ==> -44960.67425
# Too much error!
# Episode * 123 * Avg Reward is ==> -44962.077574999996
# Too much error!
# Episode * 124 * Avg Reward is ==> -44962.077575
# Too much error!
# Episode * 125 * Avg Reward is ==> -44962.0469
# Too much error!
# Episode * 126 * Avg Reward is ==> -44962.0469
# Too much error!
# Episode * 127 * Avg Reward is ==> -44962.051949999994
# Too much error!
# Episode * 128 * Avg Reward is ==> -44962.157699999996
# Done!
# Episode * 129 * Avg Reward is ==> -17460.238825
# Too much error!
# Episode * 130 * Avg Reward is ==> -17459.4902
# Too much error!
# Episode * 131 * Avg Reward is ==> -17459.597149999998
# Too much error!
# Episode * 132 * Avg Reward is ==> -17460.163624999997
# Too much error!
# Episode * 133 * Avg Reward is ==> -17460.163624999994
# Done!
# Episode * 134 * Avg Reward is ==> 10044.665375000006
# Done!
# Episode * 135 * Avg Reward is ==> 37547.673624999996
# Too much error!
# Episode * 136 * Avg Reward is ==> 37548.772625
# Too much error!
# Episode * 137 * Avg Reward is ==> 37548.8039
# Too much error!
# Episode * 138 * Avg Reward is ==> 37549.6289
# Too much error!
# Episode * 139 * Avg Reward is ==> 37549.628899999996
# Too much error!
# Episode * 140 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 141 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 142 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 143 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 144 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 145 * Avg Reward is ==> 37549.593024999995
# Too much error!
# Episode * 146 * Avg Reward is ==> 37549.193400000004
# Too much error!
# Episode * 147 * Avg Reward is ==> 37549.698775
# Done!
# Episode * 148 * Avg Reward is ==> 37549.752025
# Done!
# Episode * 149 * Avg Reward is ==> 65052.196725
# Too much error!
# Episode * 150 * Avg Reward is ==> 65052.810450000004
# Too much error!
# Episode * 151 * Avg Reward is ==> 65052.89425000001
# Too much error!
# Episode * 152 * Avg Reward is ==> 65052.89425
# Too much error!
# Episode * 153 * Avg Reward is ==> 65052.90947500001
# Too much error!
# Episode * 154 * Avg Reward is ==> 65056.02672499999
# Too much error!
# Episode * 155 * Avg Reward is ==> 65056.73990000001
# Too much error!
# Episode * 156 * Avg Reward is ==> 65056.7654
# Too much error!
# Episode * 157 * Avg Reward is ==> 65059.621250000004
# Too much error!
# Episode * 158 * Avg Reward is ==> 37556.557649999995
# Too much error!
# Episode * 159 * Avg Reward is ==> 37551.726899999994
# Too much error!
# Episode * 160 * Avg Reward is ==> 37551.74724999999
# Too much error!
# Episode * 161 * Avg Reward is ==> 37550.68389999999
# Too much error!
# Episode * 162 * Avg Reward is ==> 37550.71977499999
# Done!
# Episode * 163 * Avg Reward is ==> 65053.831974999994
# Done!
# Episode * 164 * Avg Reward is ==> 92556.90894999998
# Done!
# Episode * 165 * Avg Reward is ==> 120059.88862499999
# Done!
# Episode * 166 * Avg Reward is ==> 147562.92554999999
# Done!
# Episode * 167 * Avg Reward is ==> 175065.962475
# Done!
# Episode * 168 * Avg Reward is ==> 202571.9981
# Done!
# Episode * 169 * Avg Reward is ==> 202572.024975
# Too much error!
# Episode * 170 * Avg Reward is ==> 202572.59057499998
# Too much error!
# Episode * 171 * Avg Reward is ==> 202571.61940000003
# Too much error!
# Episode * 172 * Avg Reward is ==> 202571.609275
# Too much error!
# Episode * 173 * Avg Reward is ==> 202571.609275
# Too much error!
# Episode * 174 * Avg Reward is ==> 175067.27885
# Done!
# Episode * 175 * Avg Reward is ==> 175067.18505000003
# Done!
# Episode * 176 * Avg Reward is ==> 202569.122975
# Done!
# Episode * 177 * Avg Reward is ==> 230072.094975
# Too much error!
# Episode * 178 * Avg Reward is ==> 230072.9622
# Too much error!
# Episode * 179 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 180 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 181 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 182 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 183 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 184 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 185 * Avg Reward is ==> 230073.698925
# Too much error!
# Episode * 186 * Avg Reward is ==> 230072.95780000003
# Too much error!
# Episode * 187 * Avg Reward is ==> 230071.995475
# Too much error!
# Episode * 188 * Avg Reward is ==> 202568.96775
# Too much error!
# Episode * 189 * Avg Reward is ==> 175065.96417500003
# Too much error!
# Episode * 190 * Avg Reward is ==> 175065.35045
# Too much error!
# Episode * 191 * Avg Reward is ==> 175065.26665
# Too much error!
# Episode * 192 * Avg Reward is ==> 175065.26665
# Too much error!
# Episode * 193 * Avg Reward is ==> 175065.25142500002
# Too much error!
# Episode * 194 * Avg Reward is ==> 175062.13417499998
# Too much error!
# Episode * 195 * Avg Reward is ==> 175061.421
# Too much error!
# Episode * 196 * Avg Reward is ==> 175061.3955
# Too much error!
# Episode * 197 * Avg Reward is ==> 175058.529525
# Too much error!
# Episode * 198 * Avg Reward is ==> 175058.529525
# Too much error!
# Episode * 199 * Avg Reward is ==> 175058.529525
# Too much error!
# Episode * 200 * Avg Reward is ==> 175058.509175
# Too much error!
# Episode * 201 * Avg Reward is ==> 175058.509175
# Too much error!
# Episode * 202 * Avg Reward is ==> 175058.4733
# Too much error!
# Episode * 203 * Avg Reward is ==> 147555.35605
# Too much error!
# Episode * 204 * Avg Reward is ==> 120052.27907500001
# Too much error!
# Episode * 205 * Avg Reward is ==> 92549.268725
# Too much error!
# Episode * 206 * Avg Reward is ==> 65046.23180000002
# Too much error!
# Episode * 207 * Avg Reward is ==> 37543.194875
# Too much error!
# Episode * 208 * Avg Reward is ==> 10037.159249999997
# Too much error!
# Episode * 209 * Avg Reward is ==> -17465.958000000006
# Too much error!
# Episode * 210 * Avg Reward is ==> -17467.292875000006
# Done!
# Episode * 211 * Avg Reward is ==> 10036.041699999992
# Too much error!
# Episode * 212 * Avg Reward is ==> 10036.603624999992
# Too much error!
# Episode * 213 * Avg Reward is ==> 10042.549124999994
# Too much error!
# Episode * 214 * Avg Reward is ==> 10041.950324999994
# Too much error!
# Episode * 215 * Avg Reward is ==> -17461.066250000003
# Done!
# Episode * 216 * Avg Reward is ==> -17461.012800000004
# Done!
# Episode * 217 * Avg Reward is ==> -17460.986175000002
# Done!
# Episode * 218 * Avg Reward is ==> 10040.8256
# Done!
# Episode * 219 * Avg Reward is ==> 37543.12580000001
# Done!
# Episode * 220 * Avg Reward is ==> 65047.15585
# Done!
# Episode * 221 * Avg Reward is ==> 92550.30007499999
# Done!
# Episode * 222 * Avg Reward is ==> 120053.350325
# Done!
# Episode * 223 * Avg Reward is ==> 147556.37395
# Done!
# Episode * 224 * Avg Reward is ==> 175059.410875
# Too much error!
# Episode * 225 * Avg Reward is ==> 175060.59155
# Too much error!
# Episode * 226 * Avg Reward is ==> 175060.52395
# Too much error!
# Episode * 227 * Avg Reward is ==> 175060.52395
# Too much error!
# Episode * 228 * Avg Reward is ==> 175060.52395
# Done!
# Episode * 229 * Avg Reward is ==> 202563.55445
# Too much error!
# Episode * 230 * Avg Reward is ==> 202563.60607500002
# Too much error!
# Episode * 231 * Avg Reward is ==> 202563.60607500002
# Too much error!
# Episode * 232 * Avg Reward is ==> 202563.631575
# Done!
# Episode * 233 * Avg Reward is ==> 230067.05104999998
# Done!
# Episode * 234 * Avg Reward is ==> 257570.08797500003
# Too much error!
# Episode * 235 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 236 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 237 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 238 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 239 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 240 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 241 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 242 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 243 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 244 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 245 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 246 * Avg Reward is ==> 257571.6971
# Too much error!
# Episode * 247 * Avg Reward is ==> 257572.850325
# Too much error!
# Episode * 248 * Avg Reward is ==> 257572.89667499997
# Too much error!
# Episode * 249 * Avg Reward is ==> 257573.60204999996
# Too much error!
# Episode * 250 * Avg Reward is ==> 257573.58682500003
# Too much error!
# Episode * 251 * Avg Reward is ==> 230070.19532499998
# Too much error!
# Episode * 252 * Avg Reward is ==> 230069.6334
# Too much error!
# Episode * 253 * Avg Reward is ==> 230063.75549999997
# Too much error!
# Episode * 254 * Avg Reward is ==> 230065.293225
# Too much error!
# Episode * 255 * Avg Reward is ==> 230065.85685
# Too much error!
# Episode * 256 * Avg Reward is ==> 202562.766475
# Too much error!
# Episode * 257 * Avg Reward is ==> 175059.716225
# Too much error!
# Episode * 258 * Avg Reward is ==> 147556.22235
# Done!
# Episode * 259 * Avg Reward is ==> 147562.3469
# Too much error!
# Episode * 260 * Avg Reward is ==> 120058.89345
# Too much error!
# Episode * 261 * Avg Reward is ==> 92555.74922499999
# Too much error!
# Episode * 262 * Avg Reward is ==> 65052.69897499999
# Too much error!
# Episode * 263 * Avg Reward is ==> 37549.67535
# Too much error!
# Episode * 264 * Avg Reward is ==> 10047.267174999995
# Too much error!
# Episode * 265 * Avg Reward is ==> 10046.086499999994
# Too much error!
# Episode * 266 * Avg Reward is ==> 10046.086499999996
# Too much error!
# Episode * 267 * Avg Reward is ==> 10046.081449999998
# Too much error!
# Episode * 268 * Avg Reward is ==> 10046.045575
# Too much error!
# Episode * 269 * Avg Reward is ==> -17457.085150000003
# Too much error!
# Episode * 270 * Avg Reward is ==> -17457.136775
# Too much error!
# Episode * 271 * Avg Reward is ==> -17457.136775
# Too much error!
# Episode * 272 * Avg Reward is ==> -17457.162275
# Done!
# Episode * 273 * Avg Reward is ==> -17457.51815
# Done!
# Episode * 274 * Avg Reward is ==> -17457.531450000002
# Too much error!
# Episode * 275 * Avg Reward is ==> -17456.103649999994
# Too much error!
# Episode * 276 * Avg Reward is ==> -17456.103649999997
# Too much error!
# Episode * 277 * Avg Reward is ==> -17456.103649999997
# Done!
# Episode * 278 * Avg Reward is ==> 10047.86635
# Done!
# Episode * 279 * Avg Reward is ==> 37550.95672500001
# Done!
# Episode * 280 * Avg Reward is ==> 65054.03370000001
# Too much error!
# Episode * 281 * Avg Reward is ==> 65054.88330000001
# Too much error!
# Episode * 282 * Avg Reward is ==> 65054.88330000001
# Too much error!
# Episode * 283 * Avg Reward is ==> 65054.88330000001
# Too much error!
# Episode * 284 * Avg Reward is ==> 65054.88330000001
# Too much error!
# Episode * 285 * Avg Reward is ==> 65054.88330000001
# Too much error!
# Episode * 286 * Avg Reward is ==> 65054.893425
# Too much error!
# Episode * 287 * Avg Reward is ==> 65053.7402
# Too much error!
# Episode * 288 * Avg Reward is ==> 65053.709075
# Too much error!
# Episode * 289 * Avg Reward is ==> 65053.0037
# Too much error!
# Episode * 290 * Avg Reward is ==> 65053.0037
# Too much error!
# Episode * 291 * Avg Reward is ==> 65053.0037
# Too much error!
# Episode * 292 * Avg Reward is ==> 65053.8287
# Done!
# Episode * 293 * Avg Reward is ==> 92556.81135
# Done!
# Episode * 294 * Avg Reward is ==> 120058.323875
# Too much error!
# Episode * 295 * Avg Reward is ==> 120066.126025
# Done!
# Episode * 296 * Avg Reward is ==> 147569.36544999998
# Done!
# Episode * 297 * Avg Reward is ==> 175072.64605
# Done!
# Episode * 298 * Avg Reward is ==> 202575.8208
# Done!
# Episode * 299 * Avg Reward is ==> 202569.68295
# Too much error!
# Episode * 300 * Avg Reward is ==> 202569.697725
# Too much error!
# Episode * 301 * Avg Reward is ==> 202569.71295000002
# Done!
# Episode * 302 * Avg Reward is ==> 230072.789925
# Done!
# Episode * 303 * Avg Reward is ==> 257575.82685
# Done!
# Episode * 304 * Avg Reward is ==> 285078.31535
# Too much error!
# Episode * 305 * Avg Reward is ==> 285079.51445
# Too much error!
# Episode * 306 * Avg Reward is ==> 285079.51950000005
# Done!
# Episode * 307 * Avg Reward is ==> 312582.63674999995
# Done!
# Episode * 308 * Avg Reward is ==> 340085.70035
# Too much error!
# Episode * 309 * Avg Reward is ==> 340089.050075
# Too much error!
# Episode * 310 * Avg Reward is ==> 340089.05007500004
# Too much error!
# Episode * 311 * Avg Reward is ==> 340089.08075
# Too much error!
# Episode * 312 * Avg Reward is ==> 340089.08075
# Too much error!
# Episode * 313 * Avg Reward is ==> 312586.01715
# Too much error!
# Episode * 314 * Avg Reward is ==> 285083.0294
# Too much error!
# Episode * 315 * Avg Reward is ==> 285079.997525
# Too much error!
# Episode * 316 * Avg Reward is ==> 285079.997525
# Too much error!
# Episode * 317 * Avg Reward is ==> 285080.516025
# Too much error!
# Episode * 318 * Avg Reward is ==> 257576.546025
# Too much error!
# Episode * 319 * Avg Reward is ==> 230073.45565
# Too much error!
# Episode * 320 * Avg Reward is ==> 202570.37867499999
# Too much error!
# Episode * 321 * Avg Reward is ==> 202569.52907500003
# Too much error!
# Episode * 322 * Avg Reward is ==> 202569.52907500003
# Too much error!
# Episode * 323 * Avg Reward is ==> 202569.529075
# Too much error!
# Episode * 324 * Avg Reward is ==> 202570.3378
# Too much error!
# Episode * 325 * Avg Reward is ==> 202570.3378
# Too much error!
# Episode * 326 * Avg Reward is ==> 202570.81067500002
# Too much error!
# Episode * 327 * Avg Reward is ==> 202570.810675
# Too much error!
# Episode * 328 * Avg Reward is ==> 202570.80049999998
# Too much error!
# Episode * 329 * Avg Reward is ==> 202570.80049999998
# Too much error!
# Episode * 330 * Avg Reward is ==> 202570.8005
# Too much error!
# Episode * 331 * Avg Reward is ==> 202570.80049999998
# Too much error!
# Episode * 332 * Avg Reward is ==> 202569.9755
# Too much error!
# Episode * 333 * Avg Reward is ==> 175066.93029999998
# Too much error!
# Episode * 334 * Avg Reward is ==> 147564.97905000002
# Too much error!
# Episode * 335 * Avg Reward is ==> 147556.592925
# Too much error!
# Episode * 336 * Avg Reward is ==> 120053.35350000001
# Too much error!
# Episode * 337 * Avg Reward is ==> 92550.0729
# Too much error!
# Episode * 338 * Avg Reward is ==> 65046.89307500001
# Too much error!
# Episode * 339 * Avg Reward is ==> 37543.86945
# Too much error!
# Episode * 340 * Avg Reward is ==> 37543.278075
# Too much error!
# Episode * 341 * Avg Reward is ==> 37543.26285
# Too much error!
# Episode * 342 * Avg Reward is ==> 10041.15325
# Too much error!
# Episode * 343 * Avg Reward is ==> -17461.794425000007
# Too much error!
# Episode * 344 * Avg Reward is ==> -44964.911675
# Too much error!
# Episode * 345 * Avg Reward is ==> -44966.110775
# Too much error!
# Episode * 346 * Avg Reward is ==> -44966.115825
# Too much error!
# Episode * 347 * Avg Reward is ==> -72469.23307500001
# Too much error!
# Episode * 348 * Avg Reward is ==> -99972.29667500002
# Too much error!
# Episode * 349 * Avg Reward is ==> -99975.6464
# Too much error!
# Episode * 350 * Avg Reward is ==> -99975.6464
# Too much error!
# Episode * 351 * Avg Reward is ==> -99975.67707500001
# Too much error!
# Episode * 352 * Avg Reward is ==> -99975.6464
# Done!
# Episode * 353 * Avg Reward is ==> -72474.158925
# Too much error!
# Episode * 354 * Avg Reward is ==> -72474.1693
# Too much error!
# Episode * 355 * Avg Reward is ==> -72474.17435000002
# Too much error!
# Episode * 356 * Avg Reward is ==> -72474.17435
# Too much error!
# Episode * 357 * Avg Reward is ==> -72474.69285
# Too much error!
# Episode * 358 * Avg Reward is ==> -72474.6725
# Too much error!
# Episode * 359 * Avg Reward is ==> -72474.67250000002
# Too much error!
# Episode * 360 * Avg Reward is ==> -72474.6314
# Done!
# Episode * 361 * Avg Reward is ==> -44971.6343
# Too much error!
# Episode * 362 * Avg Reward is ==> -44970.606199999995
# Too much error!
# Episode * 363 * Avg Reward is ==> -44970.6062
# Too much error!
# Episode * 364 * Avg Reward is ==> -44971.414925
# Too much error!
# Episode * 365 * Avg Reward is ==> -44971.414925
# Too much error!
# Episode * 366 * Avg Reward is ==> -44971.897925
# Too much error!
# Episode * 367 * Avg Reward is ==> -44971.897925
# Too much error!
# Episode * 368 * Avg Reward is ==> -44971.902975
# Done!
# Episode * 369 * Avg Reward is ==> -17468.905875000004
# Done!
# Episode * 370 * Avg Reward is ==> 10034.197924999991
# Done!
# Episode * 371 * Avg Reward is ==> 37537.248175
# Too much error!
# Episode * 372 * Avg Reward is ==> 37538.66634999999
# Too much error!
# Episode * 373 * Avg Reward is ==> 37538.6613
# Too much error!
# Episode * 374 * Avg Reward is ==> 37537.572425
# Done!
# Episode * 375 * Avg Reward is ==> 65040.70315
# Too much error!
# Episode * 376 * Avg Reward is ==> 65045.2757
# Too much error!
# Episode * 377 * Avg Reward is ==> 65045.28074999999
# Done!
# Episode * 378 * Avg Reward is ==> 92548.35267500002
# Episode * 379 * Avg Reward is ==> 95060.35764999999
# Done!
# Episode * 380 * Avg Reward is ==> 122563.44802500002
# Done!
# Episode * 381 * Avg Reward is ==> 150068.39375
# Too much error!
# Episode * 382 * Avg Reward is ==> 150069.214
# Done!
# Episode * 383 * Avg Reward is ==> 177572.055975
# Too much error!
# Episode * 384 * Avg Reward is ==> 177572.06102500003
# Too much error!
# Episode * 385 * Avg Reward is ==> 177572.061025
# Done!
# Episode * 386 * Avg Reward is ==> 205075.13799999998
# Too much error!
# Episode * 387 * Avg Reward is ==> 205086.9685
# Too much error!
# Episode * 388 * Avg Reward is ==> 205087.05775
# Too much error!
# Episode * 389 * Avg Reward is ==> 205089.41225
# Done!
# Episode * 390 * Avg Reward is ==> 232592.4625
# Done!
# Episode * 391 * Avg Reward is ==> 260095.12387499996
# Too much error!
# Episode * 392 * Avg Reward is ==> 260095.10332499997
# Too much error!
# Episode * 393 * Avg Reward is ==> 232593.61585
# Too much error!
# Episode * 394 * Avg Reward is ==> 232593.59035
# Too much error!
# Episode * 395 * Avg Reward is ==> 232594.17432500003
# Too much error!
# Episode * 396 * Avg Reward is ==> 232594.17432499997
# Too much error!
# Episode * 397 * Avg Reward is ==> 232596.24892500002
# Too much error!
# Episode * 398 * Avg Reward is ==> 232596.23870000002
# Too much error!
# Episode * 399 * Avg Reward is ==> 232597.42857500003
# Too much error!
# Episode * 400 * Avg Reward is ==> 232598.108475
# Too much error!
# Episode * 401 * Avg Reward is ==> 205095.2061
# Too much error!
# Episode * 402 * Avg Reward is ==> 205095.22367500002
# Too much error!
# Episode * 403 * Avg Reward is ==> 205095.22367500002
# Too much error!
# Episode * 404 * Avg Reward is ==> 205095.22367500002
# Too much error!
# Episode * 405 * Avg Reward is ==> 205095.22367500002
# Too much error!
# Episode * 406 * Avg Reward is ==> 205095.249175
# Too much error!
# Episode * 407 * Avg Reward is ==> 205095.26440000004
# Done!
# Episode * 408 * Avg Reward is ==> 232598.46287500003
# Done!
# Episode * 409 * Avg Reward is ==> 232598.569575
# Done!
# Episode * 410 * Avg Reward is ==> 232598.76015000005
# Done!
# Episode * 411 * Avg Reward is ==> 232598.96302500003
# Too much error!
# Episode * 412 * Avg Reward is ==> 232597.55497500004
# Too much error!
# Episode * 413 * Avg Reward is ==> 232597.55497500004
# Too much error!
# Episode * 414 * Avg Reward is ==> 232597.54485000003
# Too much error!
# Episode * 415 * Avg Reward is ==> 205094.41412499998
# Too much error!
# Episode * 416 * Avg Reward is ==> 205089.84157500003
# Too much error!
# Episode * 417 * Avg Reward is ==> 205089.856875
# Too much error!
# Episode * 418 * Avg Reward is ==> 177586.8054
# Too much error!
# Episode * 419 * Avg Reward is ==> 175074.800425
# Too much error!
# Episode * 420 * Avg Reward is ==> 147571.71005
# Too much error!
# Episode * 421 * Avg Reward is ==> 120066.87007500001
# Too much error!
# Episode * 422 * Avg Reward is ==> 120065.16082499998
# Done!
# Episode * 423 * Avg Reward is ==> 120064.7172
# Too much error!
# Episode * 424 * Avg Reward is ==> 120065.52900000001
# Too much error!
# Episode * 425 * Avg Reward is ==> 120065.52900000001
# Too much error!
# Episode * 426 * Avg Reward is ==> 92562.45202499999
# Too much error!
# Episode * 427 * Avg Reward is ==> 92550.621525
# Too much error!
# Episode * 428 * Avg Reward is ==> 92550.532275
# Too much error!
# Episode * 429 * Avg Reward is ==> 92548.177775
# Too much error!
# Episode * 430 * Avg Reward is ==> 65045.127524999996
# Too much error!
# Episode * 431 * Avg Reward is ==> 37548.665575000006
# Too much error!
# Episode * 432 * Avg Reward is ==> 37549.224700000006
# Too much error!
# Episode * 433 * Avg Reward is ==> 37549.22975
# Too much error!
# Episode * 434 * Avg Reward is ==> 37549.229750000006
# Too much error!
# Episode * 435 * Avg Reward is ==> 37548.68165
# Too much error!
# Episode * 436 * Avg Reward is ==> 37548.68165
# Too much error!
# Episode * 437 * Avg Reward is ==> 37546.60704999999
# Too much error!
# Episode * 438 * Avg Reward is ==> 37546.596925000005
# Too much error!
# Episode * 439 * Avg Reward is ==> 37545.407049999994
# Done!
# Episode * 440 * Avg Reward is ==> 65048.21842499999
# Done!
# Episode * 441 * Avg Reward is ==> 92551.16062499999
# Done!
# Episode * 442 * Avg Reward is ==> 120053.34069999999
# Too much error!
# Episode * 443 * Avg Reward is ==> 120053.895325
# Too much error!
# Episode * 444 * Avg Reward is ==> 120057.02604999999
# Too much error!
# Episode * 445 * Avg Reward is ==> 120057.02604999999
# Too much error!
# Episode * 446 * Avg Reward is ==> 120059.624275
# Done!
# Episode * 447 * Avg Reward is ==> 147562.699425
# Too much error!
# Episode * 448 * Avg Reward is ==> 120059.61225
# Too much error!
# Episode * 449 * Avg Reward is ==> 92556.50845000001
# Too much error!
# Episode * 450 * Avg Reward is ==> 65053.214075
# Too much error!
# Episode * 451 * Avg Reward is ==> 37549.96095
# Too much error!
# Episode * 452 * Avg Reward is ==> 37549.95082500001
# Too much error!
# Episode * 453 * Avg Reward is ==> 37549.997175000004
# Too much error!
# Episode * 454 * Avg Reward is ==> 37550.07015000001
# Too much error!
# Episode * 455 * Avg Reward is ==> 37550.07015000001
# Too much error!
# Episode * 456 * Avg Reward is ==> 37550.07015000001
# Too much error!
# Episode * 457 * Avg Reward is ==> 37550.05992500001
# Too much error!
# Episode * 458 * Avg Reward is ==> 37550.05992500001
# Too much error!
# Episode * 459 * Avg Reward is ==> 37550.05992500001
# Too much error!
# Episode * 460 * Avg Reward is ==> 37550.059925
# Too much error!
# Episode * 461 * Avg Reward is ==> 37549.954175000006
# Too much error!
# Episode * 462 * Avg Reward is ==> 37549.8758
# Too much error!
# Episode * 463 * Avg Reward is ==> 10047.388200000001
# Too much error!
# Episode * 464 * Avg Reward is ==> 10046.571349999995
# Too much error!
# Episode * 465 * Avg Reward is ==> 10046.571349999998
# Too much error!
# Episode * 466 * Avg Reward is ==> 10046.628275000001
# Too much error!
# Episode * 467 * Avg Reward is ==> 10046.6384
# Too much error!
# Episode * 468 * Avg Reward is ==> 10046.653625000003
# Too much error!
# Episode * 469 * Avg Reward is ==> 10047.629599999997
# Too much error!
# Episode * 470 * Avg Reward is ==> 10047.629599999997
# Too much error!
# Episode * 471 * Avg Reward is ==> 10041.430174999996
# Too much error!
# Episode * 472 * Avg Reward is ==> 10040.860925
# Too much error!
# Episode * 473 * Avg Reward is ==> 10040.85587499999
# Too much error!
# Episode * 474 * Avg Reward is ==> 10040.855874999997
# Too much error!
# Episode * 475 * Avg Reward is ==> 10040.819999999992
# Too much error!
# Episode * 476 * Avg Reward is ==> 10040.819999999998
# Too much error!
# Episode * 477 * Avg Reward is ==> 10040.819999999989
# Too much error!
# Episode * 478 * Avg Reward is ==> 10040.876925
# Too much error!
# Episode * 479 * Avg Reward is ==> 10042.304924999993
# Too much error!
# Episode * 480 * Avg Reward is ==> -17460.506450000008
# Too much error!
# Episode * 481 * Avg Reward is ==> -44963.46500000001
# Too much error!
# Episode * 482 * Avg Reward is ==> -72466.633825
# Too much error!
# Episode * 483 * Avg Reward is ==> -72465.55870000001
# Too much error!
# Episode * 484 * Avg Reward is ==> -72468.627175
# Done!
# Episode * 485 * Avg Reward is ==> -44965.60355000001
# Too much error!
# Episode * 486 * Avg Reward is ==> -44966.896400000005
# Too much error!
# Episode * 487 * Avg Reward is ==> -72467.70360000001
# Too much error!
# Episode * 488 * Avg Reward is ==> -72465.21615
# Too much error!
# Episode * 489 * Avg Reward is ==> -72465.21615
# Too much error!
# Episode * 490 * Avg Reward is ==> -72464.143925
# Too much error!
# Episode * 491 * Avg Reward is ==> -72464.14392500001
# Done!
# Episode * 492 * Avg Reward is ==> -44961.419299999994
# Done!
# Episode * 493 * Avg Reward is ==> -17458.185049999993
# Too much error!
# Episode * 494 * Avg Reward is ==> -17455.951174999995
# Too much error!
# Episode * 495 * Avg Reward is ==> -17454.96657499999
# Too much error!
# Episode * 496 * Avg Reward is ==> -17454.966575000002
# Too much error!
# Episode * 497 * Avg Reward is ==> -17454.976699999992
# Too much error!
# Episode * 498 * Avg Reward is ==> -17453.149849999998
# Too much error!
# Episode * 499 * Avg Reward is ==> -17452.397299999993
# Too much error!
# Episode * 500 * Avg Reward is ==> -17452.318925
# Too much error!
# Episode * 501 * Avg Reward is ==> -17450.444800000005
# Too much error!
# Episode * 502 * Avg Reward is ==> -17450.439749999998
# Too much error!
# Episode * 503 * Avg Reward is ==> -17450.372150000003
# Too much error!
# Episode * 504 * Avg Reward is ==> -17450.37215
# Too much error!
# Episode * 505 * Avg Reward is ==> -17450.372150000003
# Too much error!
# Episode * 506 * Avg Reward is ==> -17450.429075
# Too much error!
# Episode * 507 * Avg Reward is ==> -17450.439200000004
# Done!
# Episode * 508 * Avg Reward is ==> 10052.635950000002
# Done!
# Episode * 509 * Avg Reward is ==> 37554.75035
# Done!
# Episode * 510 * Avg Reward is ==> 65057.84072500002
# Episode * 511 * Avg Reward is ==> 67569.8457
# Done!
# Episode * 512 * Avg Reward is ==> 95072.89595
# Too much error!
# Episode * 513 * Avg Reward is ==> 95078.5397
# Done!
# Episode * 514 * Avg Reward is ==> 122582.30267500001
# Done!
# Episode * 515 * Avg Reward is ==> 150085.366275
# Too much error!
# Episode * 516 * Avg Reward is ==> 150085.366275
# Too much error!
# Episode * 517 * Avg Reward is ==> 150086.5104
# Too much error!
# Episode * 518 * Avg Reward is ==> 150086.45347500002
# Too much error!
# Episode * 519 * Avg Reward is ==> 150086.06234999996
# Too much error!
# Episode * 520 * Avg Reward is ==> 150085.38245
# Done!
# Episode * 521 * Avg Reward is ==> 177589.59379999997
# Done!
# Episode * 522 * Avg Reward is ==> 205092.762625
# Too much error!
# Episode * 523 * Avg Reward is ==> 205093.427875
# Too much error!
# Episode * 524 * Avg Reward is ==> 205093.46584999998
# Done!
# Episode * 525 * Avg Reward is ==> 205093.47914999997
# Done!
# Episode * 526 * Avg Reward is ==> 232595.1852
# Too much error!
# Episode * 527 * Avg Reward is ==> 232594.78707499997
# Done!
# Episode * 528 * Avg Reward is ==> 260095.238575
# Done!
# Episode * 529 * Avg Reward is ==> 287598.396325
# Done!
# Episode * 530 * Avg Reward is ==> 315100.37435
# Done!
# Episode * 531 * Avg Reward is ==> 342603.50507499994
# Done!
# Episode * 532 * Avg Reward is ==> 342604.21394999995
# Done!
# Episode * 533 * Avg Reward is ==> 342604.13182499993
# Done!
# Episode * 534 * Avg Reward is ==> 370104.8486
# Too much error!
# Episode * 535 * Avg Reward is ==> 370106.00722499995
# Too much error!
# Episode * 536 * Avg Reward is ==> 370106.05885
# Too much error!
# Episode * 537 * Avg Reward is ==> 370106.05885
# Done!
# Episode * 538 * Avg Reward is ==> 397615.4481
# Done!
# Episode * 539 * Avg Reward is ==> 425117.73247499997
# Done!
# Episode * 540 * Avg Reward is ==> 452620.75789999997
# Done!
# Episode * 541 * Avg Reward is ==> 480122.01449999993
# Too much error!
# Episode * 542 * Avg Reward is ==> 480126.59795
# Too much error!
# Episode * 543 * Avg Reward is ==> 480127.1217250001
# Done!
# Episode * 544 * Avg Reward is ==> 507630.3202000001
# Too much error!
# Episode * 545 * Avg Reward is ==> 507639.393925
# Too much error!
# Episode * 546 * Avg Reward is ==> 507639.3939250001
# Too much error!
# Episode * 547 * Avg Reward is ==> 507639.393925
# Too much error!
# Episode * 548 * Avg Reward is ==> 480136.30355
# Too much error!
# Episode * 549 * Avg Reward is ==> 452633.21317500004
# Too much error!
# Episode * 550 * Avg Reward is ==> 425130.1586750001
# Too much error!
# Episode * 551 * Avg Reward is ==> 422618.1537
# Too much error!
# Episode * 552 * Avg Reward is ==> 395115.10345
# Too much error!
# Episode * 553 * Avg Reward is ==> 395109.4597
# Too much error!
# Episode * 554 * Avg Reward is ==> 367605.69672500005
# Too much error!
# Episode * 555 * Avg Reward is ==> 340102.633125
# Too much error!
# Episode * 556 * Avg Reward is ==> 340102.633125
# Done!
# Episode * 557 * Avg Reward is ==> 367604.5526
# Done!
# Episode * 558 * Avg Reward is ==> 395107.54970000003
# Done!
# Episode * 559 * Avg Reward is ==> 422609.576425
# Done!
# Episode * 560 * Avg Reward is ==> 450112.871175
# Too much error!
# Episode * 561 * Avg Reward is ==> 422608.66524999996
# Too much error!
# Episode * 562 * Avg Reward is ==> 395105.49112500006
# Too much error!
# Episode * 563 * Avg Reward is ==> 395103.196125
# Too much error!
# Episode * 564 * Avg Reward is ==> 395103.09589999996
# Too much error!
# Episode * 565 * Avg Reward is ==> 367600.058975
# Too much error!
# Episode * 566 * Avg Reward is ==> 340097.02205
# Too much error!
# Episode * 567 * Avg Reward is ==> 340095.66267499997
# Too much error!
# Episode * 568 * Avg Reward is ==> 312592.61242500006
# Too much error!
# Episode * 569 * Avg Reward is ==> 285089.454675
# Too much error!
# Episode * 570 * Avg Reward is ==> 257586.40442500002
# Too much error!
# Episode * 571 * Avg Reward is ==> 230083.27369999996
# Done!
# Episode * 572 * Avg Reward is ==> 230082.667325
# Too much error!
# Episode * 573 * Avg Reward is ==> 202584.69890000002
# Too much error!
# Episode * 574 * Avg Reward is ==> 175081.680325
# Too much error!
# Episode * 575 * Avg Reward is ==> 175079.610075
# Too much error!
# Episode * 576 * Avg Reward is ==> 175079.6207
# Too much error!
# Episode * 577 * Avg Reward is ==> 175079.6207
# Too much error!
# Episode * 578 * Avg Reward is ==> 147568.394325
# Too much error!
# Episode * 579 * Avg Reward is ==> 120065.36752500001
# Too much error!
# Episode * 580 * Avg Reward is ==> 92562.26372500001
# Too much error!
# Episode * 581 * Avg Reward is ==> 65059.13300000001
# Too much error!
# Episode * 582 * Avg Reward is ==> 65054.5445
# Too much error!
# Episode * 583 * Avg Reward is ==> 65053.953125
# Too much error!
# Episode * 584 * Avg Reward is ==> 37550.75464999999
# Too much error!
# Episode * 585 * Avg Reward is ==> 37541.68092499999
# Too much error!
# Episode * 586 * Avg Reward is ==> 37541.68092499999
# Too much error!
# Episode * 587 * Avg Reward is ==> 37541.68092499999
# Too much error!
# Episode * 588 * Avg Reward is ==> 37541.680924999986
# Too much error!
# Episode * 589 * Avg Reward is ==> 37541.68092499999
# Too much error!
# Episode * 590 * Avg Reward is ==> 37541.64504999999
# Too much error!
# Episode * 591 * Avg Reward is ==> 37541.64505000001
# Too much error!
# Episode * 592 * Avg Reward is ==> 37541.64505
# Done!
# Episode * 593 * Avg Reward is ==> 65044.602549999996
# Too much error!
# Episode * 594 * Avg Reward is ==> 65044.6076
# Too much error!
# Episode * 595 * Avg Reward is ==> 65044.6076
# Too much error!
# Episode * 596 * Avg Reward is ==> 65044.6076
# Too much error!
# Episode * 597 * Avg Reward is ==> 37541.543999999994
# Too much error!
# Episode * 598 * Avg Reward is ==> 10038.546899999992
# Too much error!
# Episode * 599 * Avg Reward is ==> -17464.516700000004
# Too much error!
# Episode * 600 * Avg Reward is ==> -44967.852549999996
# Too much error!
# Episode * 601 * Avg Reward is ==> -44967.936349999996
# Too much error!
# Episode * 602 * Avg Reward is ==> -44967.987975000004
# Too much error!
# Episode * 603 * Avg Reward is ==> -44967.987975000004
# Done!
# Episode * 604 * Avg Reward is ==> -17464.884174999996
# Done!
# Episode * 605 * Avg Reward is ==> 10038.126174999998
# Too much error!
# Episode * 606 * Avg Reward is ==> 10041.149800000003
# Too much error!
# Episode * 607 * Avg Reward is ==> 10040.691725
# Too much error!
# Episode * 608 * Avg Reward is ==> 10040.706950000003
# Too much error!
# Episode * 609 * Avg Reward is ==> 10040.706949999998
# Too much error!
# Episode * 610 * Avg Reward is ==> 10040.706950000002
# Too much error!
# Episode * 611 * Avg Reward is ==> 10040.706949999998
# Too much error!
# Episode * 612 * Avg Reward is ==> -17462.120175000004
# Too much error!
# Episode * 613 * Avg Reward is ==> -17464.947674999996
# Too much error!
# Episode * 614 * Avg Reward is ==> -17464.937499999996
# Too much error!
# Episode * 615 * Avg Reward is ==> -17463.092499999995
# Too much error!
# Episode * 616 * Avg Reward is ==> -17462.585499999994
# Too much error!
# Episode * 617 * Avg Reward is ==> -17462.585499999994
# Too much error!
# Episode * 618 * Avg Reward is ==> -17462.600724999997
# Too much error!
# Episode * 619 * Avg Reward is ==> -17462.610849999997
# Too much error!
# Episode * 620 * Avg Reward is ==> -17462.61085
# Too much error!
# Episode * 621 * Avg Reward is ==> -17462.600724999997
# Done!
# Episode * 622 * Avg Reward is ==> 10040.396375
# Too much error!
# Episode * 623 * Avg Reward is ==> 10041.670175000003
# Too much error!
# Episode * 624 * Avg Reward is ==> 10042.246774999998
# Too much error!
# Episode * 625 * Avg Reward is ==> 10043.427450000003
# Done!
# Episode * 626 * Avg Reward is ==> 37546.2288
# Done!
# Episode * 627 * Avg Reward is ==> 65049.319175
# Too much error!
# Episode * 628 * Avg Reward is ==> 65049.344675
# Too much error!
# Episode * 629 * Avg Reward is ==> 65049.344675000015
# Too much error!
# Episode * 630 * Avg Reward is ==> 65049.344674999986
# Too much error!
# Episode * 631 * Avg Reward is ==> 65049.344675
# Too much error!
# Episode * 632 * Avg Reward is ==> 65049.344674999986
# Too much error!
# Episode * 633 * Avg Reward is ==> 37546.387175
# Too much error!
# Episode * 634 * Avg Reward is ==> 37546.38212499999
# Too much error!
# Episode * 635 * Avg Reward is ==> 37546.382125000004
# Too much error!
# Episode * 636 * Avg Reward is ==> 37546.387174999996
# Too much error!
# Episode * 637 * Avg Reward is ==> 37547.595525
# Too much error!
# Episode * 638 * Avg Reward is ==> 37547.66849999999
# Too much error!
# Episode * 639 * Avg Reward is ==> 37554.070875
# Done!
# Episode * 640 * Avg Reward is ==> 65057.1078
# Too much error!
# Episode * 641 * Avg Reward is ==> 65057.5698
# Done!
# Episode * 642 * Avg Reward is ==> 92560.660175
# Done!
# Episode * 643 * Avg Reward is ==> 120063.83147499998
# Too much error!
# Episode * 644 * Avg Reward is ==> 92560.789925
# Too much error!
# Episode * 645 * Avg Reward is ==> 65058.37094999999
# Done!
# Episode * 646 * Avg Reward is ==> 92558.49155
# Too much error!
# Episode * 647 * Avg Reward is ==> 92558.53524999999
# Too much error!
# Episode * 648 * Avg Reward is ==> 92558.525075
# Too much error!
# Episode * 649 * Avg Reward is ==> 92565.002
# Too much error!
# Episode * 650 * Avg Reward is ==> 92565.935225
# Too much error!
# Episode * 651 * Avg Reward is ==> 92565.99215
# Done!
# Episode * 652 * Avg Reward is ==> 120069.38365
# Too much error!
# Episode * 653 * Avg Reward is ==> 120067.06490000003
# Too much error!
# Episode * 654 * Avg Reward is ==> 120067.04967499999
# Too much error!
# Episode * 655 * Avg Reward is ==> 120065.1317
# Too much error!
# Episode * 656 * Avg Reward is ==> 120064.56245
# Too much error!
# Episode * 657 * Avg Reward is ==> 120064.56245000001
# Too much error!
# Episode * 658 * Avg Reward is ==> 120064.56245
# Too much error!
# Episode * 659 * Avg Reward is ==> 120064.56245000001
# Too much error!
# Episode * 660 * Avg Reward is ==> 120064.5675
# Too much error!
# Episode * 661 * Avg Reward is ==> 120071.94022500003
# Too much error!
# Episode * 662 * Avg Reward is ==> 92571.051925
# Too much error!
# Episode * 663 * Avg Reward is ==> 92570.99575
# Too much error!
# Episode * 664 * Avg Reward is ==> 92570.449825
# Too much error!
# Episode * 665 * Avg Reward is ==> 92569.26915000001
# Too much error!
# Episode * 666 * Avg Reward is ==> 65066.472850000006
# Done!
# Episode * 667 * Avg Reward is ==> 65070.00970000001
# Too much error!
# Episode * 668 * Avg Reward is ==> 65075.76905
# Too much error!
# Episode * 669 * Avg Reward is ==> 65075.83664999999
# Too much error!
# Episode * 670 * Avg Reward is ==> 65075.841700000004
# Too much error!
# Episode * 671 * Avg Reward is ==> 65078.4905
# Too much error!
# Episode * 672 * Avg Reward is ==> 65078.4905
# Too much error!
# Episode * 673 * Avg Reward is ==> 65078.49049999999
# Too much error!
# Episode * 674 * Avg Reward is ==> 65078.4905
# Too much error!
# Episode * 675 * Avg Reward is ==> 65078.98055
# Too much error!
# Episode * 676 * Avg Reward is ==> 65080.13785
# Too much error!
# Episode * 677 * Avg Reward is ==> 65080.891724999994
# Too much error!
# Episode * 678 * Avg Reward is ==> 65080.81875
# Too much error!
# Episode * 679 * Avg Reward is ==> 65074.41637499999
# Too much error!
# Episode * 680 * Avg Reward is ==> 37571.37944999999
# Too much error!
# Episode * 681 * Avg Reward is ==> 37570.948124999995
# Done!
# Episode * 682 * Avg Reward is ==> 37570.907999999996
# Too much error!
# Episode * 683 * Avg Reward is ==> 10069.315075
# Too much error!
# Episode * 684 * Avg Reward is ==> 10069.252825
# Done!
# Episode * 685 * Avg Reward is ==> 37571.3988
# Too much error!
# Episode * 686 * Avg Reward is ==> 10068.285250000004
# Too much error!
# Episode * 687 * Avg Reward is ==> 10068.189175000001
# Too much error!
# Episode * 688 * Avg Reward is ==> 10068.184125000005
# Too much error!
# Episode * 689 * Avg Reward is ==> 10061.707200000004
# Too much error!
# Episode * 690 * Avg Reward is ==> 10060.773975000007
# Too much error!
# Episode * 691 * Avg Reward is ==> 10060.717049999997
# Too much error!
# Episode * 692 * Avg Reward is ==> -17442.67445
# Too much error!
# Episode * 693 * Avg Reward is ==> -17442.758249999995
# Too much error!
# Episode * 694 * Avg Reward is ==> -17442.758249999995
# Done!
# Episode * 695 * Avg Reward is ==> 10061.469725000003
# Done!
# Episode * 696 * Avg Reward is ==> 37564.533325000004
# Done!
# Episode * 697 * Avg Reward is ==> 65067.813925
# Done!
# Episode * 698 * Avg Reward is ==> 92570.83755000001
# Too much error!
# Episode * 699 * Avg Reward is ==> 92577.712425
# Too much error!
# Episode * 700 * Avg Reward is ==> 92577.707375
# Too much error!
# Episode * 701 * Avg Reward is ==> 92570.33975
# Too much error!
# Episode * 702 * Avg Reward is ==> 92569.40245000001
# Too much error!
# Episode * 703 * Avg Reward is ==> 92568.189875
# Too much error!
# Episode * 704 * Avg Reward is ==> 92568.82595
# Done!
# Episode * 705 * Avg Reward is ==> 120071.67895
# Done!
# Episode * 706 * Avg Reward is ==> 147574.79115
# Done!
# Episode * 707 * Avg Reward is ==> 147571.32167499998
# Too much error!
# Episode * 708 * Avg Reward is ==> 147567.18730000002
# Too much error!
# Episode * 709 * Avg Reward is ==> 147570.78100000002
# Too much error!
# Episode * 710 * Avg Reward is ==> 147570.77595
# Too much error!
# Episode * 711 * Avg Reward is ==> 147568.1322
# Done!
# Episode * 712 * Avg Reward is ==> 175071.116075
# Done!
# Episode * 713 * Avg Reward is ==> 202574.15300000002
# Done!
# Episode * 714 * Avg Reward is ==> 230077.40612500004
# Done!
# Episode * 715 * Avg Reward is ==> 257579.96632500002
# Too much error!
# Episode * 716 * Avg Reward is ==> 257583.18707499997
# Episode * 717 * Avg Reward is ==> 260093.229825
# Done!
# Episode * 718 * Avg Reward is ==> 287596.226925
# Done!
# Episode * 719 * Avg Reward is ==> 315099.290525
# Done!
# Episode * 720 * Avg Reward is ==> 342602.43475
# Done!
# Episode * 721 * Avg Reward is ==> 370105.441
# Too much error!
# Episode * 722 * Avg Reward is ==> 342605.2308
# Too much error!
# Episode * 723 * Avg Reward is ==> 342604.80565
# Done!
# Episode * 724 * Avg Reward is ==> 370107.76315
# Too much error!
# Episode * 725 * Avg Reward is ==> 342605.48085
# Too much error!
# Episode * 726 * Avg Reward is ==> 342605.450175
# Too much error!
# Episode * 727 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 728 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 729 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 730 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 731 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 732 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 733 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 734 * Avg Reward is ==> 342605.43495
# Too much error!
# Episode * 735 * Avg Reward is ==> 315101.206975
# Too much error!
# Episode * 736 * Avg Reward is ==> 287598.14337500004
# Too much error!
# Episode * 737 * Avg Reward is ==> 260094.862775
# Too much error!
# Episode * 738 * Avg Reward is ==> 232591.83914999999
# Too much error!
# Episode * 739 * Avg Reward is ==> 232584.96427499998
# Too much error!
# Episode * 740 * Avg Reward is ==> 232584.964275
# Too much error!
# Episode * 741 * Avg Reward is ==> 232584.94905
# Too much error!
# Episode * 742 * Avg Reward is ==> 232584.42902500002
# Too much error!
# Episode * 743 * Avg Reward is ==> 232584.42397499998
# Too much error!
# Episode * 744 * Avg Reward is ==> 232583.757225
# Too much error!
# Episode * 745 * Avg Reward is ==> 205080.904225
# Too much error!
# Episode * 746 * Avg Reward is ==> 177577.786975
# Too much error!
# Episode * 747 * Avg Reward is ==> 150074.62922499998
# Too much error!
# Episode * 748 * Avg Reward is ==> 150072.97874999998
# Too much error!
# Episode * 749 * Avg Reward is ==> 150069.32757499997
# Too much error!
# Episode * 750 * Avg Reward is ==> 150069.327575
# Episode * 751 * Avg Reward is ==> 152581.32749999998
# Too much error!
# Episode * 752 * Avg Reward is ==> 125078.35884999999
# Done!
# Episode * 753 * Avg Reward is ==> 125082.88454999999
# Too much error!
# Episode * 754 * Avg Reward is ==> 97584.56064999997
# Too much error!
# Episode * 755 * Avg Reward is ==> 70081.5104
# Too much error!
# Episode * 756 * Avg Reward is ==> 70077.12729999998
# Too much error!
# Episode * 757 * Avg Reward is ==> 67565.122325
# Too much error!
# Episode * 758 * Avg Reward is ==> 40062.12522499998
# Too much error!
# Episode * 759 * Avg Reward is ==> 12559.061624999998
# Too much error!
# Episode * 760 * Avg Reward is ==> -14944.082600000012
# Too much error!
# Episode * 761 * Avg Reward is ==> -42447.119525
# Too much error!
# Episode * 762 * Avg Reward is ==> -42449.959575
# Too much error!
# Episode * 763 * Avg Reward is ==> -42451.1128
# Too much error!
# Episode * 764 * Avg Reward is ==> -69954.07029999999
# Too much error!
# Episode * 765 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 766 * Avg Reward is ==> -69954.52534999998
# Too much error!
# Episode * 767 * Avg Reward is ==> -69954.52534999998
# Too much error!
# Episode * 768 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 769 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 770 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 771 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 772 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 773 * Avg Reward is ==> -69954.52535
# Too much error!
# Episode * 774 * Avg Reward is ==> -69954.51522500001
# Too much error!
# Episode * 775 * Avg Reward is ==> -69954.4583
# Too much error!
# Episode * 776 * Avg Reward is ==> -69953.6738
# Too much error!
# Episode * 777 * Avg Reward is ==> -69952.8242
# Done!
# Episode * 778 * Avg Reward is ==> -42449.827099999995
# Done!
# Episode * 779 * Avg Reward is ==> -14946.816749999998
# Done!
# Episode * 780 * Avg Reward is ==> 12556.18035000001
# Done!
# Episode * 781 * Avg Reward is ==> 40059.217275
# Done!
# Episode * 782 * Avg Reward is ==> 67561.56290000002
# Done!
# Episode * 783 * Avg Reward is ==> 95064.586525
# Done!
# Episode * 784 * Avg Reward is ==> 122567.69032500002
# Too much error!
# Episode * 785 * Avg Reward is ==> 122568.88942499999
# Too much error!
# Episode * 786 * Avg Reward is ==> 122568.88942500002
# Too much error!
# Episode * 787 * Avg Reward is ==> 122568.88942499999
# Too much error!
# Episode * 788 * Avg Reward is ==> 122568.88942500002
# Too much error!
# Episode * 789 * Avg Reward is ==> 122568.8793
# Too much error!
# Episode * 790 * Avg Reward is ==> 122568.8793
# Too much error!
# Episode * 791 * Avg Reward is ==> 120056.87432499998
# Done!
# Episode * 792 * Avg Reward is ==> 147559.334475
# Done!
# Episode * 793 * Avg Reward is ==> 147557.398075
# Too much error!
# Episode * 794 * Avg Reward is ==> 147555.4132
# Done!
# Episode * 795 * Avg Reward is ==> 175058.26619999998
# Too much error!
# Episode * 796 * Avg Reward is ==> 175067.49375
# Too much error!
# Episode * 797 * Avg Reward is ==> 175067.508975
# Too much error!
# Episode * 798 * Avg Reward is ==> 175067.508975
# Too much error!
# Episode * 799 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 800 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 801 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 802 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 803 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 804 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 805 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 806 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 807 * Avg Reward is ==> 175069.03659999996
# Too much error!
# Episode * 808 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 809 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 810 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 811 * Avg Reward is ==> 175069.03659999996
# Too much error!
# Episode * 812 * Avg Reward is ==> 175069.03659999996
# Too much error!
# Episode * 813 * Avg Reward is ==> 175069.0366
# Too much error!
# Episode * 814 * Avg Reward is ==> 175069.026475
# Too much error!
# Episode * 815 * Avg Reward is ==> 175068.96954999998
# Too much error!
# Episode * 816 * Avg Reward is ==> 175068.18504999997
# Too much error!
# Episode * 817 * Avg Reward is ==> 175070.65744999997
# Too much error!
# Episode * 818 * Avg Reward is ==> 147567.66035
# Too much error!
# Episode * 819 * Avg Reward is ==> 120064.64999999998
# Too much error!
# Episode * 820 * Avg Reward is ==> 92561.65289999999
# Too much error!
# Episode * 821 * Avg Reward is ==> 65058.615974999986
# Too much error!
# Episode * 822 * Avg Reward is ==> 37555.618875
# Done!
# Episode * 823 * Avg Reward is ==> 37555.63217499999
# Done!
# Episode * 824 * Avg Reward is ==> 37555.57862499998
# Done!
# Episode * 825 * Avg Reward is ==> 65057.550825
# Too much error!
# Episode * 826 * Avg Reward is ==> 65058.71317499998
# Too much error!
# Episode * 827 * Avg Reward is ==> 65058.713175
# Done!
# Episode * 828 * Avg Reward is ==> 92561.67067499999
# Too much error!
# Episode * 829 * Avg Reward is ==> 92562.561775
# Done!
# Episode * 830 * Avg Reward is ==> 120066.42765
# Done!
# Episode * 831 * Avg Reward is ==> 147569.571875
# Too much error!
# Episode * 832 * Avg Reward is ==> 120067.6366
# Too much error!
# Episode * 833 * Avg Reward is ==> 92562.02050000001
# Too much error!
# Episode * 834 * Avg Reward is ==> 92560.184125
# Too much error!
# Episode * 835 * Avg Reward is ==> 65057.331125000004
# Too much error!
# Episode * 836 * Avg Reward is ==> 65049.25680000001
# Too much error!
# Episode * 837 * Avg Reward is ==> 65049.293200000015
# Too much error!
# Episode * 838 * Avg Reward is ==> 65049.2932
# Too much error!
# Episode * 839 * Avg Reward is ==> 65047.76557500001
# Too much error!
# Episode * 840 * Avg Reward is ==> 65047.76557500001
# Too much error!
# Episode * 841 * Avg Reward is ==> 65047.76557500001
# Too much error!
# Episode * 842 * Avg Reward is ==> 65047.765575000005
# Done!
# Episode * 843 * Avg Reward is ==> 92550.64455
# Too much error!
# Episode * 844 * Avg Reward is ==> 92551.70790000001
# Too much error!
# Episode * 845 * Avg Reward is ==> 92551.70790000001
# Too much error!
# Episode * 846 * Avg Reward is ==> 92552.574025
# Too much error!
# Episode * 847 * Avg Reward is ==> 92553.17282499999
# Too much error!
# Episode * 848 * Avg Reward is ==> 92553.177875
# Too much error!
# Episode * 849 * Avg Reward is ==> 92553.25625
# Done!
# Episode * 850 * Avg Reward is ==> 120056.30649999999
# Done!
# Episode * 851 * Avg Reward is ==> 147559.450725
# Too much error!
# Episode * 852 * Avg Reward is ==> 147561.68685
# Done!
# Episode * 853 * Avg Reward is ==> 175064.710475
# Done!
# Episode * 854 * Avg Reward is ==> 202568.1721
# Too much error!
# Episode * 855 * Avg Reward is ==> 202568.846525
# Too much error!
# Episode * 856 * Avg Reward is ==> 202568.846525
# Too much error!
# Episode * 857 * Avg Reward is ==> 202565.52452500002
# Done!
# Episode * 858 * Avg Reward is ==> 230068.66875
# Too much error!
# Episode * 859 * Avg Reward is ==> 230069.86784999998
# Too much error!
# Episode * 860 * Avg Reward is ==> 230069.86784999998
# Too much error!
# Episode * 861 * Avg Reward is ==> 230070.43710000004
# Done!
# Episode * 862 * Avg Reward is ==> 257573.0234
# Too much error!
# Episode * 863 * Avg Reward is ==> 230071.16715000002
# Too much error!
# Episode * 864 * Avg Reward is ==> 202568.11689999996
# Too much error!
# Episode * 865 * Avg Reward is ==> 175064.94560000004
# Too much error!
# Episode * 866 * Avg Reward is ==> 175063.889
# Too much error!
# Episode * 867 * Avg Reward is ==> 175065.795975
# Too much error!
# Episode * 868 * Avg Reward is ==> 147562.838475
# Too much error!
# Episode * 869 * Avg Reward is ==> 147561.947375
# Too much error!
# Episode * 870 * Avg Reward is ==> 120058.0815
# Too much error!
# Episode * 871 * Avg Reward is ==> 92554.93727499999
# Too much error!
# Episode * 872 * Avg Reward is ==> 92554.39717499999
# Too much error!
# Episode * 873 * Avg Reward is ==> 92554.38704999999
# Too much error!
# Episode * 874 * Avg Reward is ==> 92553.78329999998
# Too much error!
# Episode * 875 * Avg Reward is ==> 92557.358425
# Too much error!
# Episode * 876 * Avg Reward is ==> 92556.21532499998
# Too much error!
# Episode * 877 * Avg Reward is ==> 92556.22595
# Too much error!
# Episode * 878 * Avg Reward is ==> 92556.22594999998
# Too much error!
# Episode * 879 * Avg Reward is ==> 92556.22595
# Too much error!
# Episode * 880 * Avg Reward is ==> 92556.22594999998
# Too much error!
# Episode * 881 * Avg Reward is ==> 92560.28617499999
# Too much error!
# Episode * 882 * Avg Reward is ==> 92560.37542499999
# Too much error!
# Episode * 883 * Avg Reward is ==> 65057.52194999999
# Too much error!
# Episode * 884 * Avg Reward is ==> 65056.48409999999
# Too much error!
# Episode * 885 * Avg Reward is ==> 65056.562474999984
# Too much error!
# Episode * 886 * Avg Reward is ==> 65055.69635
# Too much error!
# Episode * 887 * Avg Reward is ==> 65055.09754999999
# Done!
# Episode * 888 * Avg Reward is ==> 92556.510675
# Too much error!
# Episode * 889 * Avg Reward is ==> 92556.43229999999
# Too much error!
# Episode * 890 * Avg Reward is ==> 65053.38205
# Too much error!
# Episode * 891 * Avg Reward is ==> 37550.237825
# Too much error!
# Episode * 892 * Avg Reward is ==> 37548.032375
# Too much error!
# Episode * 893 * Avg Reward is ==> 10045.008749999999
# Too much error!
# Episode * 894 * Avg Reward is ==> -17458.39595
# Too much error!
# Episode * 895 * Avg Reward is ==> -17459.002774999997
# Too much error!
# Episode * 896 * Avg Reward is ==> -17457.876774999997
# Too much error!
# Episode * 897 * Avg Reward is ==> -17456.750775
# Done!
# Episode * 898 * Avg Reward is ==> -17456.73725
# Done!
# Episode * 899 * Avg Reward is ==> 10049.706825000001
# Too much error!
# Episode * 900 * Avg Reward is ==> 10056.755625000002
# Too much error!
# Episode * 901 * Avg Reward is ==> 10056.186375000001
# Too much error!
# Episode * 902 * Avg Reward is ==> -17446.399924999998
# Too much error!
# Episode * 903 * Avg Reward is ==> -17447.580599999998
# Too much error!
# Episode * 904 * Avg Reward is ==> -17447.580599999994
# Done!
# Episode * 905 * Avg Reward is ==> 10055.220750000008
# Too much error!
# Episode * 906 * Avg Reward is ==> 10055.145675000007
# Too much error!
# Episode * 907 * Avg Reward is ==> 10053.23870000001
# Too much error!
# Episode * 908 * Avg Reward is ==> 10053.238700000005
# Too much error!
# Episode * 909 * Avg Reward is ==> 10053.23870000001
# Too much error!
# Episode * 910 * Avg Reward is ==> 10053.264200000005
# Too much error!
# Episode * 911 * Avg Reward is ==> 10053.348000000009
# Too much error!
# Episode * 912 * Avg Reward is ==> 10053.348000000004
# Too much error!
# Episode * 913 * Avg Reward is ==> 10053.348000000002
# Done!
# Episode * 914 * Avg Reward is ==> 37555.222250000006
# Done!
# Episode * 915 * Avg Reward is ==> 65054.72409999999
# Done!
# Episode * 916 * Avg Reward is ==> 92557.2261
# Too much error!
# Episode * 917 * Avg Reward is ==> 92561.96197500001
# Too much error!
# Episode * 918 * Avg Reward is ==> 92561.96197500001
# Too much error!
# Episode * 919 * Avg Reward is ==> 92561.961975
# Too much error!
# Episode * 920 * Avg Reward is ==> 92561.96197500001
# Too much error!
# Episode * 921 * Avg Reward is ==> 92557.90174999999
# Too much error!
# Episode * 922 * Avg Reward is ==> 92557.81755
# Done!
# Episode * 923 * Avg Reward is ==> 120060.93627499996
# Done!
# Episode * 924 * Avg Reward is ==> 147563.98775
# Too much error!
# Episode * 925 * Avg Reward is ==> 147563.909375
# Too much error!
# Episode * 926 * Avg Reward is ==> 147563.914425
# Too much error!
# Episode * 927 * Avg Reward is ==> 147563.92964999998
# Too much error!
# Episode * 928 * Avg Reward is ==> 120062.51147499999
# Too much error!
# Episode * 929 * Avg Reward is ==> 120062.51147499999
# Too much error!
# Episode * 930 * Avg Reward is ==> 120062.51147499999
# Too much error!
# Episode * 931 * Avg Reward is ==> 120062.51147499998
# Too much error!
# Episode * 932 * Avg Reward is ==> 120062.48079999999
# Too much error!
# Episode * 933 * Avg Reward is ==> 120062.48079999998
# Too much error!
# Episode * 934 * Avg Reward is ==> 120062.42387499998
# Too much error!
# Episode * 935 * Avg Reward is ==> 120062.35627499995
# Too much error!
# Episode * 936 * Avg Reward is ==> 120061.23027499998
# Done!
# Episode * 937 * Avg Reward is ==> 147563.23499999996
# Done!
# Episode * 938 * Avg Reward is ==> 147563.114175
# Too much error!
# Episode * 939 * Avg Reward is ==> 120055.543975
# Too much error!
# Episode * 940 * Avg Reward is ==> 120048.495175
# Too much error!
# Episode * 941 * Avg Reward is ==> 120048.495175
# Too much error!
# Episode * 942 * Avg Reward is ==> 120048.5521
# Too much error!
# Episode * 943 * Avg Reward is ==> 120048.5521
# Too much error!
# Episode * 944 * Avg Reward is ==> 120048.55209999997
# Too much error!
# Episode * 945 * Avg Reward is ==> 92551.46484999999
# Too much error!
# Episode * 946 * Avg Reward is ==> 92552.01814999999
# Done!
# Episode * 947 * Avg Reward is ==> 120054.949375
# Too much error!
# Episode * 948 * Avg Reward is ==> 120056.85634999997
# Episode * 949 * Avg Reward is ==> 122568.86132499999
# Done!
# Episode * 950 * Avg Reward is ==> 150071.85945000002
# Too much error!
# Episode * 951 * Avg Reward is ==> 150073.67165
# Too much error!
# Episode * 952 * Avg Reward is ==> 150075.1392
# Too much error!
# Episode * 953 * Avg Reward is ==> 150075.14932499998
# Too much error!
# Episode * 954 * Avg Reward is ==> 122572.77085000002
# Too much error!
# Episode * 955 * Avg Reward is ==> 95069.799625
# Too much error!
# Episode * 956 * Avg Reward is ==> 67567.28749999999
# Too much error!
# Episode * 957 * Avg Reward is ==> 67562.514875
# Too much error!
# Episode * 958 * Avg Reward is ==> 67562.514875
# Too much error!
# Episode * 959 * Avg Reward is ==> 67562.514875
# Too much error!
# Episode * 960 * Avg Reward is ==> 67563.267425
# Too much error!
# Episode * 961 * Avg Reward is ==> 67563.267425
# Too much error!
# Episode * 962 * Avg Reward is ==> 67563.27249999999
# Too much error!
# Episode * 963 * Avg Reward is ==> 40060.128275
# Too much error!
# Episode * 964 * Avg Reward is ==> 12557.051300000001
# Too much error!
# Episode * 965 * Avg Reward is ==> 12558.222800000001
# Too much error!
# Episode * 966 * Avg Reward is ==> 12558.21775
# Too much error!
# Episode * 967 * Avg Reward is ==> 12558.202525
# Done!
# Episode * 968 * Avg Reward is ==> 40061.212875
# Done!
# Episode * 969 * Avg Reward is ==> 67571.250875
# Done!
# Episode * 970 * Avg Reward is ==> 95074.27449999998
# Done!
# Episode * 971 * Avg Reward is ==> 122577.459375
# Too much error!
# Episode * 972 * Avg Reward is ==> 122577.5541
# Too much error!
# Episode * 973 * Avg Reward is ==> 122577.55410000002
# Too much error!
# Episode * 974 * Avg Reward is ==> 122577.5541
# Too much error!
# Episode * 975 * Avg Reward is ==> 122577.55410000002
# Too much error!
# Episode * 976 * Avg Reward is ==> 122580.91772499999
# Too much error!
# Episode * 977 * Avg Reward is ==> 95077.78700000001
# Too much error!
# Episode * 978 * Avg Reward is ==> 67574.75007499999
# Too much error!
# Episode * 979 * Avg Reward is ==> 67574.6771
# Too much error!
# Episode * 980 * Avg Reward is ==> 67574.6771
# Done!
# Episode * 981 * Avg Reward is ==> 95083.29669999999
# Done!
# Episode * 982 * Avg Reward is ==> 122586.290025
# Done!
# Episode * 983 * Avg Reward is ==> 150089.72352499998
# Done!
# Episode * 984 * Avg Reward is ==> 177592.72062500002
# Too much error!
# Episode * 985 * Avg Reward is ==> 177588.19640000002
# Too much error!
# Episode * 986 * Avg Reward is ==> 177587.612425
# Too much error!
# Episode * 987 * Avg Reward is ==> 150084.6812
# Too much error!
# Episode * 988 * Avg Reward is ==> 150082.774225
# Too much error!
# Episode * 989 * Avg Reward is ==> 147570.76925
# Too much error!
# Episode * 990 * Avg Reward is ==> 120067.74562500001
# Too much error!
# Episode * 991 * Avg Reward is ==> 120065.84962499999
# Too much error!
# Episode * 992 * Avg Reward is ==> 120064.382075
# Done!
# Episode * 993 * Avg Reward is ==> 147567.408875
# Done!
# Episode * 994 * Avg Reward is ==> 175072.02935
# Too much error!
# Episode * 995 * Avg Reward is ==> 175072.54482500002
# Too much error!
# Episode * 996 * Avg Reward is ==> 175072.612425
# Done!
# Episode * 997 * Avg Reward is ==> 202575.758225
# Episode * 998 * Avg Reward is ==> 205087.7632
# Done!
# Episode * 999 * Avg Reward is ==> 232590.8268

# %%
## run simulation
prev_state= env.reset()
state_array = []
action_array = []
while True:
    # env.render()
    tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)
    action = policy(tf_prev_state, ou_noise)
    state, reward, done, info = env.step(action[0])
    state_array.append(env.position)
    action_array.append(action)
    if done:
        break
    prev_state = state

state_array = np.array(state_array)
action_array = np.array(action_array)
plt.plot(state_array[:,0], state_array[:,1], label='State')
plt.plot(trajectory[:,0], trajectory[:,1], label='Trajectory')
print(state_array[-1, :])
print(env.steps)
plt.legend()
plt.show()

# plot action
plt.plot(action_array.reshape(len(action_array), 2))
plt.legend()
plt.show()

print(len(action_array))
# Out:
# Done!
# [ 1.11844522 -0.06366319 -0.01343802  0.14189302]
# 531
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 531
