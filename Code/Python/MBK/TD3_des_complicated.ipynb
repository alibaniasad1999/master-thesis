# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 1024)
        self.l2 = nn.Linear(1024, 1024)
        self.l3 = nn.Linear(1024, action_dim)

        self.max_action = max_action

    def forward(self, state):
        a = F.tanh(self.l1(state))
        a = F.tanh(self.l2(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 1024)
        self.l2 = nn.Linear(1024, 1024)
        self.l3 = nn.Linear(1024, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 1024)
        self.l5 = nn.Linear(1024, 1024)
        self.l6 = nn.Linear(1024, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=1e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=1e-4)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
	eval_env.reset(seed=seed
    )

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
import gym
class MassSpringDamperEnv(gym.Env):
    def __init__(self):
        super(MassSpringDamperEnv, self).__init__()

        # System parameters
        self.m = 1.0  # Mass (kg)
        self.k = 1.0  # Spring constant (N/m)
        self.c = 0.1  # Damping coefficient (N*s/m)

        # Simulation parameters
        self.dt = 0.01  # Time step (s)
        self.max_steps = 1000  # Maximum simulation steps
        self.current_step = 0

        # State and action spaces
        self.action_space = gym.spaces.Box(low=-20.0, high=20.0, shape=(1,))
        self.observation_space = gym.spaces.Box(low=-100, high=100, shape=(2,))
        self.desired = None

        # Initial state
        self.state = None

    def reset(self,
              *,
              seed: 5 = None,
              return_info: bool = False,
              options: 6 = None):
        # Reset the environment to an initial state
        self.desired = np.random.uniform(low=-10, high=10, size=(1,))
        self.state = np.random.uniform(low=-10, high=10, size=(2,))
        self.current_step = 0
        return np.concatenate([np.array([self.state[0] - self.desired.item()]), np.array([self.state[1]])])

    def step(self, action):
        # Apply control action and simulate one time step using Euler integration
        force = action[0]
        position, velocity = self.state

        acceleration = (force - self.c * velocity - self.k * position) / self.m
        velocity += acceleration * self.dt
        position += velocity * self.dt

        self.state = np.array([position, velocity])
        # add noise to state
        # self.state += np.random.uniform(low=-0.1, high=0.1, size=(2,))
        self.current_step += 1

        # Calculate the reward (e.g., minimize position error)
        reward = -abs(position - self.desired.item())

        # Check if the episode is done
        done = self.current_step >= self.max_steps

        return np.concatenate([np.array([self.state[0] - self.desired.item()]), np.array([self.state[1]])]), reward, done, {}

    def render(self, mode='human'):
        pass

    def close(self):
        pass


# Create the custom mass-spring-damper environment
env = MassSpringDamperEnv()

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "MBK"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(5e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(1e5)
DEFAULT_EXPL_NOISE = 0.01
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.01
DEFAULT_NOISE_CLIP = 0.1
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ}
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False
episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# ---------------------------------------
# Policy: TD3, Env: MBK, Seed: 0
# ---------------------------------------
# ---------------------------------------
# Evaluation over 10 episodes: -11482.930
# ---------------------------------------

# %%
for t in range(int(DEFAULT_MAX_TIMESTEPS)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action)
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done:
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# Total T: 1000 Episode Num: 1 Episode T: 1000 Reward: -3341.327
# Total T: 2000 Episode Num: 2 Episode T: 1000 Reward: -7557.507
# Total T: 3000 Episode Num: 3 Episode T: 1000 Reward: -8235.336
# Total T: 4000 Episode Num: 4 Episode T: 1000 Reward: -3222.970
# Total T: 5000 Episode Num: 5 Episode T: 1000 Reward: -5301.464
# ---------------------------------------
# Evaluation over 10 episodes: -12328.380
# ---------------------------------------
# Total T: 5001 Episode Num: 6 Episode T: 1 Reward: -21.701
# Total T: 6001 Episode Num: 7 Episode T: 1000 Reward: -7805.784
# Total T: 7001 Episode Num: 8 Episode T: 1000 Reward: -14571.456
# Total T: 8001 Episode Num: 9 Episode T: 1000 Reward: -5361.163
# Total T: 9001 Episode Num: 10 Episode T: 1000 Reward: -7247.210
# ---------------------------------------
# Evaluation over 10 episodes: -3314.596
# ---------------------------------------
# Total T: 10001 Episode Num: 11 Episode T: 1000 Reward: -885.073
# Total T: 11001 Episode Num: 12 Episode T: 1000 Reward: -1185.001
# Total T: 12001 Episode Num: 13 Episode T: 1000 Reward: -1358.170
# Total T: 13001 Episode Num: 14 Episode T: 1000 Reward: -432.922
# Total T: 14001 Episode Num: 15 Episode T: 1000 Reward: -411.113
# ---------------------------------------
# Evaluation over 10 episodes: -594.401
# ---------------------------------------
# Total T: 15001 Episode Num: 16 Episode T: 1000 Reward: -701.859
# Total T: 16001 Episode Num: 17 Episode T: 1000 Reward: -644.124
# Total T: 17001 Episode Num: 18 Episode T: 1000 Reward: -114.322
# Total T: 18001 Episode Num: 19 Episode T: 1000 Reward: -328.040
# Total T: 19001 Episode Num: 20 Episode T: 1000 Reward: -908.581
# ---------------------------------------
# Evaluation over 10 episodes: -715.032
# ---------------------------------------
# Total T: 20001 Episode Num: 21 Episode T: 1000 Reward: -1516.933
# Total T: 21001 Episode Num: 22 Episode T: 1000 Reward: -1090.738
# Total T: 22001 Episode Num: 23 Episode T: 1000 Reward: -739.627
# Total T: 23001 Episode Num: 24 Episode T: 1000 Reward: -1074.778
# Total T: 24001 Episode Num: 25 Episode T: 1000 Reward: -305.269
# ---------------------------------------
# Evaluation over 10 episodes: -639.058
# ---------------------------------------
# Total T: 25001 Episode Num: 26 Episode T: 1000 Reward: -1119.421
# Total T: 26001 Episode Num: 27 Episode T: 1000 Reward: -1193.243
# Total T: 27001 Episode Num: 28 Episode T: 1000 Reward: -534.704
# Total T: 28001 Episode Num: 29 Episode T: 1000 Reward: -494.256
# Total T: 29001 Episode Num: 30 Episode T: 1000 Reward: -542.870
# ---------------------------------------
# Evaluation over 10 episodes: -636.861
# ---------------------------------------
# Total T: 30001 Episode Num: 31 Episode T: 1000 Reward: -1655.679
# Total T: 31001 Episode Num: 32 Episode T: 1000 Reward: -1629.387
# Total T: 32001 Episode Num: 33 Episode T: 1000 Reward: -2143.320
# Total T: 33001 Episode Num: 34 Episode T: 1000 Reward: -451.485
# Total T: 34001 Episode Num: 35 Episode T: 1000 Reward: -942.359
# ---------------------------------------
# Evaluation over 10 episodes: -1695.985
# ---------------------------------------
# Total T: 35001 Episode Num: 36 Episode T: 1000 Reward: -1286.553
# Total T: 36001 Episode Num: 37 Episode T: 1000 Reward: -1544.192
# Total T: 37001 Episode Num: 38 Episode T: 1000 Reward: -2003.861
# Total T: 38001 Episode Num: 39 Episode T: 1000 Reward: -1533.564
# Total T: 39001 Episode Num: 40 Episode T: 1000 Reward: -1879.554
# ---------------------------------------
# Evaluation over 10 episodes: -1436.794
# ---------------------------------------
# Total T: 40001 Episode Num: 41 Episode T: 1000 Reward: -1441.021
# Total T: 41001 Episode Num: 42 Episode T: 1000 Reward: -1157.972
# Total T: 42001 Episode Num: 43 Episode T: 1000 Reward: -1365.601
# Total T: 43001 Episode Num: 44 Episode T: 1000 Reward: -930.787
# Total T: 44001 Episode Num: 45 Episode T: 1000 Reward: -573.099
# ---------------------------------------
# Evaluation over 10 episodes: -590.703
# ---------------------------------------
# Total T: 45001 Episode Num: 46 Episode T: 1000 Reward: -1380.576
# Total T: 46001 Episode Num: 47 Episode T: 1000 Reward: -1573.760
# Total T: 47001 Episode Num: 48 Episode T: 1000 Reward: -133.238
# Total T: 48001 Episode Num: 49 Episode T: 1000 Reward: -1479.249
# Total T: 49001 Episode Num: 50 Episode T: 1000 Reward: -181.479
# ---------------------------------------
# Evaluation over 10 episodes: -962.790
# ---------------------------------------
# Total T: 50001 Episode Num: 51 Episode T: 1000 Reward: -1454.518
# Total T: 51001 Episode Num: 52 Episode T: 1000 Reward: -415.873
# Total T: 52001 Episode Num: 53 Episode T: 1000 Reward: -313.279
# Total T: 53001 Episode Num: 54 Episode T: 1000 Reward: -315.681
# Total T: 54001 Episode Num: 55 Episode T: 1000 Reward: -335.341
# ---------------------------------------
# Evaluation over 10 episodes: -973.225
# ---------------------------------------
# Total T: 55001 Episode Num: 56 Episode T: 1000 Reward: -496.692
# Total T: 56001 Episode Num: 57 Episode T: 1000 Reward: -214.595
# Total T: 57001 Episode Num: 58 Episode T: 1000 Reward: -946.004
# Total T: 58001 Episode Num: 59 Episode T: 1000 Reward: -671.763
# Total T: 59001 Episode Num: 60 Episode T: 1000 Reward: -690.922
# ---------------------------------------
# Evaluation over 10 episodes: -733.745
# ---------------------------------------
# Total T: 60001 Episode Num: 61 Episode T: 1000 Reward: -833.688
# Total T: 61001 Episode Num: 62 Episode T: 1000 Reward: -566.238
# Total T: 62001 Episode Num: 63 Episode T: 1000 Reward: -341.842
# Total T: 63001 Episode Num: 64 Episode T: 1000 Reward: -694.521
# Total T: 64001 Episode Num: 65 Episode T: 1000 Reward: -760.148
# ---------------------------------------
# Evaluation over 10 episodes: -762.032
# ---------------------------------------
# Total T: 65001 Episode Num: 66 Episode T: 1000 Reward: -431.326
# Total T: 66001 Episode Num: 67 Episode T: 1000 Reward: -957.258
# Total T: 67001 Episode Num: 68 Episode T: 1000 Reward: -966.974
# Total T: 68001 Episode Num: 69 Episode T: 1000 Reward: -1106.073
# Total T: 69001 Episode Num: 70 Episode T: 1000 Reward: -219.554
# ---------------------------------------
# Evaluation over 10 episodes: -767.801
# ---------------------------------------
# Total T: 70001 Episode Num: 71 Episode T: 1000 Reward: -1344.372
# Total T: 71001 Episode Num: 72 Episode T: 1000 Reward: -432.454
# Total T: 72001 Episode Num: 73 Episode T: 1000 Reward: -272.134
# Total T: 73001 Episode Num: 74 Episode T: 1000 Reward: -352.022
# Total T: 74001 Episode Num: 75 Episode T: 1000 Reward: -994.802
# ---------------------------------------
# Evaluation over 10 episodes: -810.602
# ---------------------------------------
# Total T: 75001 Episode Num: 76 Episode T: 1000 Reward: -103.937
# Total T: 76001 Episode Num: 77 Episode T: 1000 Reward: -165.724
# Total T: 77001 Episode Num: 78 Episode T: 1000 Reward: -582.538
# Total T: 78001 Episode Num: 79 Episode T: 1000 Reward: -497.040
# Total T: 79001 Episode Num: 80 Episode T: 1000 Reward: -178.550
# ---------------------------------------
# Evaluation over 10 episodes: -575.596
# ---------------------------------------
# Total T: 80001 Episode Num: 81 Episode T: 1000 Reward: -253.952
# Total T: 81001 Episode Num: 82 Episode T: 1000 Reward: -950.822
# Total T: 82001 Episode Num: 83 Episode T: 1000 Reward: -210.858
# Total T: 83001 Episode Num: 84 Episode T: 1000 Reward: -419.098
# Total T: 84001 Episode Num: 85 Episode T: 1000 Reward: -551.564
# ---------------------------------------
# Evaluation over 10 episodes: -416.779
# ---------------------------------------
# Total T: 85001 Episode Num: 86 Episode T: 1000 Reward: -1735.808
# Total T: 86001 Episode Num: 87 Episode T: 1000 Reward: -925.044
# Total T: 87001 Episode Num: 88 Episode T: 1000 Reward: -549.511
# Total T: 88001 Episode Num: 89 Episode T: 1000 Reward: -78.933
# Total T: 89001 Episode Num: 90 Episode T: 1000 Reward: -728.795
# ---------------------------------------
# Evaluation over 10 episodes: -686.249
# ---------------------------------------
# Total T: 90001 Episode Num: 91 Episode T: 1000 Reward: -1610.636
# Total T: 91001 Episode Num: 92 Episode T: 1000 Reward: -527.205
# Total T: 92001 Episode Num: 93 Episode T: 1000 Reward: -506.066
# Total T: 93001 Episode Num: 94 Episode T: 1000 Reward: -1778.521
# Total T: 94001 Episode Num: 95 Episode T: 1000 Reward: -132.942
# ---------------------------------------
# Evaluation over 10 episodes: -428.670
# ---------------------------------------
# Total T: 95001 Episode Num: 96 Episode T: 1000 Reward: -567.123
# Total T: 96001 Episode Num: 97 Episode T: 1000 Reward: -76.635
# Total T: 97001 Episode Num: 98 Episode T: 1000 Reward: -48.180
# Total T: 98001 Episode Num: 99 Episode T: 1000 Reward: -68.749
# Total T: 99001 Episode Num: 100 Episode T: 1000 Reward: -545.009
# ---------------------------------------
# Evaluation over 10 episodes: -430.250
# ---------------------------------------

# %%
import matplotlib.pyplot as plt

evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
# show results for one episode with policy
state, done = env.reset(), False
episode_reward = 0
state_array = []
action_array = []
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    state_array.append(state)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array + np.array([env.desired.item(), 0]))
plt.plot(np.linspace(0, 10, num=len(state_array)),np.ones(len(state_array))*env.desired)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity", "desired"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
# Out:
# Episode Reward: -108.516

# %%
# show results for one episode with policy
state, done = env.reset(), False
episode_reward = 0
state_array = []
action_array = []
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    state_array.append(state)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
# Out:
# Episode Reward: -222.463

# %%
# show results for one episode with policy
state, done = env.reset(), False
env.state = np.array([0, 0])
state = env.state
episode_reward = 0
state_array = []
action_array = []
desired_array = []
counter = 0
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    env.desired = 3*np.sin(counter/100)
    counter += 1
    # if counter > 300:
      # env.desired = np.array([0])
    desired_array.append(env.desired)
    state_array.append(state + env.desired)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array)
plt.plot(np.linspace(0, 10, num=len(state_array)),desired_array)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity", "desired"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
# Out:
# Episode Reward: -602.596

# %%
# show results for one episode with policy
state, done = env.reset(), False
env.state = np.array([0, 0])
state = env.state
episode_reward = 0
state_array = []
action_array = []
desired_array = []
counter = 0
while not done:
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    env.desired = np.array([counter/100])
    counter += 1
    # if counter > 300:
      # env.desired = np.array([0])
    desired_array.append(env.desired)
    state_array.append(state + env.desired)
    action_array.append(action)
    episode_reward += reward
    env.render()
print(f"Episode Reward: {episode_reward:.3f}")

plt.plot(np.linspace(0, 10, num=len(state_array)),state_array)
plt.plot(np.linspace(0, 10, num=len(state_array)),desired_array)
plt.xlabel("Time (sec)")
plt.ylabel("State")
plt.legend(["Position", "Velocity", "desired"])
plt.show()

plt.plot(np.linspace(0, 10, num=len(state_array)), action_array)
plt.xlabel("Time (sec)")
plt.ylabel("action (N)")
plt.show()
# Out:
# Episode Reward: -398.073
