# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
plt.plot(trajectory[:,0], trajectory[:,1])

# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 256)
        self.l4 = nn.Linear(256, action_dim)

        self.max_action = max_action

    def forward(self, state):
        a = F.tanh(self.l1(state))
        a = F.tanh(self.l2(a))
        a = F.tanh(self.l3(a))
        return self.max_action * torch.tanh(self.l4(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=1e-4)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=1e-4)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
	eval_env.reset(seed=seed
    )

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
# three body problem env
import gym
from gym import spaces
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-150, high=0, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.render_logic = False
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        force = action[0] * env.state[2:] + action[1] * env.state[:2]
        a_x = force[0]
        a_y = force[1]

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y

        x = x + xdot*self.dt
        y = y + ydot*self.dt
        
        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        # plot position
        if env.render_logic:
            plt.plot(x, y, 'ro')
            plt.plot(self.trajectory[:,0], self.trajectory[:,1])
            plt.show()

        reward = 1 - np.linalg.norm(self.position - self.trajectory[self.steps], axis=0) + self.steps
        done = self.steps >= self.max_steps
        if np.linalg.norm(self.position[0:2] - self.trajectory[-1, 0:2]) < 0.01:
            done = True
            reward = 1000
        if self.steps > 1000:
            done = True
            reward = -1000
        if np.linalg.norm(self.state) > 2:
            done = True
            reward = -1000

        # print(self.state, reward, done, self.position)
        return 10000*self.state, reward, done, self.position

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]
    
    def reset(self,
              *,
              seed: 5 = None,
              return_info: bool = False,
              options: 6 = None):
        self.position = self.trajectory[0]   
        self.steps = 0
        self.position2state()
        return 10000*self.state
    
    def render(self):
        pass

    def close(self):
        pass

    
env = three_body_env(trajectory)

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "TBP"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(5e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(1e5)
DEFAULT_EXPL_NOISE = 0.5
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.5
DEFAULT_NOISE_CLIP = 0.2
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ}
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False

episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# ---------------------------------------
# Policy: TD3, Env: TBP, Seed: 0
# ---------------------------------------
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# ---------------------------------------
# Evaluation over 10 episodes: -915.974
# ---------------------------------------

# %%
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]
for t in range(int(DEFAULT_MAX_TIMESTEPS)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action)
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done:
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# ---------------------------------------
# Evaluation over 10 episodes: -915.974
# ---------------------------------------
# Oooopss
# Total T: 1 Episode Num: 1 Episode T: 1 Reward: -1000.000
# Oooopss
# Total T: 16 Episode Num: 2 Episode T: 15 Reward: -986.574
# Oooopss
# Total T: 51 Episode Num: 3 Episode T: 35 Reward: -968.523
# Oooopss
# Total T: 76 Episode Num: 4 Episode T: 25 Reward: -977.042
# Oooopss
# Total T: 126 Episode Num: 5 Episode T: 50 Reward: -954.958
# Oooopss
# Total T: 173 Episode Num: 6 Episode T: 47 Reward: -958.199
# Oooopss
# Total T: 201 Episode Num: 7 Episode T: 28 Reward: -974.776
# Oooopss
# Total T: 312 Episode Num: 8 Episode T: 111 Reward: -911.566
# Oooopss
# Total T: 370 Episode Num: 9 Episode T: 58 Reward: -948.827
# Oooopss
# Total T: 388 Episode Num: 10 Episode T: 18 Reward: -983.640
# Oooopss
# Total T: 428 Episode Num: 11 Episode T: 40 Reward: -962.786
# Oooopss
# Total T: 506 Episode Num: 12 Episode T: 78 Reward: -936.732
# Oooopss
# Total T: 530 Episode Num: 13 Episode T: 24 Reward: -977.859
# Oooopss
# Total T: 544 Episode Num: 14 Episode T: 14 Reward: -987.241
# Oooopss
# Total T: 563 Episode Num: 15 Episode T: 19 Reward: -982.837
# Oooopss
# Total T: 611 Episode Num: 16 Episode T: 48 Reward: -958.274
# Oooopss
# Total T: 654 Episode Num: 17 Episode T: 43 Reward: -960.881
# Oooopss
# Total T: 678 Episode Num: 18 Episode T: 24 Reward: -979.236
# Oooopss
# Total T: 739 Episode Num: 19 Episode T: 61 Reward: -949.034
# Oooopss
# Total T: 831 Episode Num: 20 Episode T: 92 Reward: -924.122
# Oooopss
# Total T: 892 Episode Num: 21 Episode T: 61 Reward: -948.174
# Oooopss
# Total T: 1005 Episode Num: 22 Episode T: 113 Reward: -911.686
# Oooopss
# Total T: 1030 Episode Num: 23 Episode T: 25 Reward: -977.309
# Oooopss
# Total T: 1121 Episode Num: 24 Episode T: 91 Reward: -928.356
# Oooopss
# Total T: 1159 Episode Num: 25 Episode T: 38 Reward: -966.665
# Oooopss
# Total T: 1196 Episode Num: 26 Episode T: 37 Reward: -967.785
# Oooopss
# Total T: 1211 Episode Num: 27 Episode T: 15 Reward: -986.581
# Oooopss
# Total T: 1252 Episode Num: 28 Episode T: 41 Reward: -964.365
# Oooopss
# Total T: 1270 Episode Num: 29 Episode T: 18 Reward: -983.802
# Oooopss
# Total T: 1303 Episode Num: 30 Episode T: 33 Reward: -969.763
# Oooopss
# Total T: 1341 Episode Num: 31 Episode T: 38 Reward: -967.850
# Oooopss
# Total T: 1394 Episode Num: 32 Episode T: 53 Reward: -955.147
# Oooopss
# Total T: 1431 Episode Num: 33 Episode T: 37 Reward: -966.911
# Oooopss
# Total T: 1463 Episode Num: 34 Episode T: 32 Reward: -970.115
# Oooopss
# Total T: 1473 Episode Num: 35 Episode T: 10 Reward: -991.294
# Oooopss
# Total T: 1510 Episode Num: 36 Episode T: 37 Reward: -966.104
# Oooopss
# Total T: 1540 Episode Num: 37 Episode T: 30 Reward: -973.066
# Oooopss
# Total T: 1595 Episode Num: 38 Episode T: 55 Reward: -953.194
# Oooopss
# Total T: 1649 Episode Num: 39 Episode T: 54 Reward: -952.420
# Oooopss
# Total T: 1748 Episode Num: 40 Episode T: 99 Reward: -917.081
# Oooopss
# Total T: 1782 Episode Num: 41 Episode T: 34 Reward: -970.033
# Oooopss
# Total T: 1824 Episode Num: 42 Episode T: 42 Reward: -963.485
# Oooopss
# Total T: 1869 Episode Num: 43 Episode T: 45 Reward: -961.169
# Oooopss
# Total T: 1927 Episode Num: 44 Episode T: 58 Reward: -950.185
# Oooopss
# Total T: 2009 Episode Num: 45 Episode T: 82 Reward: -930.720
# Oooopss
# Total T: 2036 Episode Num: 46 Episode T: 27 Reward: -975.361
# Oooopss
# Total T: 2083 Episode Num: 47 Episode T: 47 Reward: -959.647
# Oooopss
# Total T: 2145 Episode Num: 48 Episode T: 62 Reward: -947.548
# Oooopss
# Total T: 2210 Episode Num: 49 Episode T: 65 Reward: -942.224
# Oooopss
# Total T: 2249 Episode Num: 50 Episode T: 39 Reward: -964.916
# Oooopss
# Total T: 2281 Episode Num: 51 Episode T: 32 Reward: -970.643
# Oooopss
# Total T: 2310 Episode Num: 52 Episode T: 29 Reward: -974.095
# Oooopss
# Total T: 2372 Episode Num: 53 Episode T: 62 Reward: -945.825
# Oooopss
# Total T: 2399 Episode Num: 54 Episode T: 27 Reward: -975.822
# Oooopss
# Total T: 2428 Episode Num: 55 Episode T: 29 Reward: -973.183
# Oooopss
# Total T: 2496 Episode Num: 56 Episode T: 68 Reward: -942.157
# Oooopss
# Total T: 2529 Episode Num: 57 Episode T: 33 Reward: -970.488
# Oooopss
# Total T: 2555 Episode Num: 58 Episode T: 26 Reward: -976.074
# Oooopss
# Total T: 2585 Episode Num: 59 Episode T: 30 Reward: -972.988
# Oooopss
# Total T: 2596 Episode Num: 60 Episode T: 11 Reward: -990.324
# Oooopss
# Total T: 2607 Episode Num: 61 Episode T: 11 Reward: -990.449
# Oooopss
# Total T: 2677 Episode Num: 62 Episode T: 70 Reward: -941.124
# Oooopss
# Total T: 2737 Episode Num: 63 Episode T: 60 Reward: -946.971
# Oooopss
# Total T: 2766 Episode Num: 64 Episode T: 29 Reward: -973.784
# Oooopss
# Total T: 2831 Episode Num: 65 Episode T: 65 Reward: -943.539
# Oooopss
# Total T: 2853 Episode Num: 66 Episode T: 22 Reward: -980.204
# Oooopss
# Total T: 2905 Episode Num: 67 Episode T: 52 Reward: -954.699
# Oooopss
# Total T: 2940 Episode Num: 68 Episode T: 35 Reward: -967.894
# Oooopss
# Total T: 2973 Episode Num: 69 Episode T: 33 Reward: -971.195
# Oooopss
# Total T: 3007 Episode Num: 70 Episode T: 34 Reward: -969.774
# Oooopss
# Total T: 3026 Episode Num: 71 Episode T: 19 Reward: -982.629
# Oooopss
# Total T: 3058 Episode Num: 72 Episode T: 32 Reward: -971.068
# Oooopss
# Total T: 3139 Episode Num: 73 Episode T: 81 Reward: -936.076
# Oooopss
# Total T: 3167 Episode Num: 74 Episode T: 28 Reward: -974.553
# Oooopss
# Total T: 3227 Episode Num: 75 Episode T: 60 Reward: -949.583
# Oooopss
# Total T: 3255 Episode Num: 76 Episode T: 28 Reward: -974.197
# Oooopss
# Total T: 3344 Episode Num: 77 Episode T: 89 Reward: -928.729
# Oooopss
# Total T: 3366 Episode Num: 78 Episode T: 22 Reward: -980.098
# Oooopss
# Total T: 3416 Episode Num: 79 Episode T: 50 Reward: -957.223
# Oooopss
# Total T: 3468 Episode Num: 80 Episode T: 52 Reward: -953.399
# Oooopss
# Total T: 3490 Episode Num: 81 Episode T: 22 Reward: -980.557
# Oooopss
# Total T: 3529 Episode Num: 82 Episode T: 39 Reward: -965.858
# Oooopss
# Total T: 3594 Episode Num: 83 Episode T: 65 Reward: -944.990
# Oooopss
# Total T: 3602 Episode Num: 84 Episode T: 8 Reward: -993.200
# Oooopss
# Total T: 3684 Episode Num: 85 Episode T: 82 Reward: -930.315
# Oooopss
# Total T: 3718 Episode Num: 86 Episode T: 34 Reward: -968.747
# Oooopss
# Total T: 3744 Episode Num: 87 Episode T: 26 Reward: -976.557
# Oooopss
# Total T: 3771 Episode Num: 88 Episode T: 27 Reward: -975.918
# Oooopss
# Total T: 3789 Episode Num: 89 Episode T: 18 Reward: -983.784
# Oooopss
# Total T: 3813 Episode Num: 90 Episode T: 24 Reward: -978.054
# Oooopss
# Total T: 3851 Episode Num: 91 Episode T: 38 Reward: -965.678
# Oooopss
# Total T: 3864 Episode Num: 92 Episode T: 13 Reward: -988.491
# Oooopss
# Total T: 3905 Episode Num: 93 Episode T: 41 Reward: -963.318
# Oooopss
# Total T: 3949 Episode Num: 94 Episode T: 44 Reward: -960.928
# Oooopss
# Total T: 3982 Episode Num: 95 Episode T: 33 Reward: -971.389
# Oooopss
# Total T: 4005 Episode Num: 96 Episode T: 23 Reward: -979.248
# Oooopss
# Total T: 4100 Episode Num: 97 Episode T: 95 Reward: -925.416
# Oooopss
# Total T: 4169 Episode Num: 98 Episode T: 69 Reward: -942.626
# Oooopss
# Total T: 4191 Episode Num: 99 Episode T: 22 Reward: -979.859
# Oooopss
# Total T: 4241 Episode Num: 100 Episode T: 50 Reward: -957.206
# Oooopss
# Total T: 4269 Episode Num: 101 Episode T: 28 Reward: -974.274
# Oooopss
# Total T: 4317 Episode Num: 102 Episode T: 48 Reward: -956.445
# Oooopss
# Total T: 4345 Episode Num: 103 Episode T: 28 Reward: -975.067
# Oooopss
# Total T: 4361 Episode Num: 104 Episode T: 16 Reward: -985.373
# Oooopss
# Total T: 4406 Episode Num: 105 Episode T: 45 Reward: -960.211
# Oooopss
# Total T: 4447 Episode Num: 106 Episode T: 41 Reward: -964.262
# Oooopss
# Total T: 4522 Episode Num: 107 Episode T: 75 Reward: -939.734
# Oooopss
# Total T: 4544 Episode Num: 108 Episode T: 22 Reward: -980.553
# Oooopss
# Total T: 4643 Episode Num: 109 Episode T: 99 Reward: -914.376
# Oooopss
# Total T: 4661 Episode Num: 110 Episode T: 18 Reward: -983.540
# Oooopss
# Total T: 4682 Episode Num: 111 Episode T: 21 Reward: -980.834
# Oooopss
# Total T: 4707 Episode Num: 112 Episode T: 25 Reward: -977.097
# Oooopss
# Total T: 4745 Episode Num: 113 Episode T: 38 Reward: -965.786
# Oooopss
# Total T: 4791 Episode Num: 114 Episode T: 46 Reward: -960.005
# Oooopss
# Total T: 4819 Episode Num: 115 Episode T: 28 Reward: -974.691
# Oooopss
# Total T: 4831 Episode Num: 116 Episode T: 12 Reward: -989.362
# Oooopss
# Total T: 4902 Episode Num: 117 Episode T: 71 Reward: -940.037
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# ---------------------------------------
# Evaluation over 10 episodes: -915.974
# ---------------------------------------
# Oooopss
# Total T: 5002 Episode Num: 118 Episode T: 100 Reward: -921.019
# Oooopss
# Total T: 5056 Episode Num: 119 Episode T: 54 Reward: -951.655
# Oooopss
# Total T: 5082 Episode Num: 120 Episode T: 26 Reward: -976.852
# Oooopss
# Total T: 5205 Episode Num: 121 Episode T: 123 Reward: -904.196
# Oooopss
# Total T: 5240 Episode Num: 122 Episode T: 35 Reward: -968.335
# Oooopss
# Total T: 5252 Episode Num: 123 Episode T: 12 Reward: -989.271
# Oooopss
# Total T: 5342 Episode Num: 124 Episode T: 90 Reward: -927.655
# Oooopss
# Total T: 5420 Episode Num: 125 Episode T: 78 Reward: -938.064
# Oooopss
# Total T: 5451 Episode Num: 126 Episode T: 31 Reward: -972.023
# Oooopss
# Total T: 5511 Episode Num: 127 Episode T: 60 Reward: -948.802
# Oooopss
# Total T: 5538 Episode Num: 128 Episode T: 27 Reward: -975.677
# Oooopss
# Total T: 5621 Episode Num: 129 Episode T: 83 Reward: -930.877
# Oooopss
# Total T: 5663 Episode Num: 130 Episode T: 42 Reward: -963.446
# Oooopss
# Total T: 5682 Episode Num: 131 Episode T: 19 Reward: -982.770
# Oooopss
# Total T: 5785 Episode Num: 132 Episode T: 103 Reward: -917.399
# Oooopss
# Total T: 5844 Episode Num: 133 Episode T: 59 Reward: -949.047
# Oooopss
# Total T: 5917 Episode Num: 134 Episode T: 73 Reward: -940.324
# Oooopss
# Total T: 6009 Episode Num: 135 Episode T: 92 Reward: -923.421
# Oooopss
# Total T: 6034 Episode Num: 136 Episode T: 25 Reward: -977.622
# Oooopss
# Total T: 6126 Episode Num: 137 Episode T: 92 Reward: -929.032
# Oooopss
# Total T: 6163 Episode Num: 138 Episode T: 37 Reward: -966.608
# Oooopss
# Total T: 6196 Episode Num: 139 Episode T: 33 Reward: -969.686
# Oooopss
# Total T: 6224 Episode Num: 140 Episode T: 28 Reward: -974.748
# Oooopss
# Total T: 6260 Episode Num: 141 Episode T: 36 Reward: -966.510
# Oooopss
# Total T: 6272 Episode Num: 142 Episode T: 12 Reward: -989.282
# Oooopss
# Total T: 6333 Episode Num: 143 Episode T: 61 Reward: -946.745
# Oooopss
# Total T: 6460 Episode Num: 144 Episode T: 127 Reward: -903.609
# Oooopss
# Total T: 6567 Episode Num: 145 Episode T: 107 Reward: -914.142
# Oooopss
# Total T: 6640 Episode Num: 146 Episode T: 73 Reward: -941.379
# Oooopss
# Total T: 6709 Episode Num: 147 Episode T: 69 Reward: -940.023
# Oooopss
# Total T: 6810 Episode Num: 148 Episode T: 101 Reward: -920.350
# Oooopss
# Total T: 6822 Episode Num: 149 Episode T: 12 Reward: -989.273
# Oooopss
# Total T: 7066 Episode Num: 150 Episode T: 244 Reward: -817.781
# Oooopss
# Total T: 7210 Episode Num: 151 Episode T: 144 Reward: -890.741
# Oooopss
# Total T: 7269 Episode Num: 152 Episode T: 59 Reward: -948.472
# Oooopss
# Total T: 7495 Episode Num: 153 Episode T: 226 Reward: -832.752
# Oooopss
# Total T: 7768 Episode Num: 154 Episode T: 273 Reward: -799.552
# Oooopss
# Total T: 7988 Episode Num: 155 Episode T: 220 Reward: -839.668
# Oooopss
# Total T: 8234 Episode Num: 156 Episode T: 246 Reward: -821.225
# Oooopss
# Total T: 8397 Episode Num: 157 Episode T: 163 Reward: -879.316
# Oooopss
# Total T: 8622 Episode Num: 158 Episode T: 225 Reward: -835.917
# Oooopss
# Total T: 8741 Episode Num: 159 Episode T: 119 Reward: -905.753
# Oooopss
# Total T: 9010 Episode Num: 160 Episode T: 269 Reward: -799.263
# Oooopss
# Total T: 9155 Episode Num: 161 Episode T: 145 Reward: -891.049
# Oooopss
# Total T: 9451 Episode Num: 162 Episode T: 296 Reward: -779.561
# Oooopss
# Total T: 9704 Episode Num: 163 Episode T: 253 Reward: -817.686
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# ---------------------------------------
# Evaluation over 10 episodes: -861.519
# ---------------------------------------
# Oooopss
# Total T: 10001 Episode Num: 164 Episode T: 297 Reward: -795.315
# Oooopss
# Total T: 10226 Episode Num: 165 Episode T: 225 Reward: -836.143
# Oooopss
# Total T: 10422 Episode Num: 166 Episode T: 196 Reward: -861.203
# Oooopss
# Total T: 10932 Episode Num: 167 Episode T: 510 Reward: -657.122
# Oooopss
# Total T: 11047 Episode Num: 168 Episode T: 115 Reward: -917.282
# Oooopss
# Total T: 11165 Episode Num: 169 Episode T: 118 Reward: -913.845
# Oooopss
# Total T: 11278 Episode Num: 170 Episode T: 113 Reward: -918.233
# Oooopss
# Total T: 11502 Episode Num: 171 Episode T: 224 Reward: -840.203
# Oooopss
# Total T: 11693 Episode Num: 172 Episode T: 191 Reward: -861.167
# Oooopss
# Total T: 11809 Episode Num: 173 Episode T: 116 Reward: -917.164
# Oooopss
# Total T: 11938 Episode Num: 174 Episode T: 129 Reward: -906.823
# Oooopss
# Total T: 12153 Episode Num: 175 Episode T: 215 Reward: -844.512
# Oooopss
# Total T: 12362 Episode Num: 176 Episode T: 209 Reward: -849.300
# Oooopss
# Total T: 12454 Episode Num: 177 Episode T: 92 Reward: -935.424
# Oooopss
# Total T: 12667 Episode Num: 178 Episode T: 213 Reward: -847.128
# Oooopss
# Total T: 12861 Episode Num: 179 Episode T: 194 Reward: -861.779
# Oooopss
# Total T: 13114 Episode Num: 180 Episode T: 253 Reward: -819.926
# Oooopss
# Total T: 13376 Episode Num: 181 Episode T: 262 Reward: -813.976
# Oooopss
# Total T: 13629 Episode Num: 182 Episode T: 253 Reward: -820.925
# Oooopss
# Total T: 13883 Episode Num: 183 Episode T: 254 Reward: -820.604
# Oooopss
# Total T: 14403 Episode Num: 184 Episode T: 520 Reward: -646.625
# Oooopss
# Total T: 14664 Episode Num: 185 Episode T: 261 Reward: -809.700
# Oooopss
# Total T: 14928 Episode Num: 186 Episode T: 264 Reward: -811.135
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# ---------------------------------------
# Evaluation over 10 episodes: -813.987
# ---------------------------------------
# Oooopss
# Total T: 15001 Episode Num: 187 Episode T: 73 Reward: -938.699
# Oooopss
# Total T: 15272 Episode Num: 188 Episode T: 271 Reward: -805.734
# Oooopss
# Total T: 15868 Episode Num: 189 Episode T: 596 Reward: -588.838
# Oooopss
# Total T: 16150 Episode Num: 190 Episode T: 282 Reward: -793.944
# Oooopss
# Total T: 16425 Episode Num: 191 Episode T: 275 Reward: -798.058
# Oooopss
# Total T: 16709 Episode Num: 192 Episode T: 284 Reward: -792.299
# Oooopss
# Total T: 16996 Episode Num: 193 Episode T: 287 Reward: -790.185
# Oooopss
# Total T: 17275 Episode Num: 194 Episode T: 279 Reward: -797.360
# Oooopss
# Total T: 17558 Episode Num: 195 Episode T: 283 Reward: -791.968
# Oooopss
# Total T: 17838 Episode Num: 196 Episode T: 280 Reward: -794.726
# Oooopss
# Total T: 18112 Episode Num: 197 Episode T: 274 Reward: -798.523
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      25 # Train agent after collecting sufficient data
#      26 if t >= DEFAULT_START_TIMESTEPS:
# ---> 27     policy.train(replay_buffer, DEFAULT_BATCH_SIZE)
#      29 if done:
#      30     # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
#      31     print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
#
# Cell In[3], line 118, in TD3.train(self, replay_buffer, batch_size)
#     113 next_action = (
#     114         self.actor_target(next_state) + noise
#     115 ).clamp(-self.max_action, self.max_action)
#     117 # Compute the target Q value
# --> 118 target_Q1, target_Q2 = self.critic_target(next_state, next_action)
#     119 target_Q = torch.min(target_Q1, target_Q2)
#     120 target_Q = reward + not_done * self.discount * target_Q
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[3], line 50, in Critic.forward(self, state, action)
#      47 sa = torch.cat([state, action], 1)
#      49 q1 = F.relu(self.l1(sa))
# ---> 50 q1 = F.relu(self.l2(q1))
#      51 q1 = self.l3(q1)
#      53 q2 = F.relu(self.l4(sa))
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.8/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.8/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.8/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
## run simulation
prev_state= env.reset()
state_array = []
action_array = []
while True:
    # env.render()
    action = policy.select_action(np.array(state))
    state, reward, done, _ = env.step(action)
    action_array.append(action)
    episode_reward += reward
    state_array.append(state)
    action_array.append(action)
    if done:
        break
    prev_state = state

state_array = np.array(state_array)
action_array = np.array(action_array)
plt.plot(state_array[:,0], state_array[:,1], label='State')
plt.plot(trajectory[:,0], trajectory[:,1], label='Trajectory')
print(state_array[-1, :])
print(env.steps)
plt.legend()
plt.show()

# plot action
plt.plot(action_array.reshape(len(action_array), 2))
plt.legend()
plt.show()

print(len(action_array))
