# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
plt.plot(trajectory[:,0], trajectory[:,1])

# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 256)
        self.l4 = nn.Linear(256, 256)
        self.l5 = nn.Linear(256, action_dim)


        self.max_action = max_action

    def forward(self, state):
        a = F.relu(self.l1(state))
        a = F.relu(self.l2(a))
        a = F.tanh(self.l3(a))
        a = F.tanh(self.l4(a))
        return self.max_action * torch.tanh(self.l5(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):
        self.lr = 5e-5
        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        # load actor
        # self.actor.load_state_dict(torch.load("actor_deep"))
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=self.lr)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=self.lr)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=self.lr)
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=self.lr)
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)
# Out:
# cuda

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
	eval_env.reset(seed=seed
    )

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
# three body problem env
import gym
from gym import spaces
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-10, high=10, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.render_logic = False
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        # force = action[0] * env.state[2:] + action[1] * env.state[:2]
        a_x = action[0]/10
        a_y = action[1]/10

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y

        x = x + xdot*self.dt
        y = y + ydot*self.dt

        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        # plot position
        if env.render_logic:
            plt.plot(x, y, 'ro')
            plt.plot(self.trajectory[:,0], self.trajectory[:,1])
            plt.show()

        reward =  - np.linalg.norm(self.position, axis=0) # + self.steps/100
        done = self.steps >= self.max_steps
        if np.linalg.norm(self.position[0:2] - self.trajectory[-1, 0:2]) < 0.01:
            done = True
            reward = 1000
            print("done")
        if self.steps > 1000:
            done = True
            reward = -1000
            print("end time")
        if np.linalg.norm(self.state[0:2]) > 0.05:
            done = True
            reward = -1000
            print("too much error")

        # print(self.state, reward, done, self.position)
        return 1000*self.state, reward, done, self.position

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]

    def reset(self,
              *,
              seed: 5 = None,
              return_info: bool = False,
              options: 6 = None):
        self.position = self.trajectory[0]
        self.steps = 0
        self.position2state()
        return 10000*self.state

    def render(self):
        pass

    def close(self):
        pass


env = three_body_env(trajectory)

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "TBP"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(5e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(5e5)
DEFAULT_EXPL_NOISE = 0.02
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.02
DEFAULT_NOISE_CLIP = 0.02
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ}
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False

episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------
# Policy: TD3, Env: TBP, Seed: 0
# ---------------------------------------
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1143.351
# ---------------------------------------

# %%
replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False

episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.490
# ---------------------------------------

# %%
# evaluations = [eval_policy(policy, env, DEFAULT_SEED)]
for t in range(int(DEFAULT_MAX_TIMESTEPS)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action)
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done:
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1
        policy.lr = policy.lr*0.99
        print(policy.lr)

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# too much error
# Total T: 87 Episode Num: 1 Episode T: 87 Reward: -1075.115
# too much error
# Total T: 202 Episode Num: 2 Episode T: 115 Reward: -1097.020
# too much error
# Total T: 358 Episode Num: 3 Episode T: 156 Reward: -1132.066
# too much error
# Total T: 422 Episode Num: 4 Episode T: 64 Reward: -1055.446
# too much error
# Total T: 530 Episode Num: 5 Episode T: 108 Reward: -1092.211
# too much error
# Total T: 669 Episode Num: 6 Episode T: 139 Reward: -1121.383
# too much error
# Total T: 749 Episode Num: 7 Episode T: 80 Reward: -1068.657
# too much error
# Total T: 862 Episode Num: 8 Episode T: 113 Reward: -1098.764
# too much error
# Total T: 1006 Episode Num: 9 Episode T: 144 Reward: -1125.667
# too much error
# Total T: 1114 Episode Num: 10 Episode T: 108 Reward: -1092.912
# too much error
# Total T: 1183 Episode Num: 11 Episode T: 69 Reward: -1059.929
# too much error
# Total T: 1272 Episode Num: 12 Episode T: 89 Reward: -1075.889
# too much error
# Total T: 1360 Episode Num: 13 Episode T: 88 Reward: -1076.304
# too much error
# Total T: 1496 Episode Num: 14 Episode T: 136 Reward: -1114.488
# too much error
# Total T: 1645 Episode Num: 15 Episode T: 149 Reward: -1127.839
# too much error
# Total T: 1753 Episode Num: 16 Episode T: 108 Reward: -1091.041
# too much error
# Total T: 1856 Episode Num: 17 Episode T: 103 Reward: -1087.634
# too much error
# Total T: 2009 Episode Num: 18 Episode T: 153 Reward: -1132.628
# too much error
# Total T: 2122 Episode Num: 19 Episode T: 113 Reward: -1097.780
# too much error
# Total T: 2209 Episode Num: 20 Episode T: 87 Reward: -1074.488
# too much error
# Total T: 2293 Episode Num: 21 Episode T: 84 Reward: -1071.468
# too much error
# Total T: 2427 Episode Num: 22 Episode T: 134 Reward: -1112.871
# too much error
# Total T: 2486 Episode Num: 23 Episode T: 59 Reward: -1050.226
# too much error
# Total T: 2614 Episode Num: 24 Episode T: 128 Reward: -1109.208
# too much error
# Total T: 2672 Episode Num: 25 Episode T: 58 Reward: -1050.021
# too much error
# Total T: 2793 Episode Num: 26 Episode T: 121 Reward: -1102.502
# too much error
# Total T: 2867 Episode Num: 27 Episode T: 74 Reward: -1062.591
# too much error
# Total T: 2969 Episode Num: 28 Episode T: 102 Reward: -1086.188
# too much error
# Total T: 3053 Episode Num: 29 Episode T: 84 Reward: -1072.926
# too much error
# Total T: 3119 Episode Num: 30 Episode T: 66 Reward: -1056.879
# too much error
# Total T: 3204 Episode Num: 31 Episode T: 85 Reward: -1072.455
# too much error
# Total T: 3334 Episode Num: 32 Episode T: 130 Reward: -1110.108
# too much error
# Total T: 3427 Episode Num: 33 Episode T: 93 Reward: -1078.507
# too much error
# Total T: 3562 Episode Num: 34 Episode T: 135 Reward: -1115.161
# too much error
# Total T: 3759 Episode Num: 35 Episode T: 197 Reward: -1177.823
# too much error
# Total T: 3873 Episode Num: 36 Episode T: 114 Reward: -1096.971
# too much error
# Total T: 3995 Episode Num: 37 Episode T: 122 Reward: -1104.043
# too much error
# Total T: 4070 Episode Num: 38 Episode T: 75 Reward: -1063.836
# too much error
# Total T: 4157 Episode Num: 39 Episode T: 87 Reward: -1075.918
# too much error
# Total T: 4230 Episode Num: 40 Episode T: 73 Reward: -1062.797
# too much error
# Total T: 4315 Episode Num: 41 Episode T: 85 Reward: -1072.782
# too much error
# Total T: 4406 Episode Num: 42 Episode T: 91 Reward: -1077.761
# too much error
# Total T: 4664 Episode Num: 43 Episode T: 258 Reward: -1223.856
# too much error
# Total T: 4761 Episode Num: 44 Episode T: 97 Reward: -1083.256
# too much error
# Total T: 4841 Episode Num: 45 Episode T: 80 Reward: -1068.098
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.490
# ---------------------------------------
# done
# Total T: 5001 Episode Num: 46 Episode T: 160 Reward: 860.774
# too much error
# Total T: 5567 Episode Num: 47 Episode T: 566 Reward: -1590.012
# done
# Total T: 6130 Episode Num: 48 Episode T: 563 Reward: 418.388
# too much error
# Total T: 6534 Episode Num: 49 Episode T: 404 Reward: -1394.297
# too much error
# Total T: 7102 Episode Num: 50 Episode T: 568 Reward: -1591.181
# done
# Total T: 7641 Episode Num: 51 Episode T: 539 Reward: 441.695
# done
# Total T: 8176 Episode Num: 52 Episode T: 535 Reward: 446.850
# too much error
# Total T: 8747 Episode Num: 53 Episode T: 571 Reward: -1594.892
# done
# Total T: 9285 Episode Num: 54 Episode T: 538 Reward: 443.458
# done
# Total T: 9831 Episode Num: 55 Episode T: 546 Reward: 433.387
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1395.181
# ---------------------------------------
# too much error
# Total T: 10001 Episode Num: 56 Episode T: 170 Reward: -1144.964
# too much error
# Total T: 10571 Episode Num: 57 Episode T: 570 Reward: -1593.468
# too much error
# Total T: 11148 Episode Num: 58 Episode T: 577 Reward: -1601.962
# too much error
# Total T: 11726 Episode Num: 59 Episode T: 578 Reward: -1600.738
# too much error
# Total T: 12139 Episode Num: 60 Episode T: 413 Reward: -1404.294
# done
# Total T: 12686 Episode Num: 61 Episode T: 547 Reward: 435.194
# too much error
# Total T: 13254 Episode Num: 62 Episode T: 568 Reward: -1591.833
# done
# Total T: 13791 Episode Num: 63 Episode T: 537 Reward: 444.483
# done
# Total T: 14340 Episode Num: 64 Episode T: 549 Reward: 432.889
# done
# Total T: 14904 Episode Num: 65 Episode T: 564 Reward: 418.104
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1395.855
# ---------------------------------------
# too much error
# Total T: 15001 Episode Num: 66 Episode T: 97 Reward: -1082.658
# too much error
# Total T: 15568 Episode Num: 67 Episode T: 567 Reward: -1581.306
# done
# Total T: 16139 Episode Num: 68 Episode T: 571 Reward: 410.301
# too much error
# Total T: 16702 Episode Num: 69 Episode T: 563 Reward: -1576.508
# too much error
# Total T: 17270 Episode Num: 70 Episode T: 568 Reward: -1592.196
# done
# Total T: 17820 Episode Num: 71 Episode T: 550 Reward: 437.576
# too much error
# Total T: 18389 Episode Num: 72 Episode T: 569 Reward: -1592.579
# done
# Total T: 18930 Episode Num: 73 Episode T: 541 Reward: 439.536
# done
# Total T: 19487 Episode Num: 74 Episode T: 557 Reward: 425.824
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1383.318
# ---------------------------------------
# too much error
# Total T: 20001 Episode Num: 75 Episode T: 514 Reward: -1529.839
# too much error
# Total T: 20411 Episode Num: 76 Episode T: 410 Reward: -1400.753
# done
# Total T: 20958 Episode Num: 77 Episode T: 547 Reward: 435.162
# too much error
# Total T: 21350 Episode Num: 78 Episode T: 392 Reward: -1379.955
# done
# Total T: 21887 Episode Num: 79 Episode T: 537 Reward: 443.194
# too much error
# Total T: 22286 Episode Num: 80 Episode T: 399 Reward: -1388.722
# too much error
# Total T: 22683 Episode Num: 81 Episode T: 397 Reward: -1386.260
# done
# Total T: 23217 Episode Num: 82 Episode T: 534 Reward: 446.050
# too much error
# Total T: 23614 Episode Num: 83 Episode T: 397 Reward: -1385.748
# done
# Total T: 24170 Episode Num: 84 Episode T: 556 Reward: 425.546
# too much error
# Total T: 24556 Episode Num: 85 Episode T: 386 Reward: -1373.781
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 441.529
# ---------------------------------------
# done
# Total T: 25001 Episode Num: 86 Episode T: 445 Reward: 555.593
# too much error
# Total T: 25399 Episode Num: 87 Episode T: 398 Reward: -1389.121
# done
# Total T: 25933 Episode Num: 88 Episode T: 534 Reward: 452.434
# too much error
# Total T: 26304 Episode Num: 89 Episode T: 371 Reward: -1356.455
# too much error
# Total T: 26678 Episode Num: 90 Episode T: 374 Reward: -1359.423
# too much error
# Total T: 27243 Episode Num: 91 Episode T: 565 Reward: -1589.805
# too much error
# Total T: 27812 Episode Num: 92 Episode T: 569 Reward: -1593.485
# done
# Total T: 28366 Episode Num: 93 Episode T: 554 Reward: 424.182
# too much error
# Total T: 28740 Episode Num: 94 Episode T: 374 Reward: -1361.677
# too much error
# Total T: 29320 Episode Num: 95 Episode T: 580 Reward: -1603.596
# done
# Total T: 29860 Episode Num: 96 Episode T: 540 Reward: 438.896
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1591.727
# ---------------------------------------
# too much error
# Total T: 30001 Episode Num: 97 Episode T: 141 Reward: -1120.087
# done
# Total T: 30550 Episode Num: 98 Episode T: 549 Reward: 433.009
# done
# Total T: 31098 Episode Num: 99 Episode T: 548 Reward: 435.568
# done
# Total T: 31633 Episode Num: 100 Episode T: 535 Reward: 448.282
# too much error
# Total T: 32015 Episode Num: 101 Episode T: 382 Reward: -1368.720
# done
# Total T: 32547 Episode Num: 102 Episode T: 532 Reward: 452.281
# done
# Total T: 33080 Episode Num: 103 Episode T: 533 Reward: 452.585
# too much error
# Total T: 33646 Episode Num: 104 Episode T: 566 Reward: -1590.489
# too much error
# Total T: 34026 Episode Num: 105 Episode T: 380 Reward: -1367.221
# done
# Total T: 34556 Episode Num: 106 Episode T: 530 Reward: 455.195
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 458.575
# ---------------------------------------
# done
# Total T: 35001 Episode Num: 107 Episode T: 445 Reward: 549.446
# too much error
# Total T: 35364 Episode Num: 108 Episode T: 363 Reward: -1345.972
# done
# Total T: 35925 Episode Num: 109 Episode T: 561 Reward: 420.179
# too much error
# Total T: 36495 Episode Num: 110 Episode T: 570 Reward: -1594.517
# too much error
# Total T: 36908 Episode Num: 111 Episode T: 413 Reward: -1404.627
# done
# Total T: 37469 Episode Num: 112 Episode T: 561 Reward: 421.521
# done
# Total T: 38017 Episode Num: 113 Episode T: 548 Reward: 433.538
# done
# Total T: 38563 Episode Num: 114 Episode T: 546 Reward: 435.986
# too much error
# Total T: 39132 Episode Num: 115 Episode T: 569 Reward: -1582.463
# done
# Total T: 39667 Episode Num: 116 Episode T: 535 Reward: 451.746
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 458.956
# ---------------------------------------
# done
# Total T: 40001 Episode Num: 117 Episode T: 334 Reward: 681.794
# too much error
# Total T: 40572 Episode Num: 118 Episode T: 571 Reward: -1584.842
# done
# Total T: 41116 Episode Num: 119 Episode T: 544 Reward: 435.685
# too much error
# Total T: 41686 Episode Num: 120 Episode T: 570 Reward: -1594.352
# done
# Total T: 42212 Episode Num: 121 Episode T: 526 Reward: 457.922
# done
# Total T: 42781 Episode Num: 122 Episode T: 569 Reward: 412.860
# too much error
# Total T: 43345 Episode Num: 123 Episode T: 564 Reward: -1577.971
# done
# Total T: 43914 Episode Num: 124 Episode T: 569 Reward: 412.894
# too much error
# Total T: 44326 Episode Num: 125 Episode T: 412 Reward: -1403.579
# done
# Total T: 44877 Episode Num: 126 Episode T: 551 Reward: 430.376
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 442.205
# ---------------------------------------
# done
# Total T: 45001 Episode Num: 127 Episode T: 124 Reward: 894.326
# done
# Total T: 45540 Episode Num: 128 Episode T: 539 Reward: 441.469
# too much error
# Total T: 46114 Episode Num: 129 Episode T: 574 Reward: -1587.967
# done
# Total T: 46651 Episode Num: 130 Episode T: 537 Reward: 445.970
# done
# Total T: 47180 Episode Num: 131 Episode T: 529 Reward: 453.688
# done
# Total T: 47744 Episode Num: 132 Episode T: 564 Reward: 417.083
# done
# Total T: 48301 Episode Num: 133 Episode T: 557 Reward: 424.085
# done
# Total T: 48858 Episode Num: 134 Episode T: 557 Reward: 419.071
# too much error
# Total T: 49439 Episode Num: 135 Episode T: 581 Reward: -1607.709
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.456
# ---------------------------------------
# done
# Total T: 50001 Episode Num: 136 Episode T: 562 Reward: 420.934
# done
# Total T: 50530 Episode Num: 137 Episode T: 529 Reward: 452.832
# too much error
# Total T: 51097 Episode Num: 138 Episode T: 567 Reward: -1591.034
# done
# Total T: 51643 Episode Num: 139 Episode T: 546 Reward: 432.152
# too much error
# Total T: 52209 Episode Num: 140 Episode T: 566 Reward: -1590.318
# done
# Total T: 52739 Episode Num: 141 Episode T: 530 Reward: 452.931
# done
# Total T: 53279 Episode Num: 142 Episode T: 540 Reward: 439.046
# done
# Total T: 53800 Episode Num: 143 Episode T: 521 Reward: 463.297
# too much error
# Total T: 54374 Episode Num: 144 Episode T: 574 Reward: -1587.950
# done
# Total T: 54900 Episode Num: 145 Episode T: 526 Reward: 457.427
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 438.917
# ---------------------------------------
# done
# Total T: 55001 Episode Num: 146 Episode T: 101 Reward: 913.851
# too much error
# Total T: 55580 Episode Num: 147 Episode T: 579 Reward: -1603.289
# too much error
# Total T: 56146 Episode Num: 148 Episode T: 566 Reward: -1590.176
# done
# Total T: 56682 Episode Num: 149 Episode T: 536 Reward: 444.711
# done
# Total T: 57219 Episode Num: 150 Episode T: 537 Reward: 444.046
# done
# Total T: 57759 Episode Num: 151 Episode T: 540 Reward: 442.679
# done
# Total T: 58288 Episode Num: 152 Episode T: 529 Reward: 453.921
# done
# Total T: 58834 Episode Num: 153 Episode T: 546 Reward: 432.027
# done
# Total T: 59368 Episode Num: 154 Episode T: 534 Reward: 448.093
# done
# Total T: 59897 Episode Num: 155 Episode T: 529 Reward: 453.887
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 410.722
# ---------------------------------------
# done
# Total T: 60001 Episode Num: 156 Episode T: 104 Reward: 911.314
# done
# Total T: 60536 Episode Num: 157 Episode T: 535 Reward: 446.165
# done
# Total T: 61078 Episode Num: 158 Episode T: 542 Reward: 437.868
# done
# Total T: 61606 Episode Num: 159 Episode T: 528 Reward: 455.610
# done
# Total T: 62145 Episode Num: 160 Episode T: 539 Reward: 440.673
# done
# Total T: 62673 Episode Num: 161 Episode T: 528 Reward: 454.797
# too much error
# Total T: 63239 Episode Num: 162 Episode T: 566 Reward: -1589.442
# done
# Total T: 63791 Episode Num: 163 Episode T: 552 Reward: 426.601
# done
# Total T: 64321 Episode Num: 164 Episode T: 530 Reward: 455.303
# done
# Total T: 64852 Episode Num: 165 Episode T: 531 Reward: 451.613
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.476
# ---------------------------------------
# done
# Total T: 65001 Episode Num: 166 Episode T: 149 Reward: 873.080
# done
# Total T: 65526 Episode Num: 167 Episode T: 525 Reward: 459.038
# done
# Total T: 66065 Episode Num: 168 Episode T: 539 Reward: 441.689
# done
# Total T: 66606 Episode Num: 169 Episode T: 541 Reward: 438.257
# done
# Total T: 67136 Episode Num: 170 Episode T: 530 Reward: 451.851
# done
# Total T: 67681 Episode Num: 171 Episode T: 545 Reward: 434.413
# done
# Total T: 68212 Episode Num: 172 Episode T: 531 Reward: 453.152
# done
# Total T: 68745 Episode Num: 173 Episode T: 533 Reward: 449.664
# done
# Total T: 69272 Episode Num: 174 Episode T: 527 Reward: 456.077
# too much error
# Total T: 69842 Episode Num: 175 Episode T: 570 Reward: -1595.483
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 408.557
# ---------------------------------------
# done
# Total T: 70001 Episode Num: 176 Episode T: 159 Reward: 864.515
# done
# Total T: 70540 Episode Num: 177 Episode T: 539 Reward: 441.270
# done
# Total T: 71070 Episode Num: 178 Episode T: 530 Reward: 452.057
# done
# Total T: 71601 Episode Num: 179 Episode T: 531 Reward: 451.371
# done
# Total T: 72127 Episode Num: 180 Episode T: 526 Reward: 459.841
# done
# Total T: 72661 Episode Num: 181 Episode T: 534 Reward: 447.932
# done
# Total T: 73225 Episode Num: 182 Episode T: 564 Reward: 416.667
# done
# Total T: 73760 Episode Num: 183 Episode T: 535 Reward: 447.460
# done
# Total T: 74291 Episode Num: 184 Episode T: 531 Reward: 451.391
# done
# Total T: 74835 Episode Num: 185 Episode T: 544 Reward: 435.001
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.817
# ---------------------------------------
# done
# Total T: 75001 Episode Num: 186 Episode T: 166 Reward: 858.492
# done
# Total T: 75533 Episode Num: 187 Episode T: 532 Reward: 450.600
# done
# Total T: 76093 Episode Num: 188 Episode T: 560 Reward: 422.452
# done
# Total T: 76645 Episode Num: 189 Episode T: 552 Reward: 426.331
# done
# Total T: 77172 Episode Num: 190 Episode T: 527 Reward: 455.723
# done
# Total T: 77700 Episode Num: 191 Episode T: 528 Reward: 454.525
# done
# Total T: 78228 Episode Num: 192 Episode T: 528 Reward: 457.654
# done
# Total T: 78756 Episode Num: 193 Episode T: 528 Reward: 454.828
# done
# Total T: 79295 Episode Num: 194 Episode T: 539 Reward: 441.801
# done
# Total T: 79824 Episode Num: 195 Episode T: 529 Reward: 456.752
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 461.537
# ---------------------------------------
# done
# Total T: 80001 Episode Num: 196 Episode T: 177 Reward: 848.916
# done
# Total T: 80535 Episode Num: 197 Episode T: 534 Reward: 448.054
# done
# Total T: 81070 Episode Num: 198 Episode T: 535 Reward: 445.631
# done
# Total T: 81602 Episode Num: 199 Episode T: 532 Reward: 450.259
# done
# Total T: 82139 Episode Num: 200 Episode T: 537 Reward: 443.162
# done
# Total T: 82671 Episode Num: 201 Episode T: 532 Reward: 450.127
# done
# Total T: 83205 Episode Num: 202 Episode T: 534 Reward: 447.327
# done
# Total T: 83735 Episode Num: 203 Episode T: 530 Reward: 452.267
# done
# Total T: 84270 Episode Num: 204 Episode T: 535 Reward: 446.059
# too much error
# Total T: 84839 Episode Num: 205 Episode T: 569 Reward: -1594.052
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1604.085
# ---------------------------------------
# too much error
# Total T: 85001 Episode Num: 206 Episode T: 162 Reward: -1138.062
# done
# Total T: 85531 Episode Num: 207 Episode T: 530 Reward: 452.693
# done
# Total T: 86090 Episode Num: 208 Episode T: 559 Reward: 416.952
# too much error
# Total T: 86652 Episode Num: 209 Episode T: 562 Reward: -1584.214
# done
# Total T: 87209 Episode Num: 210 Episode T: 557 Reward: 420.467
# done
# Total T: 87750 Episode Num: 211 Episode T: 541 Reward: 439.011
# too much error
# Total T: 88326 Episode Num: 212 Episode T: 576 Reward: -1597.112
# done
# Total T: 88889 Episode Num: 213 Episode T: 563 Reward: 413.230
# too much error
# Total T: 89458 Episode Num: 214 Episode T: 569 Reward: -1592.491
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 450.200
# ---------------------------------------
# done
# Total T: 90001 Episode Num: 215 Episode T: 543 Reward: 436.180
# done
# Total T: 90525 Episode Num: 216 Episode T: 524 Reward: 460.867
# done
# Total T: 91053 Episode Num: 217 Episode T: 528 Reward: 458.141
# too much error
# Total T: 91618 Episode Num: 218 Episode T: 565 Reward: -1588.482
# done
# Total T: 92162 Episode Num: 219 Episode T: 544 Reward: 435.422
# done
# Total T: 92685 Episode Num: 220 Episode T: 523 Reward: 461.975
# done
# Total T: 93221 Episode Num: 221 Episode T: 536 Reward: 445.215
# done
# Total T: 93748 Episode Num: 222 Episode T: 527 Reward: 456.607
# too much error
# Total T: 94312 Episode Num: 223 Episode T: 564 Reward: -1586.808
# done
# Total T: 94835 Episode Num: 224 Episode T: 523 Reward: 461.912
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.986
# ---------------------------------------
# done
# Total T: 95001 Episode Num: 225 Episode T: 166 Reward: 858.522
# done
# Total T: 95521 Episode Num: 226 Episode T: 520 Reward: 464.929
# done
# Total T: 96076 Episode Num: 227 Episode T: 555 Reward: 422.631
# too much error
# Total T: 96639 Episode Num: 228 Episode T: 563 Reward: -1585.870
# done
# Total T: 97169 Episode Num: 229 Episode T: 530 Reward: 452.106
# done
# Total T: 97701 Episode Num: 230 Episode T: 532 Reward: 450.307
# too much error
# Total T: 98267 Episode Num: 231 Episode T: 566 Reward: -1588.778
# too much error
# Total T: 98833 Episode Num: 232 Episode T: 566 Reward: -1589.434
# done
# Total T: 99389 Episode Num: 233 Episode T: 556 Reward: 426.646
# done
# Total T: 99917 Episode Num: 234 Episode T: 528 Reward: 457.821
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.107
# ---------------------------------------
# done
# Total T: 100001 Episode Num: 235 Episode T: 84 Reward: 928.263
# done
# Total T: 100544 Episode Num: 236 Episode T: 543 Reward: 437.032
# done
# Total T: 101083 Episode Num: 237 Episode T: 539 Reward: 441.261
# done
# Total T: 101613 Episode Num: 238 Episode T: 530 Reward: 452.527
# too much error
# Total T: 102192 Episode Num: 239 Episode T: 579 Reward: -1604.109
# done
# Total T: 102729 Episode Num: 240 Episode T: 537 Reward: 444.196
# done
# Total T: 103266 Episode Num: 241 Episode T: 537 Reward: 443.651
# done
# Total T: 103792 Episode Num: 242 Episode T: 526 Reward: 458.111
# done
# Total T: 104326 Episode Num: 243 Episode T: 534 Reward: 447.461
# done
# Total T: 104863 Episode Num: 244 Episode T: 537 Reward: 449.924
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.669
# ---------------------------------------
# done
# Total T: 105001 Episode Num: 245 Episode T: 138 Reward: 882.432
# done
# Total T: 105530 Episode Num: 246 Episode T: 529 Reward: 456.870
# done
# Total T: 106070 Episode Num: 247 Episode T: 540 Reward: 440.928
# done
# Total T: 106600 Episode Num: 248 Episode T: 530 Reward: 452.851
# done
# Total T: 107131 Episode Num: 249 Episode T: 531 Reward: 451.827
# done
# Total T: 107661 Episode Num: 250 Episode T: 530 Reward: 453.511
# done
# Total T: 108182 Episode Num: 251 Episode T: 521 Reward: 463.425
# done
# Total T: 108713 Episode Num: 252 Episode T: 531 Reward: 451.844
# done
# Total T: 109241 Episode Num: 253 Episode T: 528 Reward: 457.334
# done
# Total T: 109796 Episode Num: 254 Episode T: 555 Reward: 422.772
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 452.742
# ---------------------------------------
# done
# Total T: 110001 Episode Num: 255 Episode T: 205 Reward: 824.138
# done
# Total T: 110562 Episode Num: 256 Episode T: 561 Reward: 415.735
# done
# Total T: 111086 Episode Num: 257 Episode T: 524 Reward: 461.968
# done
# Total T: 111641 Episode Num: 258 Episode T: 555 Reward: 426.417
# done
# Total T: 112172 Episode Num: 259 Episode T: 531 Reward: 450.967
# done
# Total T: 112702 Episode Num: 260 Episode T: 530 Reward: 455.684
# done
# Total T: 113230 Episode Num: 261 Episode T: 528 Reward: 454.764
# done
# Total T: 113761 Episode Num: 262 Episode T: 531 Reward: 451.583
# done
# Total T: 114324 Episode Num: 263 Episode T: 563 Reward: 419.069
# done
# Total T: 114868 Episode Num: 264 Episode T: 544 Reward: 435.769
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 457.310
# ---------------------------------------
# done
# Total T: 115001 Episode Num: 265 Episode T: 133 Reward: 886.722
# done
# Total T: 115535 Episode Num: 266 Episode T: 534 Reward: 447.362
# done
# Total T: 116056 Episode Num: 267 Episode T: 521 Reward: 463.641
# done
# Total T: 116587 Episode Num: 268 Episode T: 531 Reward: 454.443
# done
# Total T: 117119 Episode Num: 269 Episode T: 532 Reward: 453.772
# done
# Total T: 117647 Episode Num: 270 Episode T: 528 Reward: 456.781
# done
# Total T: 118169 Episode Num: 271 Episode T: 522 Reward: 462.700
# done
# Total T: 118700 Episode Num: 272 Episode T: 531 Reward: 454.475
# done
# Total T: 119229 Episode Num: 273 Episode T: 529 Reward: 456.596
# done
# Total T: 119759 Episode Num: 274 Episode T: 530 Reward: 453.110
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.511
# ---------------------------------------
# done
# Total T: 120001 Episode Num: 275 Episode T: 242 Reward: 787.261
# done
# Total T: 120527 Episode Num: 276 Episode T: 526 Reward: 458.673
# done
# Total T: 121054 Episode Num: 277 Episode T: 527 Reward: 459.291
# too much error
# Total T: 121625 Episode Num: 278 Episode T: 571 Reward: -1583.995
# too much error
# Total T: 122207 Episode Num: 279 Episode T: 582 Reward: -1608.865
# done
# Total T: 122739 Episode Num: 280 Episode T: 532 Reward: 449.958
# done
# Total T: 123266 Episode Num: 281 Episode T: 527 Reward: 456.931
# done
# Total T: 123822 Episode Num: 282 Episode T: 556 Reward: 421.278
# done
# Total T: 124359 Episode Num: 283 Episode T: 537 Reward: 443.669
# done
# Total T: 124895 Episode Num: 284 Episode T: 536 Reward: 446.064
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.732
# ---------------------------------------
# done
# Total T: 125001 Episode Num: 285 Episode T: 106 Reward: 909.610
# done
# Total T: 125529 Episode Num: 286 Episode T: 528 Reward: 457.887
# done
# Total T: 126058 Episode Num: 287 Episode T: 529 Reward: 454.635
# done
# Total T: 126587 Episode Num: 288 Episode T: 529 Reward: 456.354
# done
# Total T: 127109 Episode Num: 289 Episode T: 522 Reward: 462.857
# done
# Total T: 127639 Episode Num: 290 Episode T: 530 Reward: 452.686
# done
# Total T: 128168 Episode Num: 291 Episode T: 529 Reward: 457.092
# done
# Total T: 128697 Episode Num: 292 Episode T: 529 Reward: 456.700
# done
# Total T: 129217 Episode Num: 293 Episode T: 520 Reward: 464.603
# done
# Total T: 129772 Episode Num: 294 Episode T: 555 Reward: 422.616
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 462.827
# ---------------------------------------
# done
# Total T: 130001 Episode Num: 295 Episode T: 229 Reward: 801.558
# done
# Total T: 130531 Episode Num: 296 Episode T: 530 Reward: 452.966
# done
# Total T: 131061 Episode Num: 297 Episode T: 530 Reward: 453.290
# done
# Total T: 131621 Episode Num: 298 Episode T: 560 Reward: 416.931
# done
# Total T: 132180 Episode Num: 299 Episode T: 559 Reward: 418.101
# done
# Total T: 132717 Episode Num: 300 Episode T: 537 Reward: 445.813
# done
# Total T: 133247 Episode Num: 301 Episode T: 530 Reward: 455.724
# done
# Total T: 133779 Episode Num: 302 Episode T: 532 Reward: 453.698
# done
# Total T: 134309 Episode Num: 303 Episode T: 530 Reward: 455.540
# done
# Total T: 134839 Episode Num: 304 Episode T: 530 Reward: 455.863
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.630
# ---------------------------------------
# done
# Total T: 135001 Episode Num: 305 Episode T: 162 Reward: 861.949
# done
# Total T: 135535 Episode Num: 306 Episode T: 534 Reward: 451.384
# done
# Total T: 136057 Episode Num: 307 Episode T: 522 Reward: 462.570
# done
# Total T: 136580 Episode Num: 308 Episode T: 523 Reward: 461.830
# too much error
# Total T: 137151 Episode Num: 309 Episode T: 571 Reward: -1584.025
# done
# Total T: 137682 Episode Num: 310 Episode T: 531 Reward: 454.465
# done
# Total T: 138214 Episode Num: 311 Episode T: 532 Reward: 453.596
# done
# Total T: 138750 Episode Num: 312 Episode T: 536 Reward: 445.400
# done
# Total T: 139276 Episode Num: 313 Episode T: 526 Reward: 458.814
# done
# Total T: 139804 Episode Num: 314 Episode T: 528 Reward: 456.879
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 461.754
# ---------------------------------------
# done
# Total T: 140001 Episode Num: 315 Episode T: 197 Reward: 831.179
# done
# Total T: 140538 Episode Num: 316 Episode T: 537 Reward: 445.514
# done
# Total T: 141102 Episode Num: 317 Episode T: 564 Reward: 411.798
# done
# Total T: 141635 Episode Num: 318 Episode T: 533 Reward: 449.872
# done
# Total T: 142160 Episode Num: 319 Episode T: 525 Reward: 459.475
# done
# Total T: 142687 Episode Num: 320 Episode T: 527 Reward: 457.666
# done
# Total T: 143220 Episode Num: 321 Episode T: 533 Reward: 453.087
# done
# Total T: 143751 Episode Num: 322 Episode T: 531 Reward: 453.827
# done
# Total T: 144285 Episode Num: 323 Episode T: 534 Reward: 448.531
# done
# Total T: 144807 Episode Num: 324 Episode T: 522 Reward: 462.854
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.542
# ---------------------------------------
# done
# Total T: 145001 Episode Num: 325 Episode T: 194 Reward: 833.862
# done
# Total T: 145539 Episode Num: 326 Episode T: 538 Reward: 443.278
# done
# Total T: 146073 Episode Num: 327 Episode T: 534 Reward: 448.841
# done
# Total T: 146603 Episode Num: 328 Episode T: 530 Reward: 453.964
# done
# Total T: 147132 Episode Num: 329 Episode T: 529 Reward: 455.648
# done
# Total T: 147657 Episode Num: 330 Episode T: 525 Reward: 460.137
# done
# Total T: 148187 Episode Num: 331 Episode T: 530 Reward: 455.310
# done
# Total T: 148715 Episode Num: 332 Episode T: 528 Reward: 455.225
# done
# Total T: 149246 Episode Num: 333 Episode T: 531 Reward: 454.126
# done
# Total T: 149776 Episode Num: 334 Episode T: 530 Reward: 455.274
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.544
# ---------------------------------------
# done
# Total T: 150001 Episode Num: 335 Episode T: 225 Reward: 805.194
# done
# Total T: 150529 Episode Num: 336 Episode T: 528 Reward: 456.549
# done
# Total T: 151057 Episode Num: 337 Episode T: 528 Reward: 457.330
# done
# Total T: 151590 Episode Num: 338 Episode T: 533 Reward: 452.380
# done
# Total T: 152122 Episode Num: 339 Episode T: 532 Reward: 451.462
# done
# Total T: 152652 Episode Num: 340 Episode T: 530 Reward: 453.365
# done
# Total T: 153191 Episode Num: 341 Episode T: 539 Reward: 442.223
# done
# Total T: 153729 Episode Num: 342 Episode T: 538 Reward: 444.140
# done
# Total T: 154258 Episode Num: 343 Episode T: 529 Reward: 454.924
# done
# Total T: 154787 Episode Num: 344 Episode T: 529 Reward: 456.345
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.704
# ---------------------------------------
# done
# Total T: 155001 Episode Num: 345 Episode T: 214 Reward: 815.677
# done
# Total T: 155536 Episode Num: 346 Episode T: 535 Reward: 451.345
# done
# Total T: 156072 Episode Num: 347 Episode T: 536 Reward: 445.936
# done
# Total T: 156603 Episode Num: 348 Episode T: 531 Reward: 454.431
# done
# Total T: 157126 Episode Num: 349 Episode T: 523 Reward: 461.624
# done
# Total T: 157662 Episode Num: 350 Episode T: 536 Reward: 446.702
# done
# Total T: 158190 Episode Num: 351 Episode T: 528 Reward: 457.431
# done
# Total T: 158717 Episode Num: 352 Episode T: 527 Reward: 457.758
# done
# Total T: 159250 Episode Num: 353 Episode T: 533 Reward: 452.322
# done
# Total T: 159778 Episode Num: 354 Episode T: 528 Reward: 456.049
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.246
# ---------------------------------------
# done
# Total T: 160001 Episode Num: 355 Episode T: 223 Reward: 806.845
# done
# Total T: 160561 Episode Num: 356 Episode T: 560 Reward: 416.842
# done
# Total T: 161092 Episode Num: 357 Episode T: 531 Reward: 452.117
# done
# Total T: 161624 Episode Num: 358 Episode T: 532 Reward: 453.334
# done
# Total T: 162161 Episode Num: 359 Episode T: 537 Reward: 445.509
# done
# Total T: 162689 Episode Num: 360 Episode T: 528 Reward: 456.742
# done
# Total T: 163222 Episode Num: 361 Episode T: 533 Reward: 452.148
# done
# Total T: 163756 Episode Num: 362 Episode T: 534 Reward: 451.274
# done
# Total T: 164285 Episode Num: 363 Episode T: 529 Reward: 456.466
# done
# Total T: 164807 Episode Num: 364 Episode T: 522 Reward: 462.833
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.581
# ---------------------------------------
# done
# Total T: 165001 Episode Num: 365 Episode T: 194 Reward: 833.883
# done
# Total T: 165523 Episode Num: 366 Episode T: 522 Reward: 462.505
# done
# Total T: 166053 Episode Num: 367 Episode T: 530 Reward: 455.692
# done
# Total T: 166582 Episode Num: 368 Episode T: 529 Reward: 456.116
# done
# Total T: 167106 Episode Num: 369 Episode T: 524 Reward: 460.564
# done
# Total T: 167639 Episode Num: 370 Episode T: 533 Reward: 449.950
# done
# Total T: 168207 Episode Num: 371 Episode T: 568 Reward: 407.478
# done
# Total T: 168736 Episode Num: 372 Episode T: 529 Reward: 456.403
# done
# Total T: 169263 Episode Num: 373 Episode T: 527 Reward: 457.617
# done
# Total T: 169817 Episode Num: 374 Episode T: 554 Reward: 425.140
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.535
# ---------------------------------------
# done
# Total T: 170001 Episode Num: 375 Episode T: 184 Reward: 842.677
# done
# Total T: 170526 Episode Num: 376 Episode T: 525 Reward: 459.748
# done
# Total T: 171058 Episode Num: 377 Episode T: 532 Reward: 453.638
# done
# Total T: 171585 Episode Num: 378 Episode T: 527 Reward: 457.181
# done
# Total T: 172096 Episode Num: 379 Episode T: 511 Reward: 477.324
# done
# Total T: 172624 Episode Num: 380 Episode T: 528 Reward: 457.516
# done
# Total T: 173158 Episode Num: 381 Episode T: 534 Reward: 451.663
# done
# Total T: 173683 Episode Num: 382 Episode T: 525 Reward: 459.824
# done
# Total T: 174216 Episode Num: 383 Episode T: 533 Reward: 452.026
# done
# Total T: 174746 Episode Num: 384 Episode T: 530 Reward: 453.363
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 451.203
# ---------------------------------------
# done
# Total T: 175001 Episode Num: 385 Episode T: 255 Reward: 772.259
# done
# Total T: 175533 Episode Num: 386 Episode T: 532 Reward: 453.226
# done
# Total T: 176058 Episode Num: 387 Episode T: 525 Reward: 459.896
# done
# Total T: 176590 Episode Num: 388 Episode T: 532 Reward: 453.722
# done
# Total T: 177120 Episode Num: 389 Episode T: 530 Reward: 455.584
# done
# Total T: 177642 Episode Num: 390 Episode T: 522 Reward: 462.627
# done
# Total T: 178168 Episode Num: 391 Episode T: 526 Reward: 460.361
# done
# Total T: 178735 Episode Num: 392 Episode T: 567 Reward: 408.203
# done
# Total T: 179265 Episode Num: 393 Episode T: 530 Reward: 455.276
# done
# Total T: 179796 Episode Num: 394 Episode T: 531 Reward: 454.430
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.500
# ---------------------------------------
# done
# Total T: 180001 Episode Num: 395 Episode T: 205 Reward: 823.863
# done
# Total T: 180534 Episode Num: 396 Episode T: 533 Reward: 452.237
# done
# Total T: 181066 Episode Num: 397 Episode T: 532 Reward: 453.029
# done
# Total T: 181598 Episode Num: 398 Episode T: 532 Reward: 453.608
# done
# Total T: 182132 Episode Num: 399 Episode T: 534 Reward: 451.379
# done
# Total T: 182665 Episode Num: 400 Episode T: 533 Reward: 452.118
# done
# Total T: 183189 Episode Num: 401 Episode T: 524 Reward: 460.634
# done
# Total T: 183723 Episode Num: 402 Episode T: 534 Reward: 451.278
# done
# Total T: 184252 Episode Num: 403 Episode T: 529 Reward: 456.349
# done
# Total T: 184810 Episode Num: 404 Episode T: 558 Reward: 419.189
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 452.235
# ---------------------------------------
# done
# Total T: 185001 Episode Num: 405 Episode T: 191 Reward: 836.495
# done
# Total T: 185530 Episode Num: 406 Episode T: 529 Reward: 456.206
# done
# Total T: 186058 Episode Num: 407 Episode T: 528 Reward: 457.500
# done
# Total T: 186585 Episode Num: 408 Episode T: 527 Reward: 457.535
# done
# Total T: 187115 Episode Num: 409 Episode T: 530 Reward: 455.417
# done
# Total T: 187646 Episode Num: 410 Episode T: 531 Reward: 454.475
# done
# Total T: 188177 Episode Num: 411 Episode T: 531 Reward: 454.456
# done
# Total T: 188699 Episode Num: 412 Episode T: 522 Reward: 462.984
# done
# Total T: 189228 Episode Num: 413 Episode T: 529 Reward: 456.643
# done
# Total T: 189761 Episode Num: 414 Episode T: 533 Reward: 452.036
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 451.291
# ---------------------------------------
# done
# Total T: 190001 Episode Num: 415 Episode T: 240 Reward: 789.317
# done
# Total T: 190531 Episode Num: 416 Episode T: 530 Reward: 453.495
# done
# Total T: 191069 Episode Num: 417 Episode T: 538 Reward: 444.314
# done
# Total T: 191597 Episode Num: 418 Episode T: 528 Reward: 457.343
# done
# Total T: 192144 Episode Num: 419 Episode T: 547 Reward: 435.881
# done
# Total T: 192675 Episode Num: 420 Episode T: 531 Reward: 454.330
# done
# Total T: 193204 Episode Num: 421 Episode T: 529 Reward: 456.170
# done
# Total T: 193735 Episode Num: 422 Episode T: 531 Reward: 453.399
# done
# Total T: 194270 Episode Num: 423 Episode T: 535 Reward: 449.271
# done
# Total T: 194803 Episode Num: 424 Episode T: 533 Reward: 451.435
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.365
# ---------------------------------------
# done
# Total T: 195001 Episode Num: 425 Episode T: 198 Reward: 830.266
# done
# Total T: 195532 Episode Num: 426 Episode T: 531 Reward: 454.752
# done
# Total T: 196068 Episode Num: 427 Episode T: 536 Reward: 446.993
# done
# Total T: 196603 Episode Num: 428 Episode T: 535 Reward: 450.662
# done
# Total T: 197124 Episode Num: 429 Episode T: 521 Reward: 463.839
# done
# Total T: 197654 Episode Num: 430 Episode T: 530 Reward: 455.482
# done
# Total T: 198183 Episode Num: 431 Episode T: 529 Reward: 456.337
# done
# Total T: 198712 Episode Num: 432 Episode T: 529 Reward: 456.366
# done
# Total T: 199246 Episode Num: 433 Episode T: 534 Reward: 448.214
# done
# Total T: 199776 Episode Num: 434 Episode T: 530 Reward: 455.392
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 452.216
# ---------------------------------------
# done
# Total T: 200001 Episode Num: 435 Episode T: 225 Reward: 805.031
# done
# Total T: 200534 Episode Num: 436 Episode T: 533 Reward: 452.757
# done
# Total T: 201064 Episode Num: 437 Episode T: 530 Reward: 455.464
# done
# Total T: 201598 Episode Num: 438 Episode T: 534 Reward: 451.024
# done
# Total T: 202126 Episode Num: 439 Episode T: 528 Reward: 457.527
# done
# Total T: 202658 Episode Num: 440 Episode T: 532 Reward: 453.600
# done
# Total T: 203189 Episode Num: 441 Episode T: 531 Reward: 454.775
# done
# Total T: 203718 Episode Num: 442 Episode T: 529 Reward: 456.383
# done
# Total T: 204250 Episode Num: 443 Episode T: 532 Reward: 453.502
# done
# Total T: 204780 Episode Num: 444 Episode T: 530 Reward: 455.388
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 452.170
# ---------------------------------------
# done
# Total T: 205001 Episode Num: 445 Episode T: 221 Reward: 808.884
# done
# Total T: 205534 Episode Num: 446 Episode T: 533 Reward: 452.019
# done
# Total T: 206067 Episode Num: 447 Episode T: 533 Reward: 452.139
# done
# Total T: 206596 Episode Num: 448 Episode T: 529 Reward: 456.334
# done
# Total T: 207128 Episode Num: 449 Episode T: 532 Reward: 453.109
# done
# Total T: 207652 Episode Num: 450 Episode T: 524 Reward: 460.882
# done
# Total T: 208182 Episode Num: 451 Episode T: 530 Reward: 455.370
# done
# Total T: 208705 Episode Num: 452 Episode T: 523 Reward: 461.654
# done
# Total T: 209236 Episode Num: 453 Episode T: 531 Reward: 454.494
# done
# Total T: 209757 Episode Num: 454 Episode T: 521 Reward: 463.805
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.138
# ---------------------------------------
# done
# Total T: 210001 Episode Num: 455 Episode T: 244 Reward: 784.266
# done
# Total T: 210526 Episode Num: 456 Episode T: 525 Reward: 459.532
# done
# Total T: 211093 Episode Num: 457 Episode T: 567 Reward: 408.144
# done
# Total T: 211625 Episode Num: 458 Episode T: 532 Reward: 453.719
# done
# Total T: 212156 Episode Num: 459 Episode T: 531 Reward: 454.296
# done
# Total T: 212689 Episode Num: 460 Episode T: 533 Reward: 452.116
# done
# Total T: 213224 Episode Num: 461 Episode T: 535 Reward: 450.807
# done
# Total T: 213753 Episode Num: 462 Episode T: 529 Reward: 456.163
# done
# Total T: 214275 Episode Num: 463 Episode T: 522 Reward: 461.828
# done
# Total T: 214808 Episode Num: 464 Episode T: 533 Reward: 452.273
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.324
# ---------------------------------------
# done
# Total T: 215001 Episode Num: 465 Episode T: 193 Reward: 834.802
# done
# Total T: 215533 Episode Num: 466 Episode T: 532 Reward: 453.195
# done
# Total T: 216058 Episode Num: 467 Episode T: 525 Reward: 460.112
# done
# Total T: 216587 Episode Num: 468 Episode T: 529 Reward: 456.977
# done
# Total T: 217120 Episode Num: 469 Episode T: 533 Reward: 452.112
# done
# Total T: 217639 Episode Num: 470 Episode T: 519 Reward: 465.875
# done
# Total T: 218173 Episode Num: 471 Episode T: 534 Reward: 447.949
# done
# Total T: 218700 Episode Num: 472 Episode T: 527 Reward: 458.020
# done
# Total T: 219231 Episode Num: 473 Episode T: 531 Reward: 453.918
# done
# Total T: 219765 Episode Num: 474 Episode T: 534 Reward: 451.845
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.572
# ---------------------------------------
# done
# Total T: 220001 Episode Num: 475 Episode T: 236 Reward: 793.318
# done
# Total T: 220530 Episode Num: 476 Episode T: 529 Reward: 456.207
# done
# Total T: 221063 Episode Num: 477 Episode T: 533 Reward: 452.231
# done
# Total T: 221594 Episode Num: 478 Episode T: 531 Reward: 454.265
# done
# Total T: 222119 Episode Num: 479 Episode T: 525 Reward: 461.653
# done
# Total T: 222651 Episode Num: 480 Episode T: 532 Reward: 453.511
# done
# Total T: 223183 Episode Num: 481 Episode T: 532 Reward: 453.606
# done
# Total T: 223714 Episode Num: 482 Episode T: 531 Reward: 454.378
# done
# Total T: 224247 Episode Num: 483 Episode T: 533 Reward: 452.422
# done
# Total T: 224779 Episode Num: 484 Episode T: 532 Reward: 453.392
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.667
# ---------------------------------------
# done
# Total T: 225001 Episode Num: 485 Episode T: 222 Reward: 807.950
# done
# Total T: 225535 Episode Num: 486 Episode T: 534 Reward: 451.733
# done
# Total T: 226067 Episode Num: 487 Episode T: 532 Reward: 453.256
# done
# Total T: 226611 Episode Num: 488 Episode T: 544 Reward: 443.708
# done
# Total T: 227144 Episode Num: 489 Episode T: 533 Reward: 452.074
# done
# Total T: 227674 Episode Num: 490 Episode T: 530 Reward: 452.819
# done
# Total T: 228199 Episode Num: 491 Episode T: 525 Reward: 459.848
# done
# Total T: 228735 Episode Num: 492 Episode T: 536 Reward: 449.060
# done
# Total T: 229267 Episode Num: 493 Episode T: 532 Reward: 452.978
# done
# Total T: 229799 Episode Num: 494 Episode T: 532 Reward: 452.995
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.944
# ---------------------------------------
# done
# Total T: 230001 Episode Num: 495 Episode T: 202 Reward: 826.772
# done
# Total T: 230524 Episode Num: 496 Episode T: 523 Reward: 461.975
# done
# Total T: 231053 Episode Num: 497 Episode T: 529 Reward: 456.297
# done
# Total T: 231584 Episode Num: 498 Episode T: 531 Reward: 454.676
# done
# Total T: 232120 Episode Num: 499 Episode T: 536 Reward: 449.305
# done
# Total T: 232646 Episode Num: 500 Episode T: 526 Reward: 458.678
# done
# Total T: 233174 Episode Num: 501 Episode T: 528 Reward: 457.373
# done
# Total T: 233703 Episode Num: 502 Episode T: 529 Reward: 456.113
# done
# Total T: 234236 Episode Num: 503 Episode T: 533 Reward: 451.974
# done
# Total T: 234769 Episode Num: 504 Episode T: 533 Reward: 452.739
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.629
# ---------------------------------------
# done
# Total T: 235001 Episode Num: 505 Episode T: 232 Reward: 797.771
# done
# Total T: 235535 Episode Num: 506 Episode T: 534 Reward: 451.158
# done
# Total T: 236065 Episode Num: 507 Episode T: 530 Reward: 455.231
# done
# Total T: 236595 Episode Num: 508 Episode T: 530 Reward: 455.291
# done
# Total T: 237125 Episode Num: 509 Episode T: 530 Reward: 455.080
# done
# Total T: 237658 Episode Num: 510 Episode T: 533 Reward: 452.037
# done
# Total T: 238193 Episode Num: 511 Episode T: 535 Reward: 450.443
# done
# Total T: 238724 Episode Num: 512 Episode T: 531 Reward: 454.028
# done
# Total T: 239253 Episode Num: 513 Episode T: 529 Reward: 456.293
# done
# Total T: 239781 Episode Num: 514 Episode T: 528 Reward: 457.067
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 453.281
# ---------------------------------------
# done
# Total T: 240001 Episode Num: 515 Episode T: 220 Reward: 810.040
# done
# Total T: 240533 Episode Num: 516 Episode T: 532 Reward: 453.707
# done
# Total T: 241059 Episode Num: 517 Episode T: 526 Reward: 459.870
# done
# Total T: 241589 Episode Num: 518 Episode T: 530 Reward: 455.168
# done
# Total T: 242121 Episode Num: 519 Episode T: 532 Reward: 453.172
# done
# Total T: 242651 Episode Num: 520 Episode T: 530 Reward: 455.278
# done
# Total T: 243180 Episode Num: 521 Episode T: 529 Reward: 456.132
# done
# Total T: 243710 Episode Num: 522 Episode T: 530 Reward: 455.342
# done
# Total T: 244240 Episode Num: 523 Episode T: 530 Reward: 455.185
# done
# Total T: 244772 Episode Num: 524 Episode T: 532 Reward: 453.162
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.399
# ---------------------------------------
# done
# Total T: 245001 Episode Num: 525 Episode T: 229 Reward: 800.964
# done
# Total T: 245524 Episode Num: 526 Episode T: 523 Reward: 461.568
# done
# Total T: 246055 Episode Num: 527 Episode T: 531 Reward: 454.481
# done
# Total T: 246585 Episode Num: 528 Episode T: 530 Reward: 454.598
# done
# Total T: 247115 Episode Num: 529 Episode T: 530 Reward: 455.373
# done
# Total T: 247646 Episode Num: 530 Episode T: 531 Reward: 454.220
# done
# Total T: 248179 Episode Num: 531 Episode T: 533 Reward: 452.216
# done
# Total T: 248710 Episode Num: 532 Episode T: 531 Reward: 454.260
# done
# Total T: 249241 Episode Num: 533 Episode T: 531 Reward: 454.270
# done
# Total T: 249773 Episode Num: 534 Episode T: 532 Reward: 453.413
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.413
# ---------------------------------------
# done
# Total T: 250001 Episode Num: 535 Episode T: 228 Reward: 801.854
# done
# Total T: 250531 Episode Num: 536 Episode T: 530 Reward: 455.257
# done
# Total T: 251061 Episode Num: 537 Episode T: 530 Reward: 455.538
# done
# Total T: 251592 Episode Num: 538 Episode T: 531 Reward: 454.246
# done
# Total T: 252120 Episode Num: 539 Episode T: 528 Reward: 456.968
# done
# Total T: 252651 Episode Num: 540 Episode T: 531 Reward: 454.324
# done
# Total T: 253182 Episode Num: 541 Episode T: 531 Reward: 454.725
# done
# Total T: 253714 Episode Num: 542 Episode T: 532 Reward: 453.396
# done
# Total T: 254244 Episode Num: 543 Episode T: 530 Reward: 455.489
# done
# Total T: 254775 Episode Num: 544 Episode T: 531 Reward: 454.310
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.542
# ---------------------------------------
# done
# Total T: 255001 Episode Num: 545 Episode T: 226 Reward: 803.974
# done
# Total T: 255533 Episode Num: 546 Episode T: 532 Reward: 453.460
# done
# Total T: 256064 Episode Num: 547 Episode T: 531 Reward: 454.274
# done
# Total T: 256591 Episode Num: 548 Episode T: 527 Reward: 457.609
# done
# Total T: 257124 Episode Num: 549 Episode T: 533 Reward: 452.489
# done
# Total T: 257653 Episode Num: 550 Episode T: 529 Reward: 456.219
# done
# Total T: 258184 Episode Num: 551 Episode T: 531 Reward: 454.777
# done
# Total T: 258715 Episode Num: 552 Episode T: 531 Reward: 454.370
# done
# ...
# done
# Total T: 409249 Episode Num: 853 Episode T: 529 Reward: 456.496
# done
# Total T: 409779 Episode Num: 854 Episode T: 530 Reward: 455.279
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -1574.611
# ---------------------------------------
# too much error
# Total T: 410001 Episode Num: 855 Episode T: 222 Reward: -1192.276
# done
# Total T: 410530 Episode Num: 856 Episode T: 529 Reward: 456.274
# done
# Total T: 411060 Episode Num: 857 Episode T: 530 Reward: 455.152
# done
# Total T: 411591 Episode Num: 858 Episode T: 531 Reward: 453.905
# done
# Total T: 412121 Episode Num: 859 Episode T: 530 Reward: 455.072
# done
# Total T: 412701 Episode Num: 860 Episode T: 580 Reward: 392.245
# done
# Total T: 413232 Episode Num: 861 Episode T: 531 Reward: 454.260
# done
# Total T: 413765 Episode Num: 862 Episode T: 533 Reward: 452.255
# done
# Total T: 414294 Episode Num: 863 Episode T: 529 Reward: 456.339
# done
# Total T: 414823 Episode Num: 864 Episode T: 529 Reward: 456.413
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.366
# ---------------------------------------
# done
# Total T: 415001 Episode Num: 865 Episode T: 178 Reward: 847.945
# done
# Total T: 415533 Episode Num: 866 Episode T: 532 Reward: 453.067
# done
# Total T: 416061 Episode Num: 867 Episode T: 528 Reward: 457.369
# done
# Total T: 416588 Episode Num: 868 Episode T: 527 Reward: 457.955
# done
# Total T: 417117 Episode Num: 869 Episode T: 529 Reward: 456.078
# done
# Total T: 417646 Episode Num: 870 Episode T: 529 Reward: 456.379
# done
# Total T: 418175 Episode Num: 871 Episode T: 529 Reward: 456.137
# done
# Total T: 418704 Episode Num: 872 Episode T: 529 Reward: 456.150
# done
# Total T: 419234 Episode Num: 873 Episode T: 530 Reward: 455.228
# done
# Total T: 419767 Episode Num: 874 Episode T: 533 Reward: 451.174
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.461
# ---------------------------------------
# done
# Total T: 420001 Episode Num: 875 Episode T: 234 Reward: 795.663
# done
# Total T: 420530 Episode Num: 876 Episode T: 529 Reward: 456.242
# done
# Total T: 421059 Episode Num: 877 Episode T: 529 Reward: 456.207
# done
# Total T: 421588 Episode Num: 878 Episode T: 529 Reward: 456.598
# done
# Total T: 422116 Episode Num: 879 Episode T: 528 Reward: 457.519
# done
# Total T: 422647 Episode Num: 880 Episode T: 531 Reward: 453.505
# done
# Total T: 423175 Episode Num: 881 Episode T: 528 Reward: 456.426
# done
# Total T: 423707 Episode Num: 882 Episode T: 532 Reward: 450.460
# done
# Total T: 424236 Episode Num: 883 Episode T: 529 Reward: 456.081
# done
# Total T: 424765 Episode Num: 884 Episode T: 529 Reward: 456.198
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 452.349
# ---------------------------------------
# done
# Total T: 425001 Episode Num: 885 Episode T: 236 Reward: 793.613
# done
# Total T: 425531 Episode Num: 886 Episode T: 530 Reward: 455.331
# done
# Total T: 426063 Episode Num: 887 Episode T: 532 Reward: 453.133
# done
# Total T: 426593 Episode Num: 888 Episode T: 530 Reward: 455.104
# done
# Total T: 427123 Episode Num: 889 Episode T: 530 Reward: 455.214
# done
# Total T: 427653 Episode Num: 890 Episode T: 530 Reward: 455.130
# done
# Total T: 428186 Episode Num: 891 Episode T: 533 Reward: 449.964
# done
# Total T: 428714 Episode Num: 892 Episode T: 528 Reward: 457.159
# done
# Total T: 429245 Episode Num: 893 Episode T: 531 Reward: 454.192
# done
# Total T: 429774 Episode Num: 894 Episode T: 529 Reward: 456.000
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.243
# ---------------------------------------
# done
# Total T: 430001 Episode Num: 895 Episode T: 227 Reward: 802.694
# done
# Total T: 430533 Episode Num: 896 Episode T: 532 Reward: 453.224
# done
# Total T: 431063 Episode Num: 897 Episode T: 530 Reward: 455.210
# done
# Total T: 431592 Episode Num: 898 Episode T: 529 Reward: 456.150
# done
# Total T: 432121 Episode Num: 899 Episode T: 529 Reward: 456.214
# done
# Total T: 432649 Episode Num: 900 Episode T: 528 Reward: 457.031
# too much error
# Total T: 433213 Episode Num: 901 Episode T: 564 Reward: -1585.237
# done
# Total T: 433736 Episode Num: 902 Episode T: 523 Reward: 461.260
# done
# Total T: 434266 Episode Num: 903 Episode T: 530 Reward: 455.490
# done
# Total T: 434797 Episode Num: 904 Episode T: 531 Reward: 454.205
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.035
# ---------------------------------------
# done
# Total T: 435001 Episode Num: 905 Episode T: 204 Reward: 824.739
# done
# Total T: 435532 Episode Num: 906 Episode T: 531 Reward: 454.446
# done
# Total T: 436056 Episode Num: 907 Episode T: 524 Reward: 460.635
# done
# Total T: 436586 Episode Num: 908 Episode T: 530 Reward: 455.193
# done
# Total T: 437115 Episode Num: 909 Episode T: 529 Reward: 456.259
# done
# Total T: 437647 Episode Num: 910 Episode T: 532 Reward: 453.275
# done
# Total T: 438175 Episode Num: 911 Episode T: 528 Reward: 456.902
# done
# Total T: 438706 Episode Num: 912 Episode T: 531 Reward: 454.043
# done
# Total T: 439237 Episode Num: 913 Episode T: 531 Reward: 454.342
# done
# Total T: 439774 Episode Num: 914 Episode T: 537 Reward: 445.542
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 456.454
# ---------------------------------------
# done
# Total T: 440001 Episode Num: 915 Episode T: 227 Reward: 802.766
# done
# Total T: 440527 Episode Num: 916 Episode T: 526 Reward: 459.337
# done
# Total T: 441058 Episode Num: 917 Episode T: 531 Reward: 453.867
# too much error
# Total T: 441616 Episode Num: 918 Episode T: 558 Reward: -1578.663
# done
# Total T: 442145 Episode Num: 919 Episode T: 529 Reward: 456.034
# done
# Total T: 442673 Episode Num: 920 Episode T: 528 Reward: 456.943
# done
# Total T: 443202 Episode Num: 921 Episode T: 529 Reward: 456.313
# done
# Total T: 443733 Episode Num: 922 Episode T: 531 Reward: 454.124
# done
# Total T: 444262 Episode Num: 923 Episode T: 529 Reward: 456.232
# done
# Total T: 444795 Episode Num: 924 Episode T: 533 Reward: 451.120
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.104
# ---------------------------------------
# done
# Total T: 445001 Episode Num: 925 Episode T: 206 Reward: 822.879
# done
# Total T: 445528 Episode Num: 926 Episode T: 527 Reward: 458.539
# done
# Total T: 446059 Episode Num: 927 Episode T: 531 Reward: 454.387
# done
# Total T: 446591 Episode Num: 928 Episode T: 532 Reward: 453.248
# done
# Total T: 447112 Episode Num: 929 Episode T: 521 Reward: 465.212
# done
# Total T: 447640 Episode Num: 930 Episode T: 528 Reward: 457.153
# done
# Total T: 448169 Episode Num: 931 Episode T: 529 Reward: 456.211
# done
# Total T: 448699 Episode Num: 932 Episode T: 530 Reward: 455.023
# done
# Total T: 449228 Episode Num: 933 Episode T: 529 Reward: 456.316
# done
# Total T: 449753 Episode Num: 934 Episode T: 525 Reward: 458.380
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 430.241
# ---------------------------------------
# done
# Total T: 450001 Episode Num: 935 Episode T: 248 Reward: 779.446
# done
# Total T: 450529 Episode Num: 936 Episode T: 528 Reward: 457.063
# done
# Total T: 451055 Episode Num: 937 Episode T: 526 Reward: 459.342
# done
# Total T: 451591 Episode Num: 938 Episode T: 536 Reward: 449.061
# done
# Total T: 452116 Episode Num: 939 Episode T: 525 Reward: 460.028
# done
# Total T: 452643 Episode Num: 940 Episode T: 527 Reward: 458.189
# done
# Total T: 453172 Episode Num: 941 Episode T: 529 Reward: 456.479
# done
# Total T: 453702 Episode Num: 942 Episode T: 530 Reward: 455.022
# done
# Total T: 454232 Episode Num: 943 Episode T: 530 Reward: 455.303
# done
# Total T: 454763 Episode Num: 944 Episode T: 531 Reward: 453.045
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 457.247
# ---------------------------------------
# done
# Total T: 455001 Episode Num: 945 Episode T: 238 Reward: 791.441
# done
# Total T: 455531 Episode Num: 946 Episode T: 530 Reward: 455.617
# done
# Total T: 456059 Episode Num: 947 Episode T: 528 Reward: 457.207
# done
# Total T: 456616 Episode Num: 948 Episode T: 557 Reward: 425.279
# done
# Total T: 457146 Episode Num: 949 Episode T: 530 Reward: 455.474
# done
# Total T: 457676 Episode Num: 950 Episode T: 530 Reward: 454.990
# done
# Total T: 458204 Episode Num: 951 Episode T: 528 Reward: 457.126
# done
# Total T: 458735 Episode Num: 952 Episode T: 531 Reward: 454.157
# done
# Total T: 459265 Episode Num: 953 Episode T: 530 Reward: 455.144
# done
# Total T: 459793 Episode Num: 954 Episode T: 528 Reward: 457.668
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 441.092
# ---------------------------------------
# done
# Total T: 460001 Episode Num: 955 Episode T: 208 Reward: 821.011
# too much error
# Total T: 460566 Episode Num: 956 Episode T: 565 Reward: -1586.943
# done
# Total T: 461096 Episode Num: 957 Episode T: 530 Reward: 455.317
# done
# Total T: 461625 Episode Num: 958 Episode T: 529 Reward: 456.016
# done
# Total T: 462157 Episode Num: 959 Episode T: 532 Reward: 453.427
# done
# Total T: 462684 Episode Num: 960 Episode T: 527 Reward: 457.908
# done
# Total T: 463214 Episode Num: 961 Episode T: 530 Reward: 455.112
# done
# Total T: 463744 Episode Num: 962 Episode T: 530 Reward: 455.290
# done
# Total T: 464275 Episode Num: 963 Episode T: 531 Reward: 454.888
# done
# Total T: 464802 Episode Num: 964 Episode T: 527 Reward: 458.375
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 457.336
# ---------------------------------------
# done
# Total T: 465001 Episode Num: 965 Episode T: 199 Reward: 829.288
# done
# Total T: 465530 Episode Num: 966 Episode T: 529 Reward: 455.936
# done
# Total T: 466058 Episode Num: 967 Episode T: 528 Reward: 457.267
# done
# Total T: 466586 Episode Num: 968 Episode T: 528 Reward: 457.059
# done
# Total T: 467117 Episode Num: 969 Episode T: 531 Reward: 454.388
# done
# Total T: 467642 Episode Num: 970 Episode T: 525 Reward: 459.671
# done
# Total T: 468170 Episode Num: 971 Episode T: 528 Reward: 457.207
# done
# Total T: 468700 Episode Num: 972 Episode T: 530 Reward: 454.850
# done
# Total T: 469234 Episode Num: 973 Episode T: 534 Reward: 450.604
# done
# Total T: 469764 Episode Num: 974 Episode T: 530 Reward: 454.854
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 457.228
# ---------------------------------------
# done
# Total T: 470001 Episode Num: 975 Episode T: 237 Reward: 792.294
# done
# Total T: 470526 Episode Num: 976 Episode T: 525 Reward: 460.478
# done
# Total T: 471106 Episode Num: 977 Episode T: 580 Reward: 391.950
# done
# Total T: 471634 Episode Num: 978 Episode T: 528 Reward: 457.163
# done
# Total T: 472162 Episode Num: 979 Episode T: 528 Reward: 457.340
# done
# Total T: 472699 Episode Num: 980 Episode T: 537 Reward: 445.544
# done
# Total T: 473228 Episode Num: 981 Episode T: 529 Reward: 456.053
# done
# Total T: 473758 Episode Num: 982 Episode T: 530 Reward: 455.288
# done
# Total T: 474283 Episode Num: 983 Episode T: 525 Reward: 459.423
# done
# Total T: 474813 Episode Num: 984 Episode T: 530 Reward: 454.719
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 443.657
# ---------------------------------------
# done
# Total T: 475001 Episode Num: 985 Episode T: 188 Reward: 839.286
# done
# Total T: 475531 Episode Num: 986 Episode T: 530 Reward: 454.841
# done
# Total T: 476059 Episode Num: 987 Episode T: 528 Reward: 457.485
# done
# Total T: 476587 Episode Num: 988 Episode T: 528 Reward: 457.257
# done
# Total T: 477116 Episode Num: 989 Episode T: 529 Reward: 456.153
# done
# Total T: 477645 Episode Num: 990 Episode T: 529 Reward: 455.937
# done
# Total T: 478182 Episode Num: 991 Episode T: 537 Reward: 450.012
# done
# Total T: 478722 Episode Num: 992 Episode T: 540 Reward: 443.799
# done
# Total T: 479265 Episode Num: 993 Episode T: 543 Reward: 440.650
# done
# Total T: 479806 Episode Num: 994 Episode T: 541 Reward: 442.548
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 454.522
# ---------------------------------------
# done
# Total T: 480001 Episode Num: 995 Episode T: 195 Reward: 832.822
# done
# Total T: 480530 Episode Num: 996 Episode T: 529 Reward: 456.141
# done
# Total T: 481063 Episode Num: 997 Episode T: 533 Reward: 451.745
# done
# Total T: 481593 Episode Num: 998 Episode T: 530 Reward: 455.146
# done
# Total T: 482122 Episode Num: 999 Episode T: 529 Reward: 456.235
# done
# Total T: 482651 Episode Num: 1000 Episode T: 529 Reward: 456.620
# done
# Total T: 483189 Episode Num: 1001 Episode T: 538 Reward: 444.315
# done
# Total T: 483717 Episode Num: 1002 Episode T: 528 Reward: 457.140
# done
# Total T: 484247 Episode Num: 1003 Episode T: 530 Reward: 455.315
# done
# Total T: 484779 Episode Num: 1004 Episode T: 532 Reward: 453.338
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.373
# ---------------------------------------
# done
# Total T: 485001 Episode Num: 1005 Episode T: 222 Reward: 807.824
# done
# Total T: 485530 Episode Num: 1006 Episode T: 529 Reward: 456.515
# done
# Total T: 486060 Episode Num: 1007 Episode T: 530 Reward: 455.185
# done
# Total T: 486592 Episode Num: 1008 Episode T: 532 Reward: 453.785
# done
# Total T: 487121 Episode Num: 1009 Episode T: 529 Reward: 456.124
# done
# Total T: 487650 Episode Num: 1010 Episode T: 529 Reward: 456.142
# done
# Total T: 488181 Episode Num: 1011 Episode T: 531 Reward: 453.807
# done
# Total T: 488714 Episode Num: 1012 Episode T: 533 Reward: 450.175
# done
# Total T: 489243 Episode Num: 1013 Episode T: 529 Reward: 456.328
# too much error
# Total T: 489802 Episode Num: 1014 Episode T: 559 Reward: -1580.011
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 457.447
# ---------------------------------------
# done
# Total T: 490001 Episode Num: 1015 Episode T: 199 Reward: 829.234
# done
# Total T: 490533 Episode Num: 1016 Episode T: 532 Reward: 453.615
# done
# Total T: 491066 Episode Num: 1017 Episode T: 533 Reward: 452.280
# done
# Total T: 491595 Episode Num: 1018 Episode T: 529 Reward: 456.504
# done
# Total T: 492125 Episode Num: 1019 Episode T: 530 Reward: 455.164
# done
# Total T: 492662 Episode Num: 1020 Episode T: 537 Reward: 447.140
# done
# Total T: 493192 Episode Num: 1021 Episode T: 530 Reward: 455.248
# done
# Total T: 493725 Episode Num: 1022 Episode T: 533 Reward: 449.592
# done
# Total T: 494250 Episode Num: 1023 Episode T: 525 Reward: 459.876
# too much error
# Total T: 494809 Episode Num: 1024 Episode T: 559 Reward: -1580.059
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 455.363
# ---------------------------------------
# done
# Total T: 495001 Episode Num: 1025 Episode T: 192 Reward: 835.609
# done
# Total T: 495535 Episode Num: 1026 Episode T: 534 Reward: 449.025
# done
# Total T: 496065 Episode Num: 1027 Episode T: 530 Reward: 454.991
# done
# Total T: 496597 Episode Num: 1028 Episode T: 532 Reward: 452.287
# done
# Total T: 497127 Episode Num: 1029 Episode T: 530 Reward: 455.296
# done
# Total T: 497666 Episode Num: 1030 Episode T: 539 Reward: 442.844
# done
# Total T: 498195 Episode Num: 1031 Episode T: 529 Reward: 456.457
# done
# Total T: 498731 Episode Num: 1032 Episode T: 536 Reward: 448.258
# done
# Total T: 499260 Episode Num: 1033 Episode T: 529 Reward: 455.949
# done
# Total T: 499788 Episode Num: 1034 Episode T: 528 Reward: 457.814
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 443.571
# ---------------------------------------

# %%
evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
## run simulation
prev_state= env.reset()
state_array = []
action_array = []
while True:
    # env.render()
    action = policy.select_action(np.array(state))
    state, reward, done, position = env.step(action)
    action_array.append(action)
    episode_reward += reward
    state_array.append(position)
    action_array.append(action)
    if done:
        break
    prev_state = state

state_array = np.array(state_array)
action_array = np.array(action_array)
plt.plot(state_array[:,0], state_array[:,1], label='State')
plt.plot(trajectory[:,0], trajectory[:,1], label='Trajectory')
print(state_array[-1, :])
print(env.steps)
plt.legend()
plt.show()

# plot action
plt.plot(action_array.reshape(len(action_array), 2))
plt.legend()
plt.show()

print(len(action_array))
# Out:
# done
# [ 1.1212658  -0.06279828 -0.01084252  0.14115717]
# 534
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1068
