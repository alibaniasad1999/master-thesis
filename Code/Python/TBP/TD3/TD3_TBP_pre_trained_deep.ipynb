# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
plt.plot(trajectory[:,0], trajectory[:,1])

# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 256)
        self.l4 = nn.Linear(256, action_dim)
        

        self.max_action = max_action

    def forward(self, state):
        a = F.tanh(self.l1(state))
        a = F.tanh(self.l2(a))
        a = F.tanh(self.l3(a))
        return self.max_action * torch.tanh(self.l4(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        # load actor
        self.actor.load_state_dict(torch.load("actor_deep"))
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=5e-7)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=5e-7)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
    eval_env.reset()

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
# three body problem env
import gym
from gym import spaces
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-10, high=10, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.render_logic = False
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        # force = action[0] * env.state[2:] + action[1] * env.state[:2]
        a_x = action[0]/10
        a_y = action[1]/10

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y

        x = x + xdot*self.dt
        y = y + ydot*self.dt

        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        # plot position
        if self.render_logic:
            plt.plot(x, y, 'ro')
            plt.plot(self.trajectory[:,0], self.trajectory[:,1])
            plt.show()

        reward = 1 - np.linalg.norm(self.position - self.trajectory[self.steps], axis=0) # + self.steps
        done = self.steps >= self.max_steps
        if np.linalg.norm(self.position[0:2] - self.trajectory[-1, 0:2]) < 0.01:
            done = True
            reward = 10000
            print("done")
        if self.steps > 1000:
            done = True
            reward = -10000
            print("end time")
        if np.linalg.norm(self.state[0:2]) > 0.05:
            done = True
            reward = -10000
            print("too much error")

        # print(self.state, reward, done, self.position)
        return 1000*self.state, reward, done, self.position

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]

    def reset(self,
              *,
              seed: 5 = None,
              return_info: bool = False,
              options: 6 = None):
        self.position = self.trajectory[0]
        self.steps = 0
        self.position2state()
        return 10000*self.state

    def render(self):
        pass

    def close(self):
        pass


env = three_body_env(trajectory)

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "TBP"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(5e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(5e4)
DEFAULT_EXPL_NOISE = 0.02
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.02
DEFAULT_NOISE_CLIP = 0.02
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ}
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False

episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# ---------------------------------------
# Policy: TD3, Env: TBP, Seed: 0
# ---------------------------------------
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10366.482
# ---------------------------------------

# %%
# evaluations = [eval_policy(policy, env, DEFAULT_SEED)]
for t in range(int(DEFAULT_MAX_TIMESTEPS)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action)
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done:
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# too much error
# Total T: 81 Episode Num: 1 Episode T: 81 Reward: -9935.363
# too much error
# Total T: 166 Episode Num: 2 Episode T: 85 Reward: -9927.828
# too much error
# Total T: 280 Episode Num: 3 Episode T: 114 Reward: -9908.162
# too much error
# Total T: 460 Episode Num: 4 Episode T: 180 Reward: -9878.295
# too much error
# Total T: 567 Episode Num: 5 Episode T: 107 Reward: -9911.003
# too much error
# Total T: 661 Episode Num: 6 Episode T: 94 Reward: -9923.719
# too much error
# Total T: 737 Episode Num: 7 Episode T: 76 Reward: -9936.434
# too much error
# Total T: 940 Episode Num: 8 Episode T: 203 Reward: -9847.211
# too much error
# Total T: 1074 Episode Num: 9 Episode T: 134 Reward: -9903.911
# too much error
# Total T: 1146 Episode Num: 10 Episode T: 72 Reward: -9939.631
# too much error
# Total T: 1266 Episode Num: 11 Episode T: 120 Reward: -9912.284
# too much error
# Total T: 1342 Episode Num: 12 Episode T: 76 Reward: -9938.993
# too much error
# Total T: 1434 Episode Num: 13 Episode T: 92 Reward: -9928.677
# too much error
# Total T: 1560 Episode Num: 14 Episode T: 126 Reward: -9909.934
# too much error
# Total T: 1623 Episode Num: 15 Episode T: 63 Reward: -9946.460
# too much error
# Total T: 1745 Episode Num: 16 Episode T: 122 Reward: -9908.346
# too much error
# Total T: 1825 Episode Num: 17 Episode T: 80 Reward: -9936.268
# too much error
# Total T: 1919 Episode Num: 18 Episode T: 94 Reward: -9922.753
# too much error
# Total T: 2010 Episode Num: 19 Episode T: 91 Reward: -9927.336
# too much error
# Total T: 2092 Episode Num: 20 Episode T: 82 Reward: -9933.560
# too much error
# Total T: 2192 Episode Num: 21 Episode T: 100 Reward: -9918.993
# too much error
# Total T: 2374 Episode Num: 22 Episode T: 182 Reward: -9863.780
# too much error
# Total T: 2501 Episode Num: 23 Episode T: 127 Reward: -9902.806
# too much error
# Total T: 2587 Episode Num: 24 Episode T: 86 Reward: -9929.001
# too much error
# Total T: 2650 Episode Num: 25 Episode T: 63 Reward: -9947.990
# too much error
# Total T: 2757 Episode Num: 26 Episode T: 107 Reward: -9919.752
# too much error
# Total T: 2883 Episode Num: 27 Episode T: 126 Reward: -9902.455
# too much error
# Total T: 2994 Episode Num: 28 Episode T: 111 Reward: -9913.533
# too much error
# Total T: 3107 Episode Num: 29 Episode T: 113 Reward: -9912.223
# too much error
# Total T: 3200 Episode Num: 30 Episode T: 93 Reward: -9925.711
# too much error
# Total T: 3288 Episode Num: 31 Episode T: 88 Reward: -9929.342
# too much error
# Total T: 3379 Episode Num: 32 Episode T: 91 Reward: -9931.346
# too much error
# Total T: 3465 Episode Num: 33 Episode T: 86 Reward: -9934.544
# too much error
# Total T: 3554 Episode Num: 34 Episode T: 89 Reward: -9932.907
# too much error
# Total T: 3713 Episode Num: 35 Episode T: 159 Reward: -9880.863
# too much error
# Total T: 3800 Episode Num: 36 Episode T: 87 Reward: -9929.378
# too much error
# Total T: 3888 Episode Num: 37 Episode T: 88 Reward: -9932.783
# too much error
# Total T: 3976 Episode Num: 38 Episode T: 88 Reward: -9930.314
# too much error
# Total T: 4069 Episode Num: 39 Episode T: 93 Reward: -9924.684
# too much error
# Total T: 4173 Episode Num: 40 Episode T: 104 Reward: -9920.520
# too much error
# Total T: 4260 Episode Num: 41 Episode T: 87 Reward: -9935.907
# too much error
# Total T: 4358 Episode Num: 42 Episode T: 98 Reward: -9922.138
# too much error
# Total T: 4462 Episode Num: 43 Episode T: 104 Reward: -9922.325
# too much error
# Total T: 4552 Episode Num: 44 Episode T: 90 Reward: -9929.842
# too much error
# Total T: 4665 Episode Num: 45 Episode T: 113 Reward: -9918.766
# too much error
# Total T: 4758 Episode Num: 46 Episode T: 93 Reward: -9924.151
# too much error
# Total T: 4869 Episode Num: 47 Episode T: 111 Reward: -9913.683
# too much error
# Total T: 4934 Episode Num: 48 Episode T: 65 Reward: -9945.121
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10366.482
# ---------------------------------------
# done
# Total T: 5001 Episode Num: 49 Episode T: 67 Reward: 10058.312
# done
# Total T: 5538 Episode Num: 50 Episode T: 537 Reward: 10365.799
# done
# Total T: 6076 Episode Num: 51 Episode T: 538 Reward: 10366.559
# done
# Total T: 6614 Episode Num: 52 Episode T: 538 Reward: 10366.574
# done
# Total T: 7152 Episode Num: 53 Episode T: 538 Reward: 10366.562
# done
# Total T: 7690 Episode Num: 54 Episode T: 538 Reward: 10366.478
# done
# Total T: 8228 Episode Num: 55 Episode T: 538 Reward: 10366.602
# done
# Total T: 8766 Episode Num: 56 Episode T: 538 Reward: 10366.481
# done
# Total T: 9304 Episode Num: 57 Episode T: 538 Reward: 10366.506
# done
# Total T: 9842 Episode Num: 58 Episode T: 538 Reward: 10366.487
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10366.517
# ---------------------------------------
# done
# Total T: 10001 Episode Num: 59 Episode T: 159 Reward: 10116.726
# done
# Total T: 10538 Episode Num: 60 Episode T: 537 Reward: 10365.801
# done
# Total T: 11076 Episode Num: 61 Episode T: 538 Reward: 10366.474
# done
# Total T: 11613 Episode Num: 62 Episode T: 537 Reward: 10365.811
# done
# Total T: 12151 Episode Num: 63 Episode T: 538 Reward: 10366.483
# done
# Total T: 12689 Episode Num: 64 Episode T: 538 Reward: 10366.534
# done
# Total T: 13227 Episode Num: 65 Episode T: 538 Reward: 10366.525
# done
# Total T: 13763 Episode Num: 66 Episode T: 536 Reward: 10365.017
# done
# Total T: 14301 Episode Num: 67 Episode T: 538 Reward: 10366.499
# done
# Total T: 14838 Episode Num: 68 Episode T: 537 Reward: 10365.770
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10366.491
# ---------------------------------------
# done
# Total T: 15001 Episode Num: 69 Episode T: 163 Reward: 10119.567
# done
# Total T: 15539 Episode Num: 70 Episode T: 538 Reward: 10366.433
# done
# Total T: 16076 Episode Num: 71 Episode T: 537 Reward: 10365.732
# done
# Total T: 16613 Episode Num: 72 Episode T: 537 Reward: 10365.683
# done
# Total T: 17151 Episode Num: 73 Episode T: 538 Reward: 10366.605
# done
# Total T: 17689 Episode Num: 74 Episode T: 538 Reward: 10366.525
# done
# Total T: 18227 Episode Num: 75 Episode T: 538 Reward: 10366.495
# done
# Total T: 18765 Episode Num: 76 Episode T: 538 Reward: 10366.511
# done
# Total T: 19302 Episode Num: 77 Episode T: 537 Reward: 10365.699
# done
# Total T: 19839 Episode Num: 78 Episode T: 537 Reward: 10365.787
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10365.819
# ---------------------------------------
# done
# Total T: 20001 Episode Num: 79 Episode T: 162 Reward: 10118.854
# done
# Total T: 20538 Episode Num: 80 Episode T: 537 Reward: 10365.744
# done
# Total T: 21075 Episode Num: 81 Episode T: 537 Reward: 10365.783
# done
# Total T: 21612 Episode Num: 82 Episode T: 537 Reward: 10365.695
# done
# Total T: 22148 Episode Num: 83 Episode T: 536 Reward: 10364.934
# done
# Total T: 22685 Episode Num: 84 Episode T: 537 Reward: 10365.814
# done
# Total T: 23222 Episode Num: 85 Episode T: 537 Reward: 10365.748
# done
# Total T: 23760 Episode Num: 86 Episode T: 538 Reward: 10366.553
# done
# Total T: 24298 Episode Num: 87 Episode T: 538 Reward: 10366.529
# done
# Total T: 24834 Episode Num: 88 Episode T: 536 Reward: 10365.044
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10365.825
# ---------------------------------------
# done
# Total T: 25001 Episode Num: 89 Episode T: 167 Reward: 10122.472
# done
# Total T: 25537 Episode Num: 90 Episode T: 536 Reward: 10365.000
# done
# Total T: 26074 Episode Num: 91 Episode T: 537 Reward: 10365.820
# done
# Total T: 26611 Episode Num: 92 Episode T: 537 Reward: 10365.831
# done
# Total T: 27148 Episode Num: 93 Episode T: 537 Reward: 10365.789
# done
# Total T: 27685 Episode Num: 94 Episode T: 537 Reward: 10365.792
# done
# Total T: 28222 Episode Num: 95 Episode T: 537 Reward: 10365.754
# done
# Total T: 28759 Episode Num: 96 Episode T: 537 Reward: 10365.839
# done
# Total T: 29295 Episode Num: 97 Episode T: 536 Reward: 10365.041
# done
# Total T: 29832 Episode Num: 98 Episode T: 537 Reward: 10365.734
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10365.787
# ---------------------------------------
# done
# Total T: 30001 Episode Num: 99 Episode T: 169 Reward: 10123.877
# done
# Total T: 30538 Episode Num: 100 Episode T: 537 Reward: 10365.788
# done
# Total T: 31075 Episode Num: 101 Episode T: 537 Reward: 10365.704
# done
# Total T: 31611 Episode Num: 102 Episode T: 536 Reward: 10365.009
# done
# Total T: 32147 Episode Num: 103 Episode T: 536 Reward: 10365.044
# done
# Total T: 32683 Episode Num: 104 Episode T: 536 Reward: 10365.064
# done
# Total T: 33220 Episode Num: 105 Episode T: 537 Reward: 10365.841
# done
# Total T: 33757 Episode Num: 106 Episode T: 537 Reward: 10365.775
# done
# Total T: 34293 Episode Num: 107 Episode T: 536 Reward: 10365.022
# done
# Total T: 34829 Episode Num: 108 Episode T: 536 Reward: 10365.066
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10365.086
# ---------------------------------------
# done
# Total T: 35001 Episode Num: 109 Episode T: 172 Reward: 10126.072
# done
# Total T: 35538 Episode Num: 110 Episode T: 537 Reward: 10365.868
# done
# Total T: 36074 Episode Num: 111 Episode T: 536 Reward: 10365.097
# done
# Total T: 36610 Episode Num: 112 Episode T: 536 Reward: 10365.005
# done
# Total T: 37144 Episode Num: 113 Episode T: 534 Reward: 10363.351
# done
# Total T: 37678 Episode Num: 114 Episode T: 534 Reward: 10363.353
# done
# Total T: 38214 Episode Num: 115 Episode T: 536 Reward: 10365.011
# done
# Total T: 38749 Episode Num: 116 Episode T: 535 Reward: 10364.260
# done
# Total T: 39284 Episode Num: 117 Episode T: 535 Reward: 10364.287
# done
# Total T: 39818 Episode Num: 118 Episode T: 534 Reward: 10363.431
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10362.703
# ---------------------------------------
# done
# Total T: 40001 Episode Num: 119 Episode T: 183 Reward: 10134.286
# done
# Total T: 40534 Episode Num: 120 Episode T: 533 Reward: 10362.696
# done
# Total T: 41067 Episode Num: 121 Episode T: 533 Reward: 10362.605
# done
# Total T: 41602 Episode Num: 122 Episode T: 535 Reward: 10364.259
# done
# Total T: 42137 Episode Num: 123 Episode T: 535 Reward: 10364.266
# done
# Total T: 42670 Episode Num: 124 Episode T: 533 Reward: 10362.501
# done
# Total T: 43204 Episode Num: 125 Episode T: 534 Reward: 10363.397
# done
# Total T: 43739 Episode Num: 126 Episode T: 535 Reward: 10364.268
# done
# Total T: 44271 Episode Num: 127 Episode T: 532 Reward: 10361.710
# done
# Total T: 44805 Episode Num: 128 Episode T: 534 Reward: 10363.479
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10361.747
# ---------------------------------------
# done
# Total T: 45001 Episode Num: 129 Episode T: 196 Reward: 10144.442
# done
# Total T: 45535 Episode Num: 130 Episode T: 534 Reward: 10363.535
# done
# Total T: 46067 Episode Num: 131 Episode T: 532 Reward: 10361.770
# done
# Total T: 46598 Episode Num: 132 Episode T: 531 Reward: 10360.383
# done
# Total T: 47129 Episode Num: 133 Episode T: 531 Reward: 10361.015
# done
# Total T: 47661 Episode Num: 134 Episode T: 532 Reward: 10361.773
# done
# Total T: 48194 Episode Num: 135 Episode T: 533 Reward: 10362.350
# done
# Total T: 48751 Episode Num: 136 Episode T: 557 Reward: 10373.432
# done
# Total T: 49284 Episode Num: 137 Episode T: 533 Reward: 10362.345
# too much error
# Total T: 49600 Episode Num: 138 Episode T: 316 Reward: -9786.900
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ---------------------------------------
# Evaluation over 10 episodes: 10362.857
# ---------------------------------------

# %%
evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
## run simulation
prev_state= env.reset()
state_array = []
action_array = []
while True:
    # env.render()
    action = policy.select_action(np.array(state))
    state, reward, done, position = env.step(action)
    action_array.append(action)
    episode_reward += reward
    state_array.append(position)
    action_array.append(action)
    if done:
        break
    prev_state = state

state_array = np.array(state_array)
action_array = np.array(action_array)
plt.plot(state_array[:,0], state_array[:,1], label='State')
plt.plot(trajectory[:,0], trajectory[:,1], label='Trajectory')
print(state_array[-1, :])
print(env.steps)
plt.legend()
plt.show()

# plot action
plt.plot(action_array.reshape(len(action_array), 2))
plt.legend()
plt.show()

print(len(action_array))
# Out:
# done
# [ 1.11854181 -0.06318094 -0.01561979  0.13318695]
# 532
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1064
