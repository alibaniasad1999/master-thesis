# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
plt.plot(trajectory[:,0], trajectory[:,1])

# %%
import copy
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Implementation of Twin Delayed Deep Deterministic Policy Gradients (TD3)
# Paper: https://arxiv.org/abs/1802.09477


class Actor(nn.Module):
    def __init__(self, state_dim, action_dim, max_action):
        super(Actor, self).__init__()

        self.l1 = nn.Linear(state_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, action_dim)

        self.max_action = max_action

    def forward(self, state):
        a = F.tanh(self.l1(state))
        a = F.tanh(self.l2(a))
        # a = F.tanh(self.l3(a))
        return self.max_action * torch.tanh(self.l3(a))


class Critic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(Critic, self).__init__()

        # Q1 architecture
        self.l1 = nn.Linear(state_dim + action_dim, 256)
        self.l2 = nn.Linear(256, 256)
        self.l3 = nn.Linear(256, 1)

        # Q2 architecture
        self.l4 = nn.Linear(state_dim + action_dim, 256)
        self.l5 = nn.Linear(256, 256)
        self.l6 = nn.Linear(256, 1)

    def forward(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)

        q2 = F.relu(self.l4(sa))
        q2 = F.relu(self.l5(q2))
        q2 = self.l6(q2)
        return q1, q2

    def Q1(self, state, action):
        sa = torch.cat([state, action], 1)

        q1 = F.relu(self.l1(sa))
        q1 = F.relu(self.l2(q1))
        q1 = self.l3(q1)
        return q1


class TD3(object):
    def __init__(
            self,
            state_dim,
            action_dim,
            max_action,
            discount=0.99,
            tau=0.005,
            policy_noise=0.2,
            noise_clip=0.5,
            policy_freq=2
    ):

        self.actor = Actor(state_dim, action_dim, max_action).to(device)
        self.actor_target = copy.deepcopy(self.actor)
        self.actor_optimizer = torch.optim.Adam(self.actor.parameters(), lr=3e-6)

        self.critic = Critic(state_dim, action_dim).to(device)
        self.critic_target = copy.deepcopy(self.critic)
        self.critic_optimizer = torch.optim.Adam(self.critic.parameters(), lr=3e-6)

        self.max_action = max_action
        self.discount = discount
        self.tau = tau
        self.policy_noise = policy_noise
        self.noise_clip = noise_clip
        self.policy_freq = policy_freq

        self.total_it = 0

    def select_action(self, state):
        state = torch.FloatTensor(state.reshape(1, -1)).to(device)
        return self.actor(state).cpu().data.numpy().flatten()

    def train(self, replay_buffer, batch_size=256):
        self.total_it += 1

        # Sample replay buffer
        state, action, next_state, reward, not_done = replay_buffer.sample(batch_size)

        with torch.no_grad():
            # Select action according to policy and add clipped noise
            noise = (
                    torch.randn_like(action) * self.policy_noise
            ).clamp(-self.noise_clip, self.noise_clip)

            next_action = (
                    self.actor_target(next_state) + noise
            ).clamp(-self.max_action, self.max_action)

            # Compute the target Q value
            target_Q1, target_Q2 = self.critic_target(next_state, next_action)
            target_Q = torch.min(target_Q1, target_Q2)
            target_Q = reward + not_done * self.discount * target_Q

        # Get current Q estimates
        current_Q1, current_Q2 = self.critic(state, action)

        # Compute critic loss
        critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)

        # Optimize the critic
        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        # Delayed policy updates
        if self.total_it % self.policy_freq == 0:

            # Compute actor losse
            actor_loss = -self.critic.Q1(state, self.actor(state)).mean()

            # Optimize the actor
            self.actor_optimizer.zero_grad()
            actor_loss.backward()
            self.actor_optimizer.step()

            # Update the frozen target models
            for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

            for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
                target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def save(self, filename):
        torch.save(self.critic.state_dict(), filename + "_critic")
        torch.save(self.critic_optimizer.state_dict(), filename + "_critic_optimizer")

        torch.save(self.actor.state_dict(), filename + "_actor")
        torch.save(self.actor_optimizer.state_dict(), filename + "_actor_optimizer")

    def load(self, filename):
        self.critic.load_state_dict(torch.load(filename + "_critic"))
        self.critic_optimizer.load_state_dict(torch.load(filename + "_critic_optimizer"))
        self.critic_target = copy.deepcopy(self.critic)

        self.actor.load_state_dict(torch.load(filename + "_actor"))
        self.actor_optimizer.load_state_dict(torch.load(filename + "_actor_optimizer"))
        self.actor_target = copy.deepcopy(self.actor)

# %%
import numpy as np
import torch


class ReplayBuffer(object):
	def __init__(self, state_dim, action_dim, max_size=int(1e6)):
		self.max_size = max_size
		self.ptr = 0
		self.size = 0

		self.state = np.zeros((max_size, state_dim))
		self.action = np.zeros((max_size, action_dim))
		self.next_state = np.zeros((max_size, state_dim))
		self.reward = np.zeros((max_size, 1))
		self.not_done = np.zeros((max_size, 1))

		self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


	def add(self, state, action, next_state, reward, done):
		self.state[self.ptr] = state
		self.action[self.ptr] = action
		self.next_state[self.ptr] = next_state
		self.reward[self.ptr] = reward
		self.not_done[self.ptr] = 1. - done

		self.ptr = (self.ptr + 1) % self.max_size
		self.size = min(self.size + 1, self.max_size)


	def sample(self, batch_size):
		ind = np.random.randint(0, self.size, size=batch_size)

		return (
			torch.FloatTensor(self.state[ind]).to(self.device),
			torch.FloatTensor(self.action[ind]).to(self.device),
			torch.FloatTensor(self.next_state[ind]).to(self.device),
			torch.FloatTensor(self.reward[ind]).to(self.device),
			torch.FloatTensor(self.not_done[ind]).to(self.device)
		)

# %%
# Runs policy for X episodes and returns average reward
# A fixed seed is used for the eval environment
def eval_policy(policy, env, seed, eval_episodes=10):
	eval_env = env
	eval_env.reset(seed=seed
    )

	avg_reward = 0.
	for _ in range(eval_episodes):
		state, done = eval_env.reset(), False
		while not done:
			action = policy.select_action(np.array(state))
			state, reward, done, _ = eval_env.step(action)
			avg_reward += reward

	avg_reward /= eval_episodes

	print("---------------------------------------")
	print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
	print("---------------------------------------")
	return avg_reward

# %%
# three body problem env
import gym
from gym import spaces
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-5, high=5, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.render_logic = False
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        # force = action[0] * env.state[2:] + action[1] * env.state[:2]
        a_x = action[0]
        a_y = action[1]

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y

        x = x + xdot*self.dt
        y = y + ydot*self.dt

        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        # plot position
        if env.render_logic:
            plt.plot(x, y, 'ro')
            plt.plot(self.trajectory[:,0], self.trajectory[:,1])
            plt.show()

        reward = 1 - np.linalg.norm(self.position - self.trajectory[self.steps], axis=0) + self.steps
        done = self.steps >= self.max_steps
        if np.linalg.norm(self.position[0:2] - self.trajectory[-1, 0:2]) < 0.01:
            done = True
            reward = 1000000
            print("done")
        if self.steps > 1000:
            done = True
            reward = -1000000
            print("end time")
        if np.linalg.norm(self.state[0:2]) > 0.05:
            done = True
            reward = -1000000
            print("too much error")

        # print(self.state, reward, done, self.position)
        return 10000*self.state, reward, done, self.position

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]

    def reset(self,
              *,
              seed: 5 = None,
              return_info: bool = False,
              options: 6 = None):
        self.position = self.trajectory[0]
        self.steps = 0
        self.position2state()
        return 10000*self.state

    def render(self):
        pass

    def close(self):
        pass


env = three_body_env(trajectory)

# %%
import numpy as np
import torch
import gym
import argparse
import os

# Define constants
DEFAULT_POLICY = "TD3"
DEFAULT_ENV = "TBP"
DEFAULT_SEED = 0
DEFAULT_START_TIMESTEPS = int(5e3)
DEFAULT_EVAL_FREQ = int(5e3)
DEFAULT_MAX_TIMESTEPS = int(5e5)
DEFAULT_EXPL_NOISE = 0.0
DEFAULT_BATCH_SIZE = 256
DEFAULT_DISCOUNT = 0.99
DEFAULT_TAU = 0.005
DEFAULT_POLICY_NOISE = 0.0
DEFAULT_NOISE_CLIP = 0.02
DEFAULT_POLICY_FREQ = 2

file_name = f"{DEFAULT_POLICY}_{DEFAULT_ENV}_{DEFAULT_SEED}"
print("---------------------------------------")
print(f"Policy: {DEFAULT_POLICY}, Env: {DEFAULT_ENV}, Seed: {DEFAULT_SEED}")
print("---------------------------------------")

if not os.path.exists("./results"):
    os.makedirs("./results")

if not os.path.exists("./models"):
    os.makedirs("./models")

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

kwargs = {"state_dim": state_dim, "action_dim": action_dim, "max_action": max_action, "discount": DEFAULT_DISCOUNT,
          "tau": DEFAULT_TAU, "policy_noise": DEFAULT_POLICY_NOISE * max_action,
          "noise_clip": DEFAULT_NOISE_CLIP * max_action, "policy_freq": DEFAULT_POLICY_FREQ}
policy = TD3(**kwargs)

replay_buffer = ReplayBuffer(state_dim, action_dim)

# Evaluate untrained policy
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]

state, done = env.reset(), False

episode_reward = 0
episode_timesteps = 0
episode_num = 0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------
# Policy: TD3, Env: TBP, Seed: 0
# ---------------------------------------
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -999793.088
# ---------------------------------------

# %%
evaluations = [eval_policy(policy, env, DEFAULT_SEED)]
for t in range(int(DEFAULT_MAX_TIMESTEPS)):

    episode_timesteps += 1

    # Select action randomly or according to policy
    if t < DEFAULT_START_TIMESTEPS:
        action = env.action_space.sample()
    else:
        action = (
            policy.select_action(np.array(state))
            + np.random.normal(0, max_action * DEFAULT_EXPL_NOISE, size=action_dim)
        ).clip(-max_action, max_action)

    # Perform action
    next_state, reward, done, _ = env.step(action)
    done_bool = float(done) if episode_timesteps < env.max_steps else 0

    # Store data in replay buffer
    replay_buffer.add(state, action, next_state, reward, done_bool)

    state = next_state
    episode_reward += reward

    # Train agent after collecting sufficient data
    if t >= DEFAULT_START_TIMESTEPS:
        policy.train(replay_buffer, DEFAULT_BATCH_SIZE)

    if done:
        # +1 to account for 0 indexing. +0 on ep_timesteps since it will increment +1 even if done=True
        print(f"Total T: {t+1} Episode Num: {episode_num+1} Episode T: {episode_timesteps} Reward: {episode_reward:.3f}")
        # Reset environment
        state, done = env.reset(), False
        episode_reward = 0
        episode_timesteps = 0
        episode_num += 1

    # Evaluate episode
    if (t + 1) % DEFAULT_EVAL_FREQ == 0:
        evaluations.append(eval_policy(policy, env, DEFAULT_SEED))
        np.save(f"./results/{file_name}", evaluations)
        policy.save(f"./models/{file_name}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -999793.088
# ---------------------------------------
# too much error
# Total T: 1 Episode Num: 1 Episode T: 1 Reward: -1000000.000
# too much error
# Total T: 52 Episode Num: 2 Episode T: 51 Reward: -998685.177
# too much error
# Total T: 73 Episode Num: 3 Episode T: 21 Reward: -999772.400
# too much error
# Total T: 86 Episode Num: 4 Episode T: 13 Reward: -999911.175
# too much error
# Total T: 113 Episode Num: 5 Episode T: 27 Reward: -999624.537
# too much error
# Total T: 119 Episode Num: 6 Episode T: 6 Reward: -999980.283
# too much error
# Total T: 150 Episode Num: 7 Episode T: 31 Reward: -999507.501
# too much error
# Total T: 197 Episode Num: 8 Episode T: 47 Reward: -998884.917
# too much error
# Total T: 255 Episode Num: 9 Episode T: 58 Reward: -998300.788
# too much error
# Total T: 355 Episode Num: 10 Episode T: 100 Reward: -994979.081
# too much error
# Total T: 386 Episode Num: 11 Episode T: 31 Reward: -999508.880
# too much error
# Total T: 426 Episode Num: 12 Episode T: 40 Reward: -999184.900
# too much error
# Total T: 487 Episode Num: 13 Episode T: 61 Reward: -998128.578
# too much error
# Total T: 511 Episode Num: 14 Episode T: 24 Reward: -999702.460
# too much error
# Total T: 516 Episode Num: 15 Episode T: 5 Reward: -999986.338
# too much error
# Total T: 539 Episode Num: 16 Episode T: 23 Reward: -999726.663
# too much error
# Total T: 558 Episode Num: 17 Episode T: 19 Reward: -999812.729
# too much error
# Total T: 580 Episode Num: 18 Episode T: 22 Reward: -999750.385
# too much error
# Total T: 632 Episode Num: 19 Episode T: 52 Reward: -998634.941
# too much error
# Total T: 683 Episode Num: 20 Episode T: 51 Reward: -998686.407
# too much error
# Total T: 739 Episode Num: 21 Episode T: 56 Reward: -998416.379
# too much error
# Total T: 802 Episode Num: 22 Episode T: 63 Reward: -998007.851
# too much error
# Total T: 832 Episode Num: 23 Episode T: 30 Reward: -999541.061
# too much error
# Total T: 893 Episode Num: 24 Episode T: 61 Reward: -998124.289
# too much error
# Total T: 939 Episode Num: 25 Episode T: 46 Reward: -998929.076
# too much error
# Total T: 1024 Episode Num: 26 Episode T: 85 Reward: -996368.426
# too much error
# Total T: 1071 Episode Num: 27 Episode T: 47 Reward: -998880.122
# too much error
# Total T: 1124 Episode Num: 28 Episode T: 53 Reward: -998580.534
# too much error
# Total T: 1168 Episode Num: 29 Episode T: 44 Reward: -999023.218
# too much error
# Total T: 1187 Episode Num: 30 Episode T: 19 Reward: -999812.516
# too much error
# Total T: 1193 Episode Num: 31 Episode T: 6 Reward: -999980.463
# too much error
# Total T: 1224 Episode Num: 32 Episode T: 31 Reward: -999510.909
# too much error
# Total T: 1250 Episode Num: 33 Episode T: 26 Reward: -999652.828
# too much error
# Total T: 1254 Episode Num: 34 Episode T: 4 Reward: -999991.191
# too much error
# Total T: 1272 Episode Num: 35 Episode T: 18 Reward: -999832.489
# too much error
# Total T: 1283 Episode Num: 36 Episode T: 11 Reward: -999935.667
# too much error
# Total T: 1334 Episode Num: 37 Episode T: 51 Reward: -998680.470
# too much error
# Total T: 1343 Episode Num: 38 Episode T: 9 Reward: -999956.582
# too much error
# Total T: 1384 Episode Num: 39 Episode T: 41 Reward: -999146.404
# too much error
# Total T: 1412 Episode Num: 40 Episode T: 28 Reward: -999598.745
# too much error
# Total T: 1416 Episode Num: 41 Episode T: 4 Reward: -999991.227
# too much error
# Total T: 1461 Episode Num: 42 Episode T: 45 Reward: -998982.291
# too much error
# Total T: 1548 Episode Num: 43 Episode T: 87 Reward: -996198.138
# too much error
# Total T: 1591 Episode Num: 44 Episode T: 43 Reward: -999072.864
# too much error
# Total T: 1601 Episode Num: 45 Episode T: 10 Reward: -999947.028
# too much error
# Total T: 1613 Episode Num: 46 Episode T: 12 Reward: -999923.893
# too much error
# Total T: 1623 Episode Num: 47 Episode T: 10 Reward: -999946.786
# too much error
# Total T: 1689 Episode Num: 48 Episode T: 66 Reward: -997801.155
# too much error
# Total T: 1716 Episode Num: 49 Episode T: 27 Reward: -999626.428
# too much error
# Total T: 1735 Episode Num: 50 Episode T: 19 Reward: -999812.588
# too much error
# Total T: 1779 Episode Num: 51 Episode T: 44 Reward: -999026.636
# too much error
# Total T: 1795 Episode Num: 52 Episode T: 16 Reward: -999866.236
# too much error
# Total T: 1811 Episode Num: 53 Episode T: 16 Reward: -999866.121
# too much error
# Total T: 1854 Episode Num: 54 Episode T: 43 Reward: -999059.381
# too much error
# Total T: 1901 Episode Num: 55 Episode T: 47 Reward: -998891.146
# too much error
# Total T: 1909 Episode Num: 56 Episode T: 8 Reward: -999965.692
# too much error
# Total T: 1946 Episode Num: 57 Episode T: 37 Reward: -999305.423
# too much error
# Total T: 1978 Episode Num: 58 Episode T: 32 Reward: -999475.119
# too much error
# Total T: 1989 Episode Num: 59 Episode T: 11 Reward: -999935.600
# too much error
# Total T: 2041 Episode Num: 60 Episode T: 52 Reward: -998632.995
# too much error
# Total T: 2216 Episode Num: 61 Episode T: 175 Reward: -984654.220
# too much error
# Total T: 2276 Episode Num: 62 Episode T: 60 Reward: -998193.410
# too much error
# Total T: 2320 Episode Num: 63 Episode T: 44 Reward: -999022.011
# too much error
# Total T: 2355 Episode Num: 64 Episode T: 35 Reward: -999373.492
# too much error
# Total T: 2386 Episode Num: 65 Episode T: 31 Reward: -999513.014
# too much error
# Total T: 2396 Episode Num: 66 Episode T: 10 Reward: -999946.617
# too much error
# Total T: 2426 Episode Num: 67 Episode T: 30 Reward: -999540.579
# too much error
# Total T: 2483 Episode Num: 68 Episode T: 57 Reward: -998358.031
# too much error
# Total T: 2541 Episode Num: 69 Episode T: 58 Reward: -998296.392
# too much error
# Total T: 2544 Episode Num: 70 Episode T: 3 Reward: -999995.127
# too much error
# Total T: 2597 Episode Num: 71 Episode T: 53 Reward: -998577.219
# too much error
# Total T: 2644 Episode Num: 72 Episode T: 47 Reward: -998882.877
# too much error
# Total T: 2679 Episode Num: 73 Episode T: 35 Reward: -999377.058
# too much error
# Total T: 2698 Episode Num: 74 Episode T: 19 Reward: -999813.544
# too much error
# Total T: 2721 Episode Num: 75 Episode T: 23 Reward: -999726.904
# too much error
# Total T: 2729 Episode Num: 76 Episode T: 8 Reward: -999965.672
# too much error
# Total T: 2784 Episode Num: 77 Episode T: 55 Reward: -998466.482
# too much error
# Total T: 2806 Episode Num: 78 Episode T: 22 Reward: -999750.717
# too much error
# Total T: 2836 Episode Num: 79 Episode T: 30 Reward: -999537.936
# too much error
# Total T: 2884 Episode Num: 80 Episode T: 48 Reward: -998835.151
# too much error
# Total T: 2892 Episode Num: 81 Episode T: 8 Reward: -999965.853
# too much error
# Total T: 2896 Episode Num: 82 Episode T: 4 Reward: -999991.241
# too much error
# Total T: 2959 Episode Num: 83 Episode T: 63 Reward: -998009.617
# too much error
# Total T: 3007 Episode Num: 84 Episode T: 48 Reward: -998830.413
# too much error
# Total T: 3081 Episode Num: 85 Episode T: 74 Reward: -997240.581
# too much error
# Total T: 3123 Episode Num: 86 Episode T: 42 Reward: -999105.447
# too much error
# Total T: 3181 Episode Num: 87 Episode T: 58 Reward: -998309.116
# too much error
# Total T: 3238 Episode Num: 88 Episode T: 57 Reward: -998357.881
# too much error
# Total T: 3257 Episode Num: 89 Episode T: 19 Reward: -999813.138
# too much error
# Total T: 3297 Episode Num: 90 Episode T: 40 Reward: -999185.547
# too much error
# Total T: 3327 Episode Num: 91 Episode T: 30 Reward: -999541.555
# too much error
# Total T: 3364 Episode Num: 92 Episode T: 37 Reward: -999302.248
# too much error
# Total T: 3414 Episode Num: 93 Episode T: 50 Reward: -998734.853
# too much error
# Total T: 3425 Episode Num: 94 Episode T: 11 Reward: -999936.290
# too much error
# Total T: 3459 Episode Num: 95 Episode T: 34 Reward: -999409.373
# too much error
# Total T: 3513 Episode Num: 96 Episode T: 54 Reward: -998535.407
# too much error
# Total T: 3526 Episode Num: 97 Episode T: 13 Reward: -999910.898
# too much error
# Total T: 3602 Episode Num: 98 Episode T: 76 Reward: -997097.462
# too much error
# Total T: 3634 Episode Num: 99 Episode T: 32 Reward: -999477.629
# too much error
# Total T: 3676 Episode Num: 100 Episode T: 42 Reward: -999100.871
# too much error
# Total T: 3682 Episode Num: 101 Episode T: 6 Reward: -999980.305
# too much error
# Total T: 3693 Episode Num: 102 Episode T: 11 Reward: -999935.847
# too much error
# Total T: 3726 Episode Num: 103 Episode T: 33 Reward: -999448.218
# too much error
# Total T: 3774 Episode Num: 104 Episode T: 48 Reward: -998840.418
# too much error
# Total T: 3786 Episode Num: 105 Episode T: 12 Reward: -999924.067
# too much error
# Total T: 3827 Episode Num: 106 Episode T: 41 Reward: -999155.486
# too much error
# Total T: 3839 Episode Num: 107 Episode T: 12 Reward: -999924.033
# too much error
# Total T: 3971 Episode Num: 108 Episode T: 132 Reward: -991261.862
# too much error
# Total T: 4027 Episode Num: 109 Episode T: 56 Reward: -998417.643
# too much error
# Total T: 4058 Episode Num: 110 Episode T: 31 Reward: -999508.422
# too much error
# Total T: 4101 Episode Num: 111 Episode T: 43 Reward: -999060.574
# too much error
# Total T: 4111 Episode Num: 112 Episode T: 10 Reward: -999946.697
# too much error
# Total T: 4139 Episode Num: 113 Episode T: 28 Reward: -999597.979
# too much error
# Total T: 4187 Episode Num: 114 Episode T: 48 Reward: -998840.855
# too much error
# Total T: 4219 Episode Num: 115 Episode T: 32 Reward: -999480.568
# too much error
# Total T: 4268 Episode Num: 116 Episode T: 49 Reward: -998787.081
# too much error
# Total T: 4320 Episode Num: 117 Episode T: 52 Reward: -998628.681
# too much error
# Total T: 4381 Episode Num: 118 Episode T: 61 Reward: -998127.361
# too much error
# Total T: 4404 Episode Num: 119 Episode T: 23 Reward: -999726.909
# too much error
# Total T: 4479 Episode Num: 120 Episode T: 75 Reward: -997176.717
# too much error
# Total T: 4504 Episode Num: 121 Episode T: 25 Reward: -999682.429
# too much error
# Total T: 4526 Episode Num: 122 Episode T: 22 Reward: -999749.468
# too much error
# Total T: 4537 Episode Num: 123 Episode T: 11 Reward: -999935.733
# too much error
# Total T: 4549 Episode Num: 124 Episode T: 12 Reward: -999923.990
# too much error
# Total T: 4564 Episode Num: 125 Episode T: 15 Reward: -999882.532
# too much error
# Total T: 4580 Episode Num: 126 Episode T: 16 Reward: -999866.787
# too much error
# Total T: 4611 Episode Num: 127 Episode T: 31 Reward: -999508.128
# too much error
# Total T: 4636 Episode Num: 128 Episode T: 25 Reward: -999677.508
# too much error
# Total T: 4663 Episode Num: 129 Episode T: 27 Reward: -999626.697
# too much error
# Total T: 4744 Episode Num: 130 Episode T: 81 Reward: -996702.874
# too much error
# Total T: 4753 Episode Num: 131 Episode T: 9 Reward: -999956.821
# too much error
# Total T: 4763 Episode Num: 132 Episode T: 10 Reward: -999946.792
# too much error
# Total T: 4792 Episode Num: 133 Episode T: 29 Reward: -999570.242
# too much error
# Total T: 4817 Episode Num: 134 Episode T: 25 Reward: -999681.969
# too much error
# Total T: 4825 Episode Num: 135 Episode T: 8 Reward: -999965.611
# too much error
# Total T: 4842 Episode Num: 136 Episode T: 17 Reward: -999849.196
# too much error
# Total T: 4848 Episode Num: 137 Episode T: 6 Reward: -999980.380
# too much error
# Total T: 4852 Episode Num: 138 Episode T: 4 Reward: -999991.276
# too much error
# Total T: 4885 Episode Num: 139 Episode T: 33 Reward: -999446.855
# too much error
# Total T: 4928 Episode Num: 140 Episode T: 43 Reward: -999059.881
# too much error
# Total T: 4960 Episode Num: 141 Episode T: 32 Reward: -999481.510
# too much error
# Total T: 4993 Episode Num: 142 Episode T: 33 Reward: -999447.997
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -999793.088
# ---------------------------------------
# too much error
# Total T: 5001 Episode Num: 143 Episode T: 8 Reward: -999965.768
# too much error
# Total T: 5022 Episode Num: 144 Episode T: 21 Reward: -999772.034
# too much error
# Total T: 5043 Episode Num: 145 Episode T: 21 Reward: -999771.871
# too much error
# Total T: 5065 Episode Num: 146 Episode T: 22 Reward: -999749.958
# too much error
# Total T: 5087 Episode Num: 147 Episode T: 22 Reward: -999749.805
# too much error
# Total T: 5110 Episode Num: 148 Episode T: 23 Reward: -999726.687
# too much error
# Total T: 5132 Episode Num: 149 Episode T: 22 Reward: -999749.643
# too much error
# Total T: 5155 Episode Num: 150 Episode T: 23 Reward: -999726.574
# too much error
# Total T: 5178 Episode Num: 151 Episode T: 23 Reward: -999726.398
# too much error
# Total T: 5202 Episode Num: 152 Episode T: 24 Reward: -999702.194
# too much error
# Total T: 5227 Episode Num: 153 Episode T: 25 Reward: -999677.196
# too much error
# Total T: 5242 Episode Num: 154 Episode T: 15 Reward: -999882.935
# too much error
# Total T: 5256 Episode Num: 155 Episode T: 14 Reward: -999897.840
# too much error
# Total T: 5270 Episode Num: 156 Episode T: 14 Reward: -999897.866
# too much error
# Total T: 5284 Episode Num: 157 Episode T: 14 Reward: -999897.894
# too much error
# Total T: 5299 Episode Num: 158 Episode T: 15 Reward: -999883.234
# too much error
# Total T: 5314 Episode Num: 159 Episode T: 15 Reward: -999883.255
# too much error
# Total T: 5331 Episode Num: 160 Episode T: 17 Reward: -999850.901
# too much error
# Total T: 5387 Episode Num: 161 Episode T: 56 Reward: -998422.282
# too much error
# Total T: 5423 Episode Num: 162 Episode T: 36 Reward: -999337.708
# too much error
# Total T: 5530 Episode Num: 163 Episode T: 107 Reward: -994243.398
# too much error
# Total T: 5586 Episode Num: 164 Episode T: 56 Reward: -998412.371
# too much error
# Total T: 5826 Episode Num: 165 Episode T: 240 Reward: -971141.259
# too much error
# Total T: 5911 Episode Num: 166 Episode T: 85 Reward: -996362.752
# too much error
# Total T: 5956 Episode Num: 167 Episode T: 45 Reward: -998971.675
# too much error
# Total T: 6034 Episode Num: 168 Episode T: 78 Reward: -996933.452
# too much error
# Total T: 6080 Episode Num: 169 Episode T: 46 Reward: -998925.969
# too much error
# Total T: 6125 Episode Num: 170 Episode T: 45 Reward: -998971.795
# too much error
# Total T: 6172 Episode Num: 171 Episode T: 47 Reward: -998879.218
# too much error
# Total T: 6216 Episode Num: 172 Episode T: 44 Reward: -999016.430
# too much error
# Total T: 6260 Episode Num: 173 Episode T: 44 Reward: -999016.631
# too much error
# Total T: 6308 Episode Num: 174 Episode T: 48 Reward: -998832.079
# too much error
# Total T: 6355 Episode Num: 175 Episode T: 47 Reward: -998879.866
# too much error
# Total T: 6418 Episode Num: 176 Episode T: 63 Reward: -997994.926
# too much error
# Total T: 6493 Episode Num: 177 Episode T: 75 Reward: -997164.560
# too much error
# Total T: 6539 Episode Num: 178 Episode T: 46 Reward: -998926.692
# too much error
# Total T: 6585 Episode Num: 179 Episode T: 46 Reward: -998926.625
# too much error
# Total T: 6631 Episode Num: 180 Episode T: 46 Reward: -998926.649
# too much error
# Total T: 6676 Episode Num: 181 Episode T: 45 Reward: -998972.452
# too much error
# Total T: 6721 Episode Num: 182 Episode T: 45 Reward: -998972.458
# too much error
# Total T: 6786 Episode Num: 183 Episode T: 65 Reward: -997866.603
# too much error
# Total T: 6829 Episode Num: 184 Episode T: 43 Reward: -999060.878
# too much error
# Total T: 6889 Episode Num: 185 Episode T: 60 Reward: -998180.321
# too much error
# Total T: 6962 Episode Num: 186 Episode T: 73 Reward: -997312.073
# too much error
# Total T: 7027 Episode Num: 187 Episode T: 65 Reward: -997866.160
# too much error
# Total T: 7089 Episode Num: 188 Episode T: 62 Reward: -998057.247
# too much error
# Total T: 7162 Episode Num: 189 Episode T: 73 Reward: -997311.987
# too much error
# Total T: 7223 Episode Num: 190 Episode T: 61 Reward: -998118.879
# too much error
# Total T: 7284 Episode Num: 191 Episode T: 61 Reward: -998118.745
# too much error
# Total T: 7347 Episode Num: 192 Episode T: 63 Reward: -997994.400
# too much error
# Total T: 7423 Episode Num: 193 Episode T: 76 Reward: -997087.671
# too much error
# Total T: 7484 Episode Num: 194 Episode T: 61 Reward: -998119.208
# too much error
# Total T: 7597 Episode Num: 195 Episode T: 113 Reward: -993584.152
# too much error
# Total T: 7687 Episode Num: 196 Episode T: 90 Reward: -995923.292
# too much error
# Total T: 7761 Episode Num: 197 Episode T: 74 Reward: -997238.417
# too much error
# Total T: 7843 Episode Num: 198 Episode T: 82 Reward: -996612.118
# too much error
# Total T: 7940 Episode Num: 199 Episode T: 97 Reward: -995266.736
# too much error
# Total T: 8022 Episode Num: 200 Episode T: 82 Reward: -996612.380
# too much error
# Total T: 8137 Episode Num: 201 Episode T: 115 Reward: -993356.278
# too much error
# Total T: 8220 Episode Num: 202 Episode T: 83 Reward: -996530.461
# too much error
# Total T: 8346 Episode Num: 203 Episode T: 126 Reward: -992030.997
# too much error
# Total T: 8452 Episode Num: 204 Episode T: 106 Reward: -994354.372
# too much error
# Total T: 8587 Episode Num: 205 Episode T: 135 Reward: -990853.848
# too much error
# Total T: 8705 Episode Num: 206 Episode T: 118 Reward: -993006.463
# too much error
# Total T: 8829 Episode Num: 207 Episode T: 124 Reward: -992280.411
# too much error
# Total T: 8941 Episode Num: 208 Episode T: 112 Reward: -993699.247
# too much error
# Total T: 9183 Episode Num: 209 Episode T: 242 Reward: -970659.483
# too much error
# Total T: 9294 Episode Num: 210 Episode T: 111 Reward: -993810.608
# too much error
# Total T: 9403 Episode Num: 211 Episode T: 109 Reward: -994030.972
# too much error
# Total T: 9503 Episode Num: 212 Episode T: 100 Reward: -994972.227
# too much error
# Total T: 9592 Episode Num: 213 Episode T: 89 Reward: -996013.604
# too much error
# Total T: 9685 Episode Num: 214 Episode T: 93 Reward: -995649.115
# too much error
# Total T: 9773 Episode Num: 215 Episode T: 88 Reward: -996102.400
# too much error
# Total T: 9865 Episode Num: 216 Episode T: 92 Reward: -995742.176
# too much error
# Total T: 9964 Episode Num: 217 Episode T: 99 Reward: -995070.784
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -995170.612
# ---------------------------------------
# too much error
# Total T: 10001 Episode Num: 218 Episode T: 37 Reward: -999301.226
# too much error
# Total T: 10099 Episode Num: 219 Episode T: 98 Reward: -995170.763
# too much error
# Total T: 10202 Episode Num: 220 Episode T: 103 Reward: -994666.513
# too much error
# Total T: 10293 Episode Num: 221 Episode T: 91 Reward: -995832.451
# too much error
# Total T: 10402 Episode Num: 222 Episode T: 109 Reward: -994030.071
# too much error
# Total T: 10539 Episode Num: 223 Episode T: 137 Reward: -990582.777
# too much error
# Total T: 10649 Episode Num: 224 Episode T: 110 Reward: -993919.960
# too much error
# Total T: 10679 Episode Num: 225 Episode T: 30 Reward: -999537.312
# too much error
# Total T: 10789 Episode Num: 226 Episode T: 110 Reward: -993920.290
# too much error
# Total T: 10905 Episode Num: 227 Episode T: 116 Reward: -993240.789
# too much error
# Total T: 11022 Episode Num: 228 Episode T: 117 Reward: -993122.863
# too much error
# Total T: 11134 Episode Num: 229 Episode T: 112 Reward: -993697.331
# too much error
# Total T: 11252 Episode Num: 230 Episode T: 118 Reward: -993006.336
# too much error
# Total T: 11338 Episode Num: 231 Episode T: 86 Reward: -996287.243
# too much error
# Total T: 11427 Episode Num: 232 Episode T: 89 Reward: -996024.198
# too much error
# Total T: 11514 Episode Num: 233 Episode T: 87 Reward: -996200.882
# too much error
# Total T: 11598 Episode Num: 234 Episode T: 84 Reward: -996457.984
# too much error
# Total T: 11678 Episode Num: 235 Episode T: 80 Reward: -996787.593
# too much error
# Total T: 11758 Episode Num: 236 Episode T: 80 Reward: -996787.129
# too much error
# Total T: 11897 Episode Num: 237 Episode T: 139 Reward: -990306.295
# too much error
# Total T: 11967 Episode Num: 238 Episode T: 70 Reward: -997539.873
# too much error
# Total T: 12033 Episode Num: 239 Episode T: 66 Reward: -997812.587
# too much error
# Total T: 12098 Episode Num: 240 Episode T: 65 Reward: -997878.291
# too much error
# Total T: 12161 Episode Num: 241 Episode T: 63 Reward: -998007.055
# too much error
# Total T: 12222 Episode Num: 242 Episode T: 61 Reward: -998131.370
# too much error
# Total T: 12330 Episode Num: 243 Episode T: 108 Reward: -994137.986
# too much error
# Total T: 12399 Episode Num: 244 Episode T: 69 Reward: -997608.507
# too much error
# Total T: 12504 Episode Num: 245 Episode T: 105 Reward: -994458.829
# too much error
# Total T: 12561 Episode Num: 246 Episode T: 57 Reward: -998368.741
# too much error
# Total T: 12616 Episode Num: 247 Episode T: 55 Reward: -998480.910
# too much error
# Total T: 12673 Episode Num: 248 Episode T: 57 Reward: -998368.487
# too much error
# Total T: 12727 Episode Num: 249 Episode T: 54 Reward: -998536.192
# too much error
# Total T: 12781 Episode Num: 250 Episode T: 54 Reward: -998535.956
# too much error
# Total T: 12835 Episode Num: 251 Episode T: 54 Reward: -998535.794
# too much error
# Total T: 12890 Episode Num: 252 Episode T: 55 Reward: -998480.931
# too much error
# Total T: 12943 Episode Num: 253 Episode T: 53 Reward: -998589.666
# too much error
# Total T: 12995 Episode Num: 254 Episode T: 52 Reward: -998642.506
# too much error
# Total T: 13044 Episode Num: 255 Episode T: 49 Reward: -998794.688
# too much error
# Total T: 13095 Episode Num: 256 Episode T: 51 Reward: -998694.232
# too much error
# Total T: 13145 Episode Num: 257 Episode T: 50 Reward: -998745.163
# too much error
# Total T: 13194 Episode Num: 258 Episode T: 49 Reward: -998794.863
# too much error
# Total T: 13243 Episode Num: 259 Episode T: 49 Reward: -998795.037
# too much error
# Total T: 13358 Episode Num: 260 Episode T: 115 Reward: -993360.993
# too much error
# Total T: 13401 Episode Num: 261 Episode T: 43 Reward: -999072.634
# too much error
# Total T: 13518 Episode Num: 262 Episode T: 117 Reward: -993122.712
# too much error
# Total T: 13558 Episode Num: 263 Episode T: 40 Reward: -999197.930
# too much error
# Total T: 13598 Episode Num: 264 Episode T: 40 Reward: -999197.958
# too much error
# Total T: 13639 Episode Num: 265 Episode T: 41 Reward: -999157.299
# too much error
# Total T: 13679 Episode Num: 266 Episode T: 40 Reward: -999198.367
# too much error
# Total T: 13718 Episode Num: 267 Episode T: 39 Reward: -999237.789
# too much error
# Total T: 13756 Episode Num: 268 Episode T: 38 Reward: -999276.616
# too much error
# Total T: 13793 Episode Num: 269 Episode T: 37 Reward: -999314.387
# too much error
# Total T: 13830 Episode Num: 270 Episode T: 37 Reward: -999314.651
# too much error
# Total T: 13866 Episode Num: 271 Episode T: 36 Reward: -999351.054
# too much error
# Total T: 13902 Episode Num: 272 Episode T: 36 Reward: -999351.259
# too much error
# Total T: 13937 Episode Num: 273 Episode T: 35 Reward: -999386.769
# too much error
# Total T: 13972 Episode Num: 274 Episode T: 35 Reward: -999386.761
# too much error
# Total T: 14007 Episode Num: 275 Episode T: 35 Reward: -999387.212
# too much error
# Total T: 14041 Episode Num: 276 Episode T: 34 Reward: -999421.741
# too much error
# Total T: 14075 Episode Num: 277 Episode T: 34 Reward: -999421.666
# too much error
# Total T: 14108 Episode Num: 278 Episode T: 33 Reward: -999455.456
# too much error
# Total T: 14141 Episode Num: 279 Episode T: 33 Reward: -999455.412
# too much error
# Total T: 14174 Episode Num: 280 Episode T: 33 Reward: -999455.508
# too much error
# Total T: 14207 Episode Num: 281 Episode T: 33 Reward: -999455.655
# too much error
# Total T: 14240 Episode Num: 282 Episode T: 33 Reward: -999455.576
# too much error
# Total T: 14272 Episode Num: 283 Episode T: 32 Reward: -999487.997
# too much error
# Total T: 14304 Episode Num: 284 Episode T: 32 Reward: -999487.934
# too much error
# Total T: 14336 Episode Num: 285 Episode T: 32 Reward: -999488.142
# too much error
# Total T: 14367 Episode Num: 286 Episode T: 31 Reward: -999519.936
# too much error
# Total T: 14399 Episode Num: 287 Episode T: 32 Reward: -999488.402
# too much error
# Total T: 14431 Episode Num: 288 Episode T: 32 Reward: -999488.544
# too much error
# Total T: 14462 Episode Num: 289 Episode T: 31 Reward: -999520.320
# too much error
# Total T: 14493 Episode Num: 290 Episode T: 31 Reward: -999520.063
# too much error
# Total T: 14523 Episode Num: 291 Episode T: 30 Reward: -999550.990
# too much error
# Total T: 14553 Episode Num: 292 Episode T: 30 Reward: -999550.978
# too much error
# Total T: 14582 Episode Num: 293 Episode T: 29 Reward: -999580.400
# too much error
# Total T: 14611 Episode Num: 294 Episode T: 29 Reward: -999580.393
# too much error
# Total T: 14646 Episode Num: 295 Episode T: 35 Reward: -999386.511
# too much error
# Total T: 14683 Episode Num: 296 Episode T: 37 Reward: -999313.924
# too much error
# Total T: 14712 Episode Num: 297 Episode T: 29 Reward: -999580.785
# too much error
# Total T: 14740 Episode Num: 298 Episode T: 28 Reward: -999609.172
# too much error
# Total T: 14768 Episode Num: 299 Episode T: 28 Reward: -999609.332
# too much error
# Total T: 14796 Episode Num: 300 Episode T: 28 Reward: -999609.373
# too much error
# Total T: 14824 Episode Num: 301 Episode T: 28 Reward: -999609.453
# too much error
# Total T: 14963 Episode Num: 302 Episode T: 139 Reward: -990303.515
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -999609.830
# ---------------------------------------
# too much error
# Total T: 15001 Episode Num: 303 Episode T: 38 Reward: -999263.364
# too much error
# Total T: 15029 Episode Num: 304 Episode T: 28 Reward: -999609.915
# too much error
# Total T: 15057 Episode Num: 305 Episode T: 28 Reward: -999609.917
# too much error
# Total T: 15084 Episode Num: 306 Episode T: 27 Reward: -999636.933
# too much error
# Total T: 15111 Episode Num: 307 Episode T: 27 Reward: -999636.969
# too much error
# Total T: 15138 Episode Num: 308 Episode T: 27 Reward: -999637.021
# too much error
# Total T: 15165 Episode Num: 309 Episode T: 27 Reward: -999637.074
# too much error
# Total T: 15192 Episode Num: 310 Episode T: 27 Reward: -999637.144
# too much error
# Total T: 15219 Episode Num: 311 Episode T: 27 Reward: -999637.125
# too much error
# Total T: 15246 Episode Num: 312 Episode T: 27 Reward: -999637.038
# too much error
# Total T: 15337 Episode Num: 313 Episode T: 91 Reward: -995833.547
# too much error
# Total T: 15469 Episode Num: 314 Episode T: 132 Reward: -991254.682
# too much error
# Total T: 15594 Episode Num: 315 Episode T: 125 Reward: -992156.220
# too much error
# Total T: 15618 Episode Num: 316 Episode T: 24 Reward: -999702.365
# too much error
# Total T: 15644 Episode Num: 317 Episode T: 26 Reward: -999651.627
# too much error
# Total T: 15766 Episode Num: 318 Episode T: 122 Reward: -992529.113
# too much error
# Total T: 15861 Episode Num: 319 Episode T: 95 Reward: -995460.114
# too much error
# Total T: 15982 Episode Num: 320 Episode T: 121 Reward: -992650.892
# too much error
# Total T: 16104 Episode Num: 321 Episode T: 122 Reward: -992529.022
# too much error
# Total T: 16132 Episode Num: 322 Episode T: 28 Reward: -999596.641
# too much error
# Total T: 16160 Episode Num: 323 Episode T: 28 Reward: -999596.652
# too much error
# Total T: 16254 Episode Num: 324 Episode T: 94 Reward: -995555.550
# too much error
# Total T: 16282 Episode Num: 325 Episode T: 28 Reward: -999596.639
# too much error
# Total T: 16375 Episode Num: 326 Episode T: 93 Reward: -995649.662
# too much error
# Total T: 16469 Episode Num: 327 Episode T: 94 Reward: -995556.263
# too much error
# Total T: 16496 Episode Num: 328 Episode T: 27 Reward: -999624.716
# too much error
# Total T: 16592 Episode Num: 329 Episode T: 96 Reward: -995365.538
# too much error
# Total T: 16688 Episode Num: 330 Episode T: 96 Reward: -995365.514
# too much error
# Total T: 16715 Episode Num: 331 Episode T: 27 Reward: -999624.542
# too much error
# Total T: 16809 Episode Num: 332 Episode T: 94 Reward: -995555.084
# too much error
# Total T: 16901 Episode Num: 333 Episode T: 92 Reward: -995742.070
# too much error
# Total T: 17002 Episode Num: 334 Episode T: 101 Reward: -994872.446
# too much error
# Total T: 17104 Episode Num: 335 Episode T: 102 Reward: -994770.666
# too much error
# Total T: 17199 Episode Num: 336 Episode T: 95 Reward: -995460.327
# too much error
# Total T: 17291 Episode Num: 337 Episode T: 92 Reward: -995741.956
# too much error
# Total T: 17390 Episode Num: 338 Episode T: 99 Reward: -995072.751
# too much error
# Total T: 17481 Episode Num: 339 Episode T: 91 Reward: -995834.333
# too much error
# Total T: 17610 Episode Num: 340 Episode T: 129 Reward: -991649.536
# too much error
# Total T: 17733 Episode Num: 341 Episode T: 123 Reward: -992407.612
# too much error
# Total T: 17860 Episode Num: 342 Episode T: 127 Reward: -991907.279
# too much error
# Total T: 17950 Episode Num: 343 Episode T: 90 Reward: -995925.043
# too much error
# Total T: 18053 Episode Num: 344 Episode T: 103 Reward: -994668.062
# too much error
# Total T: 18148 Episode Num: 345 Episode T: 95 Reward: -995460.921
# too much error
# Total T: 18251 Episode Num: 346 Episode T: 103 Reward: -994667.657
# too much error
# Total T: 18379 Episode Num: 347 Episode T: 128 Reward: -991778.319
# too much error
# Total T: 18523 Episode Num: 348 Episode T: 144 Reward: -989600.567
# too much error
# Total T: 18628 Episode Num: 349 Episode T: 105 Reward: -994459.572
# too much error
# Total T: 18824 Episode Num: 350 Episode T: 196 Reward: -980749.696
# too much error
# Total T: 19112 Episode Num: 351 Episode T: 288 Reward: -958475.016
# too much error
# Total T: 19226 Episode Num: 352 Episode T: 114 Reward: -993472.321
# too much error
# Total T: 19387 Episode Num: 353 Episode T: 161 Reward: -987003.506
# too much error
# Total T: 19508 Episode Num: 354 Episode T: 121 Reward: -992647.903
# too much error
# Total T: 19613 Episode Num: 355 Episode T: 105 Reward: -994458.138
# too much error
# Total T: 19756 Episode Num: 356 Episode T: 143 Reward: -989742.576
# too much error
# Total T: 19900 Episode Num: 357 Episode T: 144 Reward: -989598.786
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -969192.290
# ---------------------------------------
# too much error
# Total T: 20003 Episode Num: 358 Episode T: 103 Reward: -994372.361
# too much error
# Total T: 20164 Episode Num: 359 Episode T: 161 Reward: -987003.822
# too much error
# Total T: 20328 Episode Num: 360 Episode T: 164 Reward: -986517.673
# too much error
# Total T: 20504 Episode Num: 361 Episode T: 176 Reward: -984475.459
# too much error
# Total T: 20652 Episode Num: 362 Episode T: 148 Reward: -989012.836
# too much error
# Total T: 20820 Episode Num: 363 Episode T: 168 Reward: -985848.436
# too much error
# Total T: 20995 Episode Num: 364 Episode T: 175 Reward: -984635.421
# too much error
# Total T: 21255 Episode Num: 365 Episode T: 260 Reward: -966142.069
# too much error
# Total T: 21542 Episode Num: 366 Episode T: 287 Reward: -958748.192
# too much error
# Total T: 21718 Episode Num: 367 Episode T: 176 Reward: -984471.750
# too much error
# Total T: 21898 Episode Num: 368 Episode T: 180 Reward: -983758.047
# too much error
# Total T: 22073 Episode Num: 369 Episode T: 175 Reward: -984645.609
# too much error
# Total T: 22253 Episode Num: 370 Episode T: 180 Reward: -983757.709
# too much error
# Total T: 22418 Episode Num: 371 Episode T: 165 Reward: -986347.382
# too much error
# Total T: 22603 Episode Num: 372 Episode T: 185 Reward: -982844.185
# too much error
# Total T: 22771 Episode Num: 373 Episode T: 168 Reward: -985846.950
# too much error
# Total T: 22943 Episode Num: 374 Episode T: 172 Reward: -985168.897
# too much error
# Total T: 23132 Episode Num: 375 Episode T: 189 Reward: -982098.102
# too much error
# Total T: 23297 Episode Num: 376 Episode T: 165 Reward: -986346.061
# too much error
# Total T: 23503 Episode Num: 377 Episode T: 206 Reward: -978737.998
# too much error
# Total T: 23674 Episode Num: 378 Episode T: 171 Reward: -985338.014
# too much error
# Total T: 23849 Episode Num: 379 Episode T: 175 Reward: -984646.156
# too much error
# Total T: 24017 Episode Num: 380 Episode T: 168 Reward: -985847.046
# too much error
# Total T: 24214 Episode Num: 381 Episode T: 197 Reward: -980554.897
# too much error
# Total T: 24367 Episode Num: 382 Episode T: 153 Reward: -988261.387
# too much error
# Total T: 24579 Episode Num: 383 Episode T: 212 Reward: -977482.120
# too much error
# Total T: 24742 Episode Num: 384 Episode T: 163 Reward: -986682.678
# too much error
# Total T: 24929 Episode Num: 385 Episode T: 187 Reward: -982477.455
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -985681.597
# ---------------------------------------
# too much error
# Total T: 25001 Episode Num: 386 Episode T: 72 Reward: -997382.068
# too much error
# Total T: 25165 Episode Num: 387 Episode T: 164 Reward: -986514.338
# too much error
# Total T: 25430 Episode Num: 388 Episode T: 265 Reward: -964829.282
# too much error
# Total T: 25561 Episode Num: 389 Episode T: 131 Reward: -991392.020
# too much error
# Total T: 25823 Episode Num: 390 Episode T: 262 Reward: -965619.901
# too much error
# Total T: 26030 Episode Num: 391 Episode T: 207 Reward: -978532.159
# too much error
# Total T: 26344 Episode Num: 392 Episode T: 314 Reward: -950644.270
# too much error
# Total T: 26511 Episode Num: 393 Episode T: 167 Reward: -986020.933
# too much error
# Total T: 26749 Episode Num: 394 Episode T: 238 Reward: -971622.772
# too much error
# Total T: 26880 Episode Num: 395 Episode T: 131 Reward: -991393.269
# too much error
# Total T: 27127 Episode Num: 396 Episode T: 247 Reward: -969442.248
# too much error
# Total T: 27372 Episode Num: 397 Episode T: 245 Reward: -969934.598
# too much error
# Total T: 27557 Episode Num: 398 Episode T: 185 Reward: -982850.379
# too much error
# Total T: 27693 Episode Num: 399 Episode T: 136 Reward: -990724.945
# too much error
# Total T: 27831 Episode Num: 400 Episode T: 138 Reward: -990450.647
# too much error
# Total T: 27986 Episode Num: 401 Episode T: 155 Reward: -987957.097
# too much error
# Total T: 28247 Episode Num: 402 Episode T: 261 Reward: -965874.681
# too much error
# Total T: 28448 Episode Num: 403 Episode T: 201 Reward: -979754.261
# too much error
# Total T: 28632 Episode Num: 404 Episode T: 184 Reward: -983034.414
# too much error
# Total T: 28886 Episode Num: 405 Episode T: 254 Reward: -967686.380
# too much error
# Total T: 29082 Episode Num: 406 Episode T: 196 Reward: -980750.947
# too much error
# Total T: 29340 Episode Num: 407 Episode T: 258 Reward: -966657.806
# too much error
# Total T: 29482 Episode Num: 408 Episode T: 142 Reward: -989890.061
# too much error
# Total T: 29749 Episode Num: 409 Episode T: 267 Reward: -964296.069
# too much error
# Total T: 29989 Episode Num: 410 Episode T: 240 Reward: -971144.762
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -967940.373
# ---------------------------------------
# too much error
# Total T: 30005 Episode Num: 411 Episode T: 16 Reward: -998899.232
# too much error
# Total T: 30289 Episode Num: 412 Episode T: 284 Reward: -959614.167
# too much error
# Total T: 30541 Episode Num: 413 Episode T: 252 Reward: -968193.713
# too much error
# Total T: 30749 Episode Num: 414 Episode T: 208 Reward: -978323.710
# too much error
# Total T: 31045 Episode Num: 415 Episode T: 296 Reward: -956128.235
# too much error
# Total T: 31213 Episode Num: 416 Episode T: 168 Reward: -985854.847
# too much error
# Total T: 31447 Episode Num: 417 Episode T: 234 Reward: -972569.746
# too much error
# Total T: 31620 Episode Num: 418 Episode T: 173 Reward: -985000.234
# too much error
# Total T: 31883 Episode Num: 419 Episode T: 263 Reward: -965358.934
# too much error
# Total T: 32057 Episode Num: 420 Episode T: 174 Reward: -984827.382
# too much error
# Total T: 32255 Episode Num: 421 Episode T: 198 Reward: -980356.980
# too much error
# Total T: 32467 Episode Num: 422 Episode T: 212 Reward: -977482.765
# too much error
# Total T: 32651 Episode Num: 423 Episode T: 184 Reward: -983034.563
# too much error
# Total T: 32857 Episode Num: 424 Episode T: 206 Reward: -978738.856
# too much error
# Total T: 33093 Episode Num: 425 Episode T: 236 Reward: -972100.242
# too much error
# Total T: 33287 Episode Num: 426 Episode T: 194 Reward: -981142.591
# too much error
# Total T: 33540 Episode Num: 427 Episode T: 253 Reward: -967939.724
# too much error
# Total T: 33814 Episode Num: 428 Episode T: 274 Reward: -962400.338
# too much error
# Total T: 34006 Episode Num: 429 Episode T: 192 Reward: -981528.634
# too much error
# Total T: 34218 Episode Num: 430 Episode T: 212 Reward: -977483.418
# too much error
# Total T: 34469 Episode Num: 431 Episode T: 251 Reward: -968445.514
# too much error
# Total T: 34786 Episode Num: 432 Episode T: 317 Reward: -949696.220
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -975306.192
# ---------------------------------------
# too much error
# Total T: 35001 Episode Num: 433 Episode T: 215 Reward: -976835.098
# too much error
# Total T: 35170 Episode Num: 434 Episode T: 169 Reward: -985685.255
# too much error
# Total T: 35443 Episode Num: 435 Episode T: 273 Reward: -962676.144
# too much error
# Total T: 35702 Episode Num: 436 Episode T: 259 Reward: -966407.097
# too much error
# Total T: 35900 Episode Num: 437 Episode T: 198 Reward: -980357.609
# too much error
# Total T: 36163 Episode Num: 438 Episode T: 263 Reward: -965361.467
# too much error
# Total T: 36332 Episode Num: 439 Episode T: 169 Reward: -985684.238
# too much error
# Total T: 36582 Episode Num: 440 Episode T: 250 Reward: -968696.244
# too much error
# Total T: 36795 Episode Num: 441 Episode T: 213 Reward: -977271.294
# too much error
# Total T: 36960 Episode Num: 442 Episode T: 165 Reward: -986353.360
# too much error
# Total T: 37144 Episode Num: 443 Episode T: 184 Reward: -983035.415
# too much error
# Total T: 37323 Episode Num: 444 Episode T: 179 Reward: -983943.426
# too much error
# Total T: 37597 Episode Num: 445 Episode T: 274 Reward: -962402.394
# too much error
# Total T: 37761 Episode Num: 446 Episode T: 164 Reward: -986517.970
# too much error
# Total T: 38009 Episode Num: 447 Episode T: 248 Reward: -969199.382
# too much error
# Total T: 38278 Episode Num: 448 Episode T: 269 Reward: -963760.723
# too much error
# Total T: 38449 Episode Num: 449 Episode T: 171 Reward: -985345.067
# too much error
# Total T: 38732 Episode Num: 450 Episode T: 283 Reward: -959898.450
# too much error
# Total T: 38963 Episode Num: 451 Episode T: 231 Reward: -973273.468
# too much error
# Total T: 39181 Episode Num: 452 Episode T: 218 Reward: -976190.426
# too much error
# Total T: 39441 Episode Num: 453 Episode T: 260 Reward: -966143.138
# too much error
# Total T: 39684 Episode Num: 454 Episode T: 243 Reward: -970424.169
# too much error
# Total T: 39921 Episode Num: 455 Episode T: 237 Reward: -971864.895
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -973963.129
# ---------------------------------------
# too much error
# Total T: 40001 Episode Num: 456 Episode T: 80 Reward: -996777.445
# too much error
# Total T: 40236 Episode Num: 457 Episode T: 235 Reward: -972336.199
# too much error
# Total T: 40465 Episode Num: 458 Episode T: 229 Reward: -973733.205
# too much error
# Total T: 40688 Episode Num: 459 Episode T: 223 Reward: -975087.198
# too much error
# Total T: 40919 Episode Num: 460 Episode T: 231 Reward: -973269.889
# too much error
# Total T: 41149 Episode Num: 461 Episode T: 230 Reward: -973504.072
# too much error
# Total T: 41365 Episode Num: 462 Episode T: 216 Reward: -976624.658
# too much error
# Total T: 41619 Episode Num: 463 Episode T: 254 Reward: -967689.100
# too much error
# Total T: 41845 Episode Num: 464 Episode T: 226 Reward: -974417.050
# too much error
# Total T: 42061 Episode Num: 465 Episode T: 216 Reward: -976629.772
# too much error
# Total T: 42273 Episode Num: 466 Episode T: 212 Reward: -977482.160
# too much error
# Total T: 42507 Episode Num: 467 Episode T: 234 Reward: -972569.705
# too much error
# Total T: 42725 Episode Num: 468 Episode T: 218 Reward: -976194.811
# too much error
# Total T: 42945 Episode Num: 469 Episode T: 220 Reward: -975750.915
# too much error
# Total T: 43171 Episode Num: 470 Episode T: 226 Reward: -974412.755
# too much error
# Total T: 43401 Episode Num: 471 Episode T: 230 Reward: -973504.050
# too much error
# Total T: 43615 Episode Num: 472 Episode T: 214 Reward: -977054.333
# too much error
# Total T: 43872 Episode Num: 473 Episode T: 257 Reward: -966914.252
# too much error
# Total T: 44093 Episode Num: 474 Episode T: 221 Reward: -975536.438
# too much error
# Total T: 44331 Episode Num: 475 Episode T: 238 Reward: -971632.498
# too much error
# Total T: 44546 Episode Num: 476 Episode T: 215 Reward: -976839.112
# too much error
# Total T: 44763 Episode Num: 477 Episode T: 217 Reward: -976413.055
# too much error
# Total T: 45000 Episode Num: 478 Episode T: 237 Reward: -971867.096
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -968440.235
# ---------------------------------------
# too much error
# Total T: 45001 Episode Num: 479 Episode T: 1 Reward: -1000000.000
# too much error
# Total T: 45236 Episode Num: 480 Episode T: 235 Reward: -972339.481
# too much error
# Total T: 45459 Episode Num: 481 Episode T: 223 Reward: -975087.116
# too much error
# Total T: 45674 Episode Num: 482 Episode T: 215 Reward: -976839.258
# too much error
# Total T: 45916 Episode Num: 483 Episode T: 242 Reward: -970662.294
# too much error
# Total T: 46174 Episode Num: 484 Episode T: 258 Reward: -966656.698
# too much error
# Total T: 46437 Episode Num: 485 Episode T: 263 Reward: -965352.286
# too much error
# Total T: 46687 Episode Num: 486 Episode T: 250 Reward: -968691.448
# too much error
# Total T: 46940 Episode Num: 487 Episode T: 253 Reward: -967936.254
# too much error
# Total T: 47195 Episode Num: 488 Episode T: 255 Reward: -967427.213
# too much error
# Total T: 47444 Episode Num: 489 Episode T: 249 Reward: -968941.193
# too much error
# Total T: 47731 Episode Num: 490 Episode T: 287 Reward: -958761.241
# too much error
# Total T: 47981 Episode Num: 491 Episode T: 250 Reward: -968691.763
# too much error
# Total T: 48227 Episode Num: 492 Episode T: 246 Reward: -969683.270
# too much error
# Total T: 48466 Episode Num: 493 Episode T: 239 Reward: -971383.325
# too much error
# Total T: 48757 Episode Num: 494 Episode T: 291 Reward: -957606.060
# too much error
# Total T: 48987 Episode Num: 495 Episode T: 230 Reward: -973497.298
# too much error
# Total T: 49222 Episode Num: 496 Episode T: 235 Reward: -972333.555
# too much error
# Total T: 49476 Episode Num: 497 Episode T: 254 Reward: -967687.618
# too much error
# Total T: 49711 Episode Num: 498 Episode T: 235 Reward: -972334.146
# too much error
# Total T: 49993 Episode Num: 499 Episode T: 282 Reward: -960186.125
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -962958.293
# ---------------------------------------
# too much error
# Total T: 50001 Episode Num: 500 Episode T: 8 Reward: -999965.233
# too much error
# Total T: 50248 Episode Num: 501 Episode T: 247 Reward: -969444.219
# too much error
# Total T: 50600 Episode Num: 502 Episode T: 352 Reward: -937987.819
# too much error
# Total T: 50824 Episode Num: 503 Episode T: 224 Reward: -974862.400
# too much error
# Total T: 51060 Episode Num: 504 Episode T: 236 Reward: -972102.766
# too much error
# Total T: 51290 Episode Num: 505 Episode T: 230 Reward: -973498.953
# too much error
# Total T: 51569 Episode Num: 506 Episode T: 279 Reward: -961026.216
# too much error
# Total T: 51801 Episode Num: 507 Episode T: 232 Reward: -973042.432
# too much error
# Total T: 52033 Episode Num: 508 Episode T: 232 Reward: -973041.738
# too much error
# Total T: 52264 Episode Num: 509 Episode T: 231 Reward: -973274.501
# too much error
# Total T: 52494 Episode Num: 510 Episode T: 230 Reward: -973505.218
# too much error
# Total T: 52720 Episode Num: 511 Episode T: 226 Reward: -974416.843
# too much error
# Total T: 52947 Episode Num: 512 Episode T: 227 Reward: -974190.678
# too much error
# Total T: 53177 Episode Num: 513 Episode T: 230 Reward: -973505.418
# too much error
# Total T: 53437 Episode Num: 514 Episode T: 260 Reward: -966155.375
# too much error
# Total T: 53632 Episode Num: 515 Episode T: 195 Reward: -980943.896
# too much error
# Total T: 53855 Episode Num: 516 Episode T: 223 Reward: -975091.562
# too much error
# Total T: 54067 Episode Num: 517 Episode T: 212 Reward: -977480.543
# too much error
# Total T: 54288 Episode Num: 518 Episode T: 221 Reward: -975536.069
# too much error
# Total T: 54517 Episode Num: 519 Episode T: 229 Reward: -973734.406
# too much error
# Total T: 54744 Episode Num: 520 Episode T: 227 Reward: -974188.977
# too much error
# Total T: 54975 Episode Num: 521 Episode T: 231 Reward: -973271.387
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -975091.593
# ---------------------------------------
# too much error
# Total T: 55001 Episode Num: 522 Episode T: 26 Reward: -999652.002
# too much error
# Total T: 55243 Episode Num: 523 Episode T: 242 Reward: -970674.192
# too much error
# Total T: 55465 Episode Num: 524 Episode T: 222 Reward: -975313.983
# too much error
# Total T: 55690 Episode Num: 525 Episode T: 225 Reward: -974642.087
# too much error
# Total T: 55912 Episode Num: 526 Episode T: 222 Reward: -975314.332
# too much error
# Total T: 56144 Episode Num: 527 Episode T: 232 Reward: -973041.236
# too much error
# Total T: 56321 Episode Num: 528 Episode T: 177 Reward: -984295.569
# too much error
# Total T: 56554 Episode Num: 529 Episode T: 233 Reward: -972807.231
# too much error
# Total T: 56772 Episode Num: 530 Episode T: 218 Reward: -976194.174
# too much error
# Total T: 56995 Episode Num: 531 Episode T: 223 Reward: -975091.650
# too much error
# Total T: 57223 Episode Num: 532 Episode T: 228 Reward: -973962.268
# too much error
# Total T: 57454 Episode Num: 533 Episode T: 231 Reward: -973272.701
# too much error
# Total T: 57685 Episode Num: 534 Episode T: 231 Reward: -973273.658
# too much error
# Total T: 57916 Episode Num: 535 Episode T: 231 Reward: -973273.221
# too much error
# Total T: 58140 Episode Num: 536 Episode T: 224 Reward: -974866.614
# too much error
# Total T: 58396 Episode Num: 537 Episode T: 256 Reward: -967187.489
# too much error
# Total T: 58617 Episode Num: 538 Episode T: 221 Reward: -975536.072
# too much error
# Total T: 58844 Episode Num: 539 Episode T: 227 Reward: -974189.538
# too much error
# Total T: 59048 Episode Num: 540 Episode T: 204 Reward: -979144.905
# too much error
# Total T: 59276 Episode Num: 541 Episode T: 228 Reward: -973963.174
# too much error
# Total T: 59470 Episode Num: 542 Episode T: 194 Reward: -981138.152
# too much error
# Total T: 59658 Episode Num: 543 Episode T: 188 Reward: -982285.721
# too much error
# Total T: 59927 Episode Num: 544 Episode T: 269 Reward: -963772.879
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -975971.270
# ---------------------------------------
# too much error
# Total T: 60001 Episode Num: 545 Episode T: 74 Reward: -997242.085
# too much error
# Total T: 60229 Episode Num: 546 Episode T: 228 Reward: -973961.991
# too much error
# ...
# Total T: 105854 Episode Num: 769 Episode T: 207 Reward: -978535.644
# too much error
# Total T: 106066 Episode Num: 770 Episode T: 212 Reward: -977487.243
# too much error
# Total T: 106282 Episode Num: 771 Episode T: 216 Reward: -976629.564
# too much error
# Total T: 106482 Episode Num: 772 Episode T: 200 Reward: -979954.539
# too much error
# Total T: 106698 Episode Num: 773 Episode T: 216 Reward: -976632.118
# too much error
# Total T: 106906 Episode Num: 774 Episode T: 208 Reward: -978328.668
# too much error
# Total T: 107077 Episode Num: 775 Episode T: 171 Reward: -985339.823
# too much error
# Total T: 107289 Episode Num: 776 Episode T: 212 Reward: -977488.194
# too much error
# Total T: 107507 Episode Num: 777 Episode T: 218 Reward: -976196.589
# too much error
# Total T: 107732 Episode Num: 778 Episode T: 225 Reward: -974644.930
# too much error
# Total T: 107950 Episode Num: 779 Episode T: 218 Reward: -976194.922
# too much error
# Total T: 108167 Episode Num: 780 Episode T: 217 Reward: -976413.176
# too much error
# Total T: 108390 Episode Num: 781 Episode T: 223 Reward: -975089.938
# too much error
# Total T: 108599 Episode Num: 782 Episode T: 209 Reward: -978111.183
# too much error
# Total T: 108820 Episode Num: 783 Episode T: 221 Reward: -975536.790
# too much error
# Total T: 109040 Episode Num: 784 Episode T: 220 Reward: -975758.782
# too much error
# Total T: 109261 Episode Num: 785 Episode T: 221 Reward: -975535.405
# too much error
# Total T: 109471 Episode Num: 786 Episode T: 210 Reward: -977911.475
# too much error
# Total T: 109679 Episode Num: 787 Episode T: 208 Reward: -978328.923
# too much error
# Total T: 109891 Episode Num: 788 Episode T: 212 Reward: -977487.815
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -976195.045
# ---------------------------------------
# too much error
# Total T: 110001 Episode Num: 789 Episode T: 110 Reward: -993923.238
# too much error
# Total T: 110215 Episode Num: 790 Episode T: 214 Reward: -977060.781
# too much error
# Total T: 110429 Episode Num: 791 Episode T: 214 Reward: -977061.578
# too much error
# Total T: 110605 Episode Num: 792 Episode T: 176 Reward: -984471.037
# too much error
# Total T: 110811 Episode Num: 793 Episode T: 206 Reward: -978734.082
# too much error
# Total T: 111033 Episode Num: 794 Episode T: 222 Reward: -975313.676
# too much error
# Total T: 111247 Episode Num: 795 Episode T: 214 Reward: -977061.042
# too much error
# Total T: 111475 Episode Num: 796 Episode T: 228 Reward: -973962.038
# too much error
# Total T: 111693 Episode Num: 797 Episode T: 218 Reward: -976197.725
# too much error
# Total T: 111905 Episode Num: 798 Episode T: 212 Reward: -977487.914
# too much error
# Total T: 112111 Episode Num: 799 Episode T: 206 Reward: -978745.072
# too much error
# Total T: 112323 Episode Num: 800 Episode T: 212 Reward: -977486.121
# too much error
# Total T: 112537 Episode Num: 801 Episode T: 214 Reward: -977061.566
# too much error
# Total T: 112717 Episode Num: 802 Episode T: 180 Reward: -983757.726
# too much error
# Total T: 112889 Episode Num: 803 Episode T: 172 Reward: -985168.317
# too much error
# Total T: 113105 Episode Num: 804 Episode T: 216 Reward: -976630.504
# too much error
# Total T: 113313 Episode Num: 805 Episode T: 208 Reward: -978320.936
# too much error
# Total T: 113530 Episode Num: 806 Episode T: 217 Reward: -976413.166
# too much error
# Total T: 113726 Episode Num: 807 Episode T: 196 Reward: -980747.693
# too much error
# Total T: 113896 Episode Num: 808 Episode T: 170 Reward: -985510.919
# too much error
# Total T: 114071 Episode Num: 809 Episode T: 175 Reward: -984647.329
# too much error
# Total T: 114285 Episode Num: 810 Episode T: 214 Reward: -977062.561
# too much error
# Total T: 114501 Episode Num: 811 Episode T: 216 Reward: -976631.309
# too much error
# Total T: 114709 Episode Num: 812 Episode T: 208 Reward: -978329.269
# too much error
# Total T: 114921 Episode Num: 813 Episode T: 212 Reward: -977489.283
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -978742.615
# ---------------------------------------
# too much error
# Total T: 115001 Episode Num: 814 Episode T: 80 Reward: -996778.607
# too much error
# Total T: 115214 Episode Num: 815 Episode T: 213 Reward: -977274.495
# too much error
# Total T: 115431 Episode Num: 816 Episode T: 217 Reward: -976413.780
# too much error
# Total T: 115645 Episode Num: 817 Episode T: 214 Reward: -977062.681
# too much error
# Total T: 115862 Episode Num: 818 Episode T: 217 Reward: -976412.920
# too much error
# Total T: 116080 Episode Num: 819 Episode T: 218 Reward: -976197.768
# too much error
# Total T: 116288 Episode Num: 820 Episode T: 208 Reward: -978329.567
# too much error
# Total T: 116495 Episode Num: 821 Episode T: 207 Reward: -978538.298
# too much error
# Total T: 116672 Episode Num: 822 Episode T: 177 Reward: -984294.899
# too much error
# Total T: 116878 Episode Num: 823 Episode T: 206 Reward: -978745.659
# too much error
# Total T: 117080 Episode Num: 824 Episode T: 202 Reward: -979562.004
# too much error
# Total T: 117301 Episode Num: 825 Episode T: 221 Reward: -975535.640
# too much error
# Total T: 117509 Episode Num: 826 Episode T: 208 Reward: -978330.445
# too much error
# Total T: 117699 Episode Num: 827 Episode T: 190 Reward: -981908.378
# too much error
# Total T: 117908 Episode Num: 828 Episode T: 209 Reward: -978120.559
# too much error
# Total T: 118110 Episode Num: 829 Episode T: 202 Reward: -979561.283
# too much error
# Total T: 118318 Episode Num: 830 Episode T: 208 Reward: -978331.456
# too much error
# Total T: 118520 Episode Num: 831 Episode T: 202 Reward: -979553.709
# too much error
# Total T: 118685 Episode Num: 832 Episode T: 165 Reward: -986350.543
# too much error
# Total T: 118863 Episode Num: 833 Episode T: 178 Reward: -984117.106
# too much error
# Total T: 119068 Episode Num: 834 Episode T: 205 Reward: -978951.355
# too much error
# Total T: 119274 Episode Num: 835 Episode T: 206 Reward: -978745.034
# too much error
# Total T: 119467 Episode Num: 836 Episode T: 193 Reward: -981342.169
# too much error
# Total T: 119674 Episode Num: 837 Episode T: 207 Reward: -978538.875
# too much error
# Total T: 119824 Episode Num: 838 Episode T: 150 Reward: -988717.341
# too much error
# Total T: 119979 Episode Num: 839 Episode T: 155 Reward: -987954.732
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -981727.612
# ---------------------------------------
# too much error
# Total T: 120001 Episode Num: 840 Episode T: 22 Reward: -999750.176
# too much error
# Total T: 120180 Episode Num: 841 Episode T: 179 Reward: -983941.256
# too much error
# Total T: 120346 Episode Num: 842 Episode T: 166 Reward: -986184.428
# too much error
# Total T: 120541 Episode Num: 843 Episode T: 195 Reward: -980953.701
# too much error
# Total T: 120739 Episode Num: 844 Episode T: 198 Reward: -980362.379
# too much error
# Total T: 120949 Episode Num: 845 Episode T: 210 Reward: -977910.941
# too much error
# Total T: 121105 Episode Num: 846 Episode T: 156 Reward: -987798.246
# too much error
# Total T: 121258 Episode Num: 847 Episode T: 153 Reward: -988263.980
# too much error
# Total T: 121463 Episode Num: 848 Episode T: 205 Reward: -978949.659
# too much error
# Total T: 121670 Episode Num: 849 Episode T: 207 Reward: -978538.071
# too much error
# Total T: 121878 Episode Num: 850 Episode T: 208 Reward: -978330.858
# too much error
# Total T: 122077 Episode Num: 851 Episode T: 199 Reward: -980164.757
# too much error
# Total T: 122215 Episode Num: 852 Episode T: 138 Reward: -990449.484
# too much error
# Total T: 122402 Episode Num: 853 Episode T: 187 Reward: -982483.782
# too much error
# Total T: 122581 Episode Num: 854 Episode T: 179 Reward: -983951.312
# too much error
# Total T: 122761 Episode Num: 855 Episode T: 180 Reward: -983770.762
# too much error
# Total T: 122889 Episode Num: 856 Episode T: 128 Reward: -991782.072
# too much error
# Total T: 123076 Episode Num: 857 Episode T: 187 Reward: -982483.886
# too much error
# Total T: 123249 Episode Num: 858 Episode T: 173 Reward: -985009.472
# too much error
# Total T: 123418 Episode Num: 859 Episode T: 169 Reward: -985684.538
# too much error
# Total T: 123592 Episode Num: 860 Episode T: 174 Reward: -984835.397
# too much error
# Total T: 123779 Episode Num: 861 Episode T: 187 Reward: -982484.707
# too much error
# Total T: 123959 Episode Num: 862 Episode T: 180 Reward: -983771.151
# too much error
# Total T: 124069 Episode Num: 863 Episode T: 110 Reward: -993930.901
# too much error
# Total T: 124239 Episode Num: 864 Episode T: 170 Reward: -985524.336
# too much error
# Total T: 124411 Episode Num: 865 Episode T: 172 Reward: -985182.718
# too much error
# Total T: 124573 Episode Num: 866 Episode T: 162 Reward: -986845.556
# too much error
# Total T: 124688 Episode Num: 867 Episode T: 115 Reward: -993365.604
# too much error
# Total T: 124808 Episode Num: 868 Episode T: 120 Reward: -992776.951
# too much error
# Total T: 124967 Episode Num: 869 Episode T: 159 Reward: -987328.343
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -993250.995
# ---------------------------------------
# too much error
# Total T: 125001 Episode Num: 870 Episode T: 34 Reward: -999413.683
# too much error
# Total T: 125106 Episode Num: 871 Episode T: 105 Reward: -994470.260
# too much error
# Total T: 125276 Episode Num: 872 Episode T: 170 Reward: -985524.085
# too much error
# Total T: 125440 Episode Num: 873 Episode T: 164 Reward: -986528.860
# too much error
# Total T: 125595 Episode Num: 874 Episode T: 155 Reward: -987957.277
# too much error
# Total T: 125769 Episode Num: 875 Episode T: 174 Reward: -984835.625
# too much error
# Total T: 125938 Episode Num: 876 Episode T: 169 Reward: -985694.386
# too much error
# Total T: 126064 Episode Num: 877 Episode T: 126 Reward: -992037.948
# too much error
# Total T: 126203 Episode Num: 878 Episode T: 139 Reward: -990311.144
# too much error
# Total T: 126300 Episode Num: 879 Episode T: 97 Reward: -995279.153
# too much error
# Total T: 126461 Episode Num: 880 Episode T: 161 Reward: -987007.408
# too much error
# Total T: 126618 Episode Num: 881 Episode T: 157 Reward: -987644.602
# too much error
# Total T: 126786 Episode Num: 882 Episode T: 168 Reward: -985863.498
# too much error
# Total T: 126949 Episode Num: 883 Episode T: 163 Reward: -986682.758
# too much error
# Total T: 127083 Episode Num: 884 Episode T: 134 Reward: -990996.200
# too much error
# Total T: 127253 Episode Num: 885 Episode T: 170 Reward: -985515.461
# too much error
# Total T: 127358 Episode Num: 886 Episode T: 105 Reward: -994469.806
# too much error
# Total T: 127522 Episode Num: 887 Episode T: 164 Reward: -986528.949
# too much error
# Total T: 127684 Episode Num: 888 Episode T: 162 Reward: -986856.363
# too much error
# Total T: 127838 Episode Num: 889 Episode T: 154 Reward: -988112.255
# too much error
# Total T: 127934 Episode Num: 890 Episode T: 96 Reward: -995376.599
# too much error
# Total T: 128085 Episode Num: 891 Episode T: 151 Reward: -988570.685
# too much error
# Total T: 128248 Episode Num: 892 Episode T: 163 Reward: -986683.037
# too much error
# Total T: 128407 Episode Num: 893 Episode T: 159 Reward: -987328.103
# too much error
# Total T: 128544 Episode Num: 894 Episode T: 137 Reward: -990589.406
# too much error
# Total T: 128650 Episode Num: 895 Episode T: 106 Reward: -994363.926
# too much error
# Total T: 128819 Episode Num: 896 Episode T: 169 Reward: -985695.405
# too much error
# Total T: 128987 Episode Num: 897 Episode T: 168 Reward: -985862.957
# too much error
# Total T: 129153 Episode Num: 898 Episode T: 166 Reward: -986188.848
# too much error
# Total T: 129255 Episode Num: 899 Episode T: 102 Reward: -994781.142
# too much error
# Total T: 129416 Episode Num: 900 Episode T: 161 Reward: -987007.452
# too much error
# Total T: 129588 Episode Num: 901 Episode T: 172 Reward: -985183.171
# too much error
# Total T: 129766 Episode Num: 902 Episode T: 178 Reward: -984117.963
# too much error
# Total T: 129932 Episode Num: 903 Episode T: 166 Reward: -986185.677
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# too much error
# ---------------------------------------
# Evaluation over 10 episodes: -995278.112
# ---------------------------------------
# too much error
# Total T: 130001 Episode Num: 904 Episode T: 69 Reward: -997599.627
# too much error
# Total T: 130137 Episode Num: 905 Episode T: 136 Reward: -990725.595
# too much error
# Total T: 130304 Episode Num: 906 Episode T: 167 Reward: -986031.248
# too much error
# Total T: 130460 Episode Num: 907 Episode T: 156 Reward: -987801.327
# too much error
# Total T: 130570 Episode Num: 908 Episode T: 110 Reward: -993929.801
# too much error
# Total T: 130706 Episode Num: 909 Episode T: 136 Reward: -990726.034
# too much error
# Total T: 130880 Episode Num: 910 Episode T: 174 Reward: -984836.097
# too much error
# Total T: 131016 Episode Num: 911 Episode T: 136 Reward: -990725.842
# too much error
# Total T: 131126 Episode Num: 912 Episode T: 110 Reward: -993930.594
# too much error
# Total T: 131294 Episode Num: 913 Episode T: 168 Reward: -985864.541
# too much error
# Total T: 131386 Episode Num: 914 Episode T: 92 Reward: -995753.033
# too much error
# Total T: 131492 Episode Num: 915 Episode T: 106 Reward: -994364.974
# too much error
# Total T: 131641 Episode Num: 916 Episode T: 149 Reward: -988869.239
# too much error
# Total T: 131733 Episode Num: 917 Episode T: 92 Reward: -995753.146
# too much error
# Total T: 131836 Episode Num: 918 Episode T: 103 Reward: -994677.952
# too much error
# Total T: 131949 Episode Num: 919 Episode T: 113 Reward: -993595.778
# too much error
# Total T: 132125 Episode Num: 920 Episode T: 176 Reward: -984486.071
# too much error
# Total T: 132285 Episode Num: 921 Episode T: 160 Reward: -987168.457
# too much error
# Total T: 132395 Episode Num: 922 Episode T: 110 Reward: -993930.692
# too much error
# Total T: 132527 Episode Num: 923 Episode T: 132 Reward: -991263.313
# too much error
# Total T: 132639 Episode Num: 924 Episode T: 112 Reward: -993709.339
# too much error
# Total T: 132742 Episode Num: 925 Episode T: 103 Reward: -994677.986
# too much error
# Total T: 132906 Episode Num: 926 Episode T: 164 Reward: -986518.697
# too much error
# Total T: 133067 Episode Num: 927 Episode T: 161 Reward: -987007.890
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ba9bcda43ad9> in <cell line: 2>()
#      25     # Train agent after collecting sufficient data
#      26     if t >= DEFAULT_START_TIMESTEPS:
# ---> 27         policy.train(replay_buffer, DEFAULT_BATCH_SIZE)
#      28
#      29     if done:
#
# <ipython-input-3-c7098bb05c4f> in train(self, replay_buffer, batch_size)
#     128         # Optimize the critic
#     129         self.critic_optimizer.zero_grad()
# --> 130         critic_loss.backward()
#     131         self.critic_optimizer.step()
#     132
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     520                 inputs=inputs,
#     521             )
# --> 522         torch.autograd.backward(
#     523             self, gradient, retain_graph, create_graph, inputs=inputs
#     524         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     264     # some Python versions print out the first line of a multi-line function
#     265     # calls in the traceback and some print out the last line
# --> 266     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267         tensors,
#     268         grad_tensors_,
#
# KeyboardInterrupt:

# %%
evaluations = np.load(f"./results/{file_name}.npy")

plt.plot(evaluations, label="evaluations")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.legend()
plt.show()

# %%
## run simulation
prev_state= env.reset()
state_array = []
action_array = []
while True:
    # env.render()
    action = policy.select_action(np.array(state))
    state, reward, done, position = env.step(action)
    action_array.append(action)
    episode_reward += reward
    state_array.append(position)
    action_array.append(action)
    if done:
        break
    prev_state = state

state_array = np.array(state_array)
action_array = np.array(action_array)
plt.plot(state_array[:,0], state_array[:,1], label='State')
plt.plot(trajectory[:,0], trajectory[:,1], label='Trajectory')
print(state_array[-1, :])
print(env.steps)
plt.legend()
plt.show()

# plot action
plt.plot(action_array.reshape(len(action_array), 2))
plt.legend()
plt.show()

print(len(action_array))
