# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
## import trajectory data
df = pd.read_csv('trajectory.csv')
df.head()
# df to numpy array
data = df.to_numpy()
data.shape
trajectory = np.delete(data, 2, 1)
trajectory = np.delete(trajectory, -1, 1)
trajectory.shape
# Out:
# (9999, 4)

# %%
plt.plot(trajectory[:,0], trajectory[:,1])

# %%
# three body problem env
import gym
from gym import spaces
from stable_baselines3 import PPO, DDPG
import numpy as np

class three_body_env(gym.Env):
    def __init__(self, trajectory):
        self.trajectory = trajectory
        self.state = np.zeros(4)
        self.dt = 0.01
        self.mu = 0.012277471
        self.action_space = spaces.Box(low=-100, high=100, shape=(2,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-10, high=10, shape=(4,), dtype=np.float32)
        self.position = trajectory[0]
        self.steps = 0
        self.max_steps = 1000
        self.reward_range = (-float('inf'), float('inf'))
        self.reset()

    def step(self, action):
        x = self.position[0]
        y = self.position[1]
        xdot = self.position[2]
        ydot = self.position[3]

        a_x = action[0]
        a_y = action[1]

        r1 = np.sqrt((x+self.mu)**2 + y**2)
        r2 = np.sqrt((x-1+self.mu)**2 + y**2)

        xddot = 2*ydot + x -(1-self.mu)*((x+self.mu)/(r1**3)) - self.mu*(x-1+self.mu)/(r2**3) + a_x/100
        yddot = -2*xdot + y - (1-self.mu)*(y/(r1**3)) - self.mu*(y)/(r2**3) + a_y/100

        x = x + xdot*self.dt
        y = y + ydot*self.dt
        
        xdot = xdot + xddot*self.dt
        ydot = ydot + yddot*self.dt

        self.position = np.array([x, y, xdot, ydot])

        self.steps += 1

        self.position2state()

        reward = 1 - np.linalg.norm(self.position - self.trajectory[self.steps], axis=0)
        done = self.steps >= self.max_steps
        if abs(self.position - self.trajectory[-1]).sum() < 0.005:
            done = True
            reward = 1000
        if self.steps > 1000:
            print('Haji shit kar kard')
            done = True
            reward = -1000
        if np.linalg.norm(self.state) > 4:
            done = True
            print('Oooopss')
            reward = -1000

        return self.state, reward, done, {}

    def position2state(self):
        # find nearest point from position to trajectory
        distance = np.linalg.norm(self.trajectory - self.position, axis=1)
        nearest_idx = np.argmin(distance)
        # estate = position - nearest(index)
        self.state = self.position - self.trajectory[nearest_idx]
        self.state *= 100
    
    def reset(self):
        self.position = self.trajectory[0]   
        self.steps = 0
        self.position2state()
        return self.state
    
    def render(self):
        pass

    def close(self):
        pass

# %%
env = three_body_env(trajectory)
# Create a PPO agent
# model = PPO("MlpPolicy", env, verbose=1)
model = PPO("MlpPolicy", env, verbose=1)
# model.learn(total_timesteps=100000, log_interval=4)
TIMESTEPS = 10000
for i in range (3):
# model = PPO ("MlpPolicy", env, verbose=1)
  model. learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
  print(i)


env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /Users/Ali/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -350     |
# | time/              |          |
# |    fps             | 1114     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -6.56e+03    |
# | time/                   |              |
# |    fps                  | 831          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0064984285 |
# |    clip_fraction        | 0.0521       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -0.0506      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.72         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 1.02         |
# |    value_loss           | 66.4         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       6 TIMESTEPS = 10000
#       7 for i in range (3):
#       8 # model = PPO ("MlpPolicy", env, verbose=1)
# ----> 9   model. learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
#      10   print(i)
#      13 env.close()
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:178, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     175 with th.no_grad():
#     176     # Convert to pytorch tensor or to TensorDict
#     177     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 178     actions, values, log_probs = self.policy(obs_tensor)
#     179 actions = actions.cpu().numpy()
#     181 # Rescale and perform action
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/policies.py:653, in ActorCriticPolicy.forward(self, obs, deterministic)
#     651 values = self.value_net(latent_vf)
#     652 distribution = self._get_action_dist_from_latent(latent_pi)
# --> 653 actions = distribution.get_actions(deterministic=deterministic)
#     654 log_prob = distribution.log_prob(actions)
#     655 actions = actions.reshape((-1, *self.action_space.shape))  # type: ignore[misc]
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/distributions.py:89, in Distribution.get_actions(self, deterministic)
#      87 if deterministic:
#      88     return self.mode()
# ---> 89 return self.sample()
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/stable_baselines3/common/distributions.py:183, in DiagGaussianDistribution.sample(self)
#     181 def sample(self) -> th.Tensor:
#     182     # Reparametrization trick to pass gradients
# --> 183     return self.distribution.rsample()
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/torch/distributions/normal.py:74, in Normal.rsample(self, sample_shape)
#      72 def rsample(self, sample_shape=torch.Size()):
#      73     shape = self._extended_shape(sample_shape)
# ---> 74     eps = _standard_normal(shape, dtype=self.loc.dtype, device=self.loc.device)
#      75     return self.loc + eps * self.scale
#
# File ~/Documents/BAI/Master/master-thesis/.env/lib/python3.11/site-packages/torch/distributions/utils.py:56, in _standard_normal(shape, dtype, device)
#      52         return torch.broadcast_tensors(*new_values)
#      53     return torch.broadcast_tensors(*values)
# ---> 56 def _standard_normal(shape, dtype, device):
#      57     if torch._C._get_tracing_state():
#      58         # [JIT WORKAROUND] lack of support for .normal_()
#      59         return torch.normal(
#      60             torch.zeros(shape, dtype=dtype, device=device),
#      61             torch.ones(shape, dtype=dtype, device=device),
#      62         )
#
# KeyboardInterrupt:

# %%
# load model
env = three_body_env(trajectory)
model_trained = PPO.load("PPO_thbp", env, verbose=1)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# test trained model
# save states 
position = np.zeros((10000, 4))
env = three_body_env(trajectory)
obs = env.reset()
for i in range(10000):
  action, _states = model.predict(obs, deterministic=True)
  obs, rewards, dones, info = env.step(action)
  position[i] = env.position
  env.render()
  if dones:
    obs = env.reset()

env.close()
# Out:
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss
# Oooopss

# %%
# plot position
plt.plot(position[:,0], position[:,1])
plt.plot(trajectory[:,0], trajectory[:,1])
plt.legend(['position', 'trajectory'])
plt.show()
